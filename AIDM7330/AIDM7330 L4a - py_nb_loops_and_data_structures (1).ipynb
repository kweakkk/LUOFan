# %%
n = 5
while n > 0 :
    print('Lather')
    print('Rinse')
print('Dry off!')
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-bd32595d7920> in <cell line: 2>()
#       1 n = 5
#       2 while n > 0 :
# ----> 3     print('Lather')
#       4     print('Rinse')
#       5 print('Dry off!')
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/lib/python3.10/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     616                 )
#     617             data.group = group
# --> 618         return super().send(data, flags=flags, copy=copy, track=track)
#     619
#     620     def send_multipart(
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.10/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %% [markdown]
# # AIDM7330 Basic Programming for Data Science

# %% [markdown]
# # Loops

# %% [markdown]
# ## Indefinite Loops

# %%
n = 5
while n > 0 :
    print(n)
    n = n - 1
print('Blastoff!')
print(n)
# Out:
# 5
# 4
# 3
# 2
# 1
# Blastoff!
# 0

# %%
n = 0
while n > 0 :
    print('Lather')
    print('Rinse')
print('Dry off!')
# Out:
# Dry off!

# %%
n = -1
while n > 0:
    print(n)
    n = n - 1
print('Blatoff!')
# Out:
# Blatoff!

# %%
10 > 0
# Out:
# True

# %% [markdown]
# ### Break

# %%
while True: #avoid using while true
    line = input('input something:')
    if line == 'done':
        break
    print(line)
print('BYE BYE!')
# Out:
# input something:123
# 123
# input something:done
# BYE BYE!

# %% [markdown]
# ### Continue

# %%
nextInput = True
while nextInput == True:
    line = input(' -->')
    if line =='#':
        continue
    if line == 'done':
        nextInput = False
    else:
        print(line)
print('DONE!')
# Out:
#  -->0
# 0
#  -->done
# DONE!

# %% [markdown]
# ### Example: Guess the number!

# %%
# Extract a random number between 1 and 10
import random
extractedNumber = int(random.randint(1,10))

# Request a number to the user
myGuess = int(input('Your guessed number:'))

# Loop until the user guess the exact number
while myGuess != extractedNumber:
    if myGuess > extractedNumber:
        print('Guess a smaller number')
        myGuess = int(input('Your guessed number:'))
    if myGuess < extractedNumber:
        print('Guess a bigger number')
        myGuess = int(input('Your guessed number:'))
    if myGuess == extractedNumber:
        print('Bravo!')
        break
print(extractedNumber)
# Out:
# Your guessed number:10
# Guess a smaller number
# Your guessed number:1
# Guess a bigger number
# Your guessed number:9
# Guess a smaller number
# Your guessed number:6
# Guess a smaller number
# Your guessed number:3
# Guess a bigger number
# Your guessed number:4
# Guess a bigger number
# Your guessed number:5
# Bravo!
# 5

# %% [markdown]
# ## Exercise 1
# Rewrite the program using:
# - only one input

# %%
# Extract a random number between 1 and 10
import random
extractedNumber = int(random.randint(1,10))

myGuess=None #you can input everything,none!=int
# Request a number to the user


# Loop until the user guess the exact number
while myGuess != extractedNumber:
  myGuess = int(input('Your guessed number:'))
  if myGuess > extractedNumber:
        print('Guess a smaller number')
        #no myGuess = int(input('Your guessed number:')),you don't need to check again
  if myGuess < extractedNumber:
        print('Guess a bigger number')

  if myGuess == extractedNumber:
        print('Bravo!')
        break
print(extractedNumber)
# Out:
# Your guessed number:8
# Guess a smaller number
# Your guessed number:7
# Guess a smaller number
# Your guessed number:5
# Guess a bigger number
# Your guessed number:6
# Bravo!
# 6

# %% [markdown]
# ## Exercise 2
# Rewrite the program using:
# - only one input
# - continue statement

# %%
# only when you get the right number can escape the loop
import random
extractedNumber = int(random.randint(1,10))

myGuess=None
#loop until the user guess the exact number
while myGuess != extractedNumber:
  myGuess=int(input("You guessed number:"))
  if myGuess > extractedNumber:
        print('Guess a smaller number')
        continue
  if myGuess < extractedNumber:
        print('Guess a bigger number')
        continue
print("Bravo!")
print(extractedNumber)
#keep the condition easy to understand
# Out:
# You guessed number:9
# Guess a smaller number
# You guessed number:7
# Guess a bigger number
# You guessed number:8
# Bravo!
# 8

# %% [markdown]
# ## Exercise 3
# Rewrite the program using:
# - only one input
# - continue statement
# - boolean variable ```guessedCorrectly``` to control the loop and check if the user guessed the right number

# %%
import random
extractedNumber = int(random.randint(1,10))
guessedCorrectly=False

while not(guessedCorrectly ==True):
  myGuess=int(input("You guessed number:"))
  if myGuess>extractedNumber:
      print("Guess a smaller number")
      continue
  if myGuess < extractedNumber:
        print('Guess a bigger number')
        continue
  if myGuess==extractedNumber:
        print("Bravo")
        guessedCorrectly=True #escape from the loop
        continue
print(extractedNumber)
# Out:
# You guessed number:8
# Guess a bigger number
# You guessed number:9
# Guess a bigger number
# You guessed number:10
# Bravo
# 10

# %% [markdown]
# ## Definite Loops

# %% [markdown]
# Let's rewrite the first example in a more readable way

# %%
for number in [5,4,3,2,1]:
    print(number)
print('Blastoff!')
# Out:
# 5
# 4
# 3
# 2
# 1
# Blastoff!

# %% [markdown]
# We can loop through the list strings using ```for```

# %%
list1 = ['Italia', 'Pizza','Ciao']
for word in list1:
    print(word)
# Out:
# Italia
# Pizza
# Ciao

# %% [markdown]
# Strings are special... they are lists of characters

# %%
text = 'Pizza' #string is a special list
for character in text:
    print(character, end='-') #Another print parameter
# Out:
# P-i-z-z-a-

# %%
text = ['P', 'i', 'z', 'z', 'a']
for character in text:
    print(character, end='-') #Another print parameter
# Out:
# P-i-z-z-a-

# %% [markdown]
# Find big elements in a list of numbers

# %%
for number in [8, 56, 75, 9, 10]:
    if number > 40:
        print('Element value:', number)
# Out:
# Element value: 56
# Element value: 75

# %% [markdown]
# Find the maximum element in a list

# %%
maxElement = 0
for number in [8, 56, 75, 9, 10]:
    if number >= maxElement:
        maxElement = number
print('Maximum element value:', maxElement)
# Out:
# Maximum element value: 75

# %% [markdown]
# ## Exercise 4
# Find the minimum element in a list

# %%
minElement=75
for number in [8,56,75,9,10]:
  if number <= minElement:
      minElement=number
print("Minimum element value: ",minElement)
# Out:
# Minimum element value:  8

# %%
minElement=None
for number in [8,56,75,9,10]:
    if minElement is None: #make sure number in the list
        minElement=number
        continue
    if number<= minElement:
        minElement = number
print("Minimum element value: ",minElement)
# Out:
# Minimum element value:  8

# %% [markdown]
# # Advanced Loops with Iterators
# We will use them throughout the course, together with the data structures

# %% [markdown]
# ## range()
# Generates a sequence of numbers
# Starting from 0 (programmers count from 0)

# %%
for i in range(2, 6, 2):# 2+2=4 range(start, stop[, step])
    print(i)
# Out:
# 2
# 4

# %%
for i in range(6):
    print(i, end=',')
# Out:
# 0,1,2,3,4,5,

# %%
help(range)
# Out:
# Help on class range in module builtins:
#
# class range(object)
#  |  range(stop) -> range object
#  |  range(start, stop[, step]) -> range object
#  |
#  |  Return an object that produces a sequence of integers from start (inclusive)
#  |  to stop (exclusive) by step.  range(i, j) produces i, i+1, i+2, ..., j-1.
#  |  start defaults to 0, and stop is omitted!  range(4) produces 0, 1, 2, 3.
#  |  These are exactly the valid indices for a list of 4 elements.
#  |  When step is given, it specifies the increment (or decrement).
#  |
#  |  Methods defined here:
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __reduce__(...)
#  |      Helper for pickle.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __reversed__(...)
#  |      Return a reverse iterator.
#  |
#  |  count(...)
#  |      rangeobject.count(value) -> integer -- return number of occurrences of value
#  |
#  |  index(...)
#  |      rangeobject.index(value) -> integer -- return index of value.
#  |      Raise ValueError if the value is not present.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  start
#  |
#  |  step
#  |
#  |  stop

# %% [markdown]
# ## enumerate()
# Keep track of values in the list and their index

# %%
myList = ['Ciao', 'Italia', 'Pizza']
print('Starting from 0:')
for index, value in enumerate(myList): #index value 建立对应关系
    print(index, value)

print('Starting from 1:')
for index, value in enumerate(myList, 1): #starting from 1
    print(index, value)
# Out:
# Starting from 0:
# 0 Ciao
# 1 Italia
# 2 Pizza
# Starting from 1:
# 1 Ciao
# 2 Italia
# 3 Pizza

# %% [markdown]
# ## zip()
# Loop over multiple lists.
#
# If the lists have different lengths, the shortest will determine the length of the zip

# %%
myLeftList = ['Ciao', 'Bella', 'Pizza', 'Arrivederci']
myRightList = ['Amore', 'Italia', 'Margherita']
for lval, rval in zip(myLeftList, myRightList):
    print(lval, rval)
# Out:
# Ciao Amore
# Bella Italia
# Pizza Margherita

# %% [markdown]
# # Lists

# %%
list1 = [1, 2, 3, 4]
list2 = ['Ciao', 'Italia', 'Pizza']
list3 = [] #Important
list4 = [1, 2, 3, 4, 5, 6, 7, ['Ciao', 'Italia', 'Pizza']] # Nested list

print(list1)
print(list2)
print(list3)
print(list4)
# Out:
# [1, 2, 3, 4]
# ['Ciao', 'Italia', 'Pizza']
# []
# [1, 2, 3, 4, 5, 6, 7, ['Ciao', 'Italia', 'Pizza']]

# %%
list4[7][1] #集中集
# Out:
# 'Italia'

# %% [markdown]
# Lists are mutable

# %%
print(list2)
list2[2] = 'Pizza Margherita' #change some element
print(list2)
# Out:
# ['Ciao', 'Italia', 'Pizza']
# ['Ciao', 'Italia', 'Pizza Margherita']

# %% [markdown]
# Lists can be concatenated

# %%
list1 + list2
# Out:
# [1, 2, 3, 4, 'Ciao', 'Italia', 'Pizza Margherita']

# %% [markdown]
# Invert a list

# %%
print(list1)
print(list1[::-1])#reverse a list
# Out:
# [1, 2, 3, 4]
# [4, 3, 2, 1]

# %% [markdown]
# Getitng the lenght of a list

# %%
len(list1)
# Out:
# 4

# %%
list1[3] # start from zero
# Out:
# 4

# %%
print(list1[0]) #We count from 0!
print(list1[3])

# %% [markdown]
# Adding elements to a list

# %%
list1[4] = 90 # NO
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-47-00d3b0cc144b> in <cell line: 1>()
# ----> 1 list1[4] = 90 # NO
#
# IndexError: list assignment index out of range

# %%
# Add elements at the end
list1.append(5) #don't care position,just put on the end
print(list1)
# Out:
# [1, 2, 3, 4, 5]

# %%
len(list1)
# Out:
# 5

# %%
# Add elements in a specific position
list1.insert(2,'Ciao') #2 is index
print(list1)
# Out:
# [1, 2, 'Ciao', 3, 4, 5]

# %% [markdown]
# Remove an element from the list (specify the value)
# - Removes the first occurrence of value.
# - Raises ValueError if the value is not present.

# %%
list1.remove(2)
print(list1)
# Out:
# [1, 'Ciao', 3, 4, 5]

# %% [markdown]
# Remove (and return) the last element in the list

# %%
list1.pop()
# Out:
# 5

# %% [markdown]
# Sorting a list
# - using builtin method (in-place)
# - using the ```sorted``` function (returns a new list)

# %%
list1 = [2,1,3,4] #reorder
list1.sort()
print(list1)# the order of list1 has changed
# Out:
# [1, 2, 3, 4]

# %%
reverseList1 = sorted(list1, reverse = True)
print(list1)
print(reverseList1)
# Out:
# [1, 2, 3, 4]
# [4, 3, 2, 1]

# %% [markdown]
# Check presence of valure in list

# %%
4 in list1 #very important
# Out:
# True

# %% [markdown]
# Utility functions

# %%
print(min(list1))
print(max(list1))
print(sum(list1))
print(sum(list1)/len(list1)) #avg
# Out:
# 1
# 4
# 10
# 2.5

# %% [markdown]
# Traversing a list

# %%
list1 = [1, 2, 3, 4, 5, 6, 7]
numElements = len(list1) #returns the length of the list1
for i in range(numElements):
    list1[i] = list1[i] * 2 #double the value of the elements
print(list1)
# Out:
# [2, 4, 6, 8, 10, 12, 14]

# %%
for element in list1:
    print(element)
# Out:
# 2
# 4
# 6
# 8
# 10
# 12
# 14

# %% [markdown]
# # Dictionaries

# %%
purse = dict()
purse['money'] = 12
purse['candy'] = 3
purse['tissues'] = 75
print(purse)
# Out:
# {'money': 12, 'candy': 3, 'tissues': 75}

# %%
print(purse['candy'])
# Out:
# 3

# %%
purse['candy'] = purse['candy'] + 2
print(purse)
# Out:
# {'money': 12, 'candy': 7, 'tissues': 75}

# %%
purse['key']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-59571994d730> in <cell line: 1>()
# ----> 1 purse['key']
#
# KeyError: 'key'

# %%
'key' in purse
# Out:
# False

# %%
'candy' in purse
# Out:
# True

# %%
#put key in purse
if not('key' in purse):
    purse['key'] = 1
else:
    purse['key'] = purse['key'] + 1

# %%
print(purse['key'])
# Out:
# 1

# %%
for keyWord in purse:
    print(keyWord)
# Out:
# money
# candy
# tissues
# key

# %%
for keyWord in purse:
    print(keyWord)
    print(purse[keyWord])
# Out:
# money
# 12
# candy
# 7
# tissues
# 75
# key
# 1

# %%
print(purse.items())

# %%
for keyWord, value in purse.items():
    print('Object:', keyWord, 'Number:', value)

# %%
# Cannot be ordered
d = {'money': 1, 'ID': 'M999888'}
d

# %% [markdown]
# ### Ordering a dict

# %%
d = {'a':10, 'c':22, 'b':1}
print(d.items())
print(sorted(d.items()))
# Out:
# dict_items([('a', 10), ('c', 22), ('b', 1)])
# [('a', 10), ('b', 1), ('c', 22)]

# %%
d # No change

# %% [markdown]
# # Tuples

# %%
x = ('Glenn', 'Sally', 'Joseph')
print(x)
print(x[2])
y = ( 1, 9, 2 )
print(y)
print(max(y))

# %%
for e in x:
    print('Element:', e)

# %% [markdown]
# Tuples are immutable

# %%
y[2] = 4

# %% [markdown]
# Comparing tuples

# %%
x > y

# %%
z = (12, 13, 15)
print(y)
print(z)
print(y < z)

# %% [markdown]
# Be careful about the comparison:
# - ```<``` operation answers the question "Is the majority of elements in the first tuple smaller than the ones in the second tuple?"

# %%
print(y)
print(z)
print(y < z)

# %% [markdown]
# # Sets

# %%
# Unordered collection of *unique* values; which are mutable and unordered
set1 = {'Italia', 'Ciao','Pizza'}
set1
# Out:
# {'Ciao', 'Italia', 'Pizza'}

# %% [markdown]
# Add elements to a set

# %%
set1.add('Amore')
set1.add('Pizza') # Add another Pizza ... unique values, only one pizza
set1

# %% [markdown]
# Sets are unordered, we cannot access the elements by index

# %%
set1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-c38563f1af7a> in <cell line: 1>()
# ----> 1 set1[0]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# Check if an element is in the set

# %%
'Pizza' in set1
# Out:
# True

# %% [markdown]
# Remove an element by value (only way)

# %%
set1.remove('Pizza')
set1

# %%
set2 = set([1,2,3,3,3,4])
print(set2)
print("The size of the set is ", len(set2))

# %%
set2.add("B") # The elements can be of different types
print(set2)

# %%
# common methods for sets: intersection, union, difference

a_set = {4,3,2,1}
b_set = {3,4,5,6}

intersect_set = set.intersection(a_set, b_set)
print("The intersection of a and b is ", intersect_set)

union_set = set.union(a_set, b_set)
print("The union of a and b is ", union_set)

# pay attention to the order
difference_set = a_set.difference(b_set)
print("Set a is different from set b by ", difference_set)
difference_set2 = b_set.difference(a_set)
print("Set b is different from set a by ", difference_set2)
# Out:
# The intersection of a and b is  {3, 4}
# The union of a and b is  {1, 2, 3, 4, 5, 6}
# Set a is different from set b by  {1, 2}
# Set b is different from set a by  {5, 6}

# %%
a_set={'money','candy'}
b_set={'tissues','smartphone'}
union_set=set.union(a_set,b_set)
print(union_set)
# Out:
# {'candy', 'smartphone', 'tissues', 'money'}
