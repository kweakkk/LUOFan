# %% [markdown]
# # AIDM7330 Basic Programming for Data Science
#
# ## Scraping a single webpage

# %% [markdown]
# ## Webscraping intro
#
# In order to scrape content from a website we first need to download the HTML contents of the website. This can be done with the Python library **requests** (with its `.get` method).
#
# Then when we want to extract certain information from a website we use the scraping tool **BeautifulSoup4** (import bs4). In order to extract information with beautifulsoup we have to create a soup object from the HTML source code of a website.

# %%
# Install required packages using pip package manager in the current Jupyter kernel
#import sys
#!{sys.executable} -m pip install bs4

# %%
import requests # The requests library is an
# HTTP library for getting content and posting etc.

import bs4 as bs # BeautifulSoup4 is a Python library ，simplify our scraping
# for pulling data out of HTML and XML code.

# %%
# stretch Jupyter coding blocks to fit screen
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %% [markdown]
# ## An example: The HKBU JOUR faculty page

# %% [markdown]
# ### to fetch and to download the page

# %%
source = requests.get("http://www.jour.hkbu.edu.hk/faculty/")
# a GET request will download the HTML webpage.
#get request,post requesy ,put request...
print(source)
# If <Response [200]> then the website has been downloaded succesfully,200 is code with meaning
# Out:
# <Response [200]>

# %%
# errors may occur
source2 = requests.get("http://www.jour.hkbu.edu.hk/faculty/asdfajgkhgkhfsdf")
print(source2)
# "404"
# Out:
# <Response [404]>

# %%
print(source.content)
# This is the HTML content of the website, do you want to read it?
# Out:
# b'    <!DOCTYPE html>\r\n<html lang="en-US" xmlns:og="http://opengraphprotocol.org/schema/" xmlns:fb="http://www.facebook.com/2008/fbml">\r\n<head>\r\n<meta charset="UTF-8">\r\n\t<meta name="viewport" content="width=device-width, initial-scale=1.0">\r\n<title>Faculty | HKBU | Department of Journalism</title>\r\n<meta name="description" content="Hong Kong Baptist University - Department of Journalism was the first of its kind in Hong Kong when it was founded in 1968." />\r\n<meta property="og:title" content="Faculty | HKBU | Department of Journalism" />\r\n<meta property="og:description" content="HKBU Journalism was the first of its kind in Hong Kong when it was founded in 1968." />\r\n<meta property="og:type" content="website">\r\n<meta property="og:url" content="http://jour.hkbu.edu.hk" />\r\n<meta property="og:image" content="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/fb-image.jpg" />\r\n<link rel="profile" href="http://gmpg.org/xfn/11">\r\n<link rel="icon" type="image/png" href="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/favicon.png">\r\n<link rel="shortcut icon" href="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/favicon.png" type="image/png" />\r\n<link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.0.13/css/all.css" integrity="sha384-DNOHZ68U8hZfKXOrtjWvjxusGo9WQnrNx2sqG0tfsghAvtVlRW3tvkXWZh58N9jp" crossorigin="anonymous">\r\n<script src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/js/jquery.js"></script>\r\n<script src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/js/bootstrap.min.js"></script>\r\n<script src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/js/custom.js"></script>\r\n<link rel="alternate" hreflang="en" href="https://jour.hkbu.edu.hk/faculty/" />\n<link rel="alternate" hreflang="zh-hant" href="https://jour.hkbu.edu.hk/zh-hant/faculty/" />\n<link rel="alternate" hreflang="zh-hans" href="https://jour.hkbu.edu.hk/zh-hans/faculty/" />\n<link rel=\'dns-prefetch\' href=\'//s.w.org\' />\n<link rel=\'stylesheet\' id=\'layerslider-css\'  href=\'http://jour.hkbu.edu.hk/home/wp-content/plugins/LayerSlider/static/layerslider/css/layerslider.css?ver=6.7.1\' type=\'text/css\' media=\'all\' />\n<link rel=\'stylesheet\' id=\'wpml-legacy-horizontal-list-0-css\'  href=\'//jour.hkbu.edu.hk/home/wp-content/plugins/sitepress-multilingual-cms/templates/language-switchers/legacy-list-horizontal/style.css?ver=1\' type=\'text/css\' media=\'all\' />\n<link rel=\'stylesheet\' id=\'wp-pagenavi-css\'  href=\'http://jour.hkbu.edu.hk/home/wp-content/plugins/wp-pagenavi/pagenavi-css.css?ver=2.70\' type=\'text/css\' media=\'all\' />\n<link rel=\'stylesheet\' id=\'journalism-style-css\'  href=\'http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/style.css?ver=4.9.6\' type=\'text/css\' media=\'all\' />\n<link rel=\'stylesheet\' id=\'faculty-css\'  href=\'http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/css/faculty.css?ver=4.9.6\' type=\'text/css\' media=\'all\' />\n<meta name="generator" content="Powered by LayerSlider 6.7.1 - Multi-Purpose, Responsive, Parallax, Mobile-Friendly Slider Plugin for WordPress." />\r\n<!-- LayerSlider updates and docs at: https://layerslider.kreaturamedia.com -->\r\n<link rel="canonical" href="https://jour.hkbu.edu.hk/faculty/" />\n<link rel=\'shortlink\' href=\'https://jour.hkbu.edu.hk/?p=26\' />\n<meta name="generator" content="WPML ver:4.0.2 stt:60,62,1;" />\n<!-- Google tag (gtag.js) -->\r\n<script async src="https://www.googletagmanager.com/gtag/js?id=G-FZJSBGM7DL"></script>\r\n<script>\r\n  window.dataLayer = window.dataLayer || [];\r\n  function gtag(){dataLayer.push(arguments);}\r\n  gtag(\'js\', new Date());\r\n\r\n  gtag(\'config\', \'G-FZJSBGM7DL\');\r\n</script>\r\n\r\n<style>\r\n.bu_logo{width: unset; margin-right:35px}\r\n.bu_logo img{display:block; max-height: 45px;}\r\n.bu_logo_mobile{width: unset; }\r\n.bu_logo_mobile img{display:none}\r\n\r\n\r\n.jour_logo{width: unset;}\r\n.j ...

# %%
# Read in source.content to beautifulsoup
# beautifulsoup can parse (extract specific information) HTML code

soup = bs.BeautifulSoup(source.content , features='html.parser')
# we pass in the source content and choose a parser

# features specifies what type of code we are parsing,
# here 'html.parser' specifies an HTML parser, there are other parsers

# %%
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
print(soup)
# Out:
#  <!DOCTYPE html>
#
# <html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Faculty | HKBU | Department of Journalism</title>
# <meta content="Hong Kong Baptist University - Department of Journalism was the first of its kind in Hong Kong when it was founded in 1968." name="description">
# <meta content="Faculty | HKBU | Department of Journalism" property="og:title">
# <meta content="HKBU Journalism was the first of its kind in Hong Kong when it was founded in 1968." property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="http://jour.hkbu.edu.hk" property="og:url">
# <meta content="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/fb-image.jpg" property="og:image"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/favicon.png" rel="icon" type="image/png"/>
# <link href="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/favicon.png" rel="shortcut icon" type="image/png">
# <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.0.13/css/all.css" integrity="sha384-DNOHZ68U8hZfKXOrtjWvjxusGo9WQnrNx2sqG0tfsghAvtVlRW3tvkXWZh58N9jp" rel="stylesheet"/>
# <script src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/js/jquery.js"></script>
# <script src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/js/bootstrap.min.js"></script>
# <script src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/js/custom.js"></script>
# <link href="https://jour.hkbu.edu.hk/faculty/" hreflang="en" rel="alternate">
# <link href="https://jour.hkbu.edu.hk/zh-hant/faculty/" hreflang="zh-hant" rel="alternate">
# <link href="https://jour.hkbu.edu.hk/zh-hans/faculty/" hreflang="zh-hans" rel="alternate"/>
# <link href="//s.w.org" rel="dns-prefetch"/>
# <link href="http://jour.hkbu.edu.hk/home/wp-content/plugins/LayerSlider/static/layerslider/css/layerslider.css?ver=6.7.1" id="layerslider-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//jour.hkbu.edu.hk/home/wp-content/plugins/sitepress-multilingual-cms/templates/language-switchers/legacy-list-horizontal/style.css?ver=1" id="wpml-legacy-horizontal-list-0-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://jour.hkbu.edu.hk/home/wp-content/plugins/wp-pagenavi/pagenavi-css.css?ver=2.70" id="wp-pagenavi-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/style.css?ver=4.9.6" id="journalism-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/css/faculty.css?ver=4.9.6" id="faculty-css" media="all" rel="stylesheet" type="text/css"/>
# <meta content="Powered by LayerSlider 6.7.1 - Multi-Purpose, Responsive, Parallax, Mobile-Friendly Slider Plugin for WordPress." name="generator"/>
# <!-- LayerSlider updates and docs at: https://layerslider.kreaturamedia.com -->
# <link href="https://jour.hkbu.edu.hk/faculty/" rel="canonical"/>
# <link href="https://jour.hkbu.edu.hk/?p=26" rel="shortlink"/>
# <meta content="WPML ver:4.0.2 stt:60,62,1;" name="generator"/>
# <!-- Google tag (gtag.js) -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-FZJSBGM7DL"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-FZJSBGM7DL');
# </script>
# <style>
# .bu_logo{width: unset; margin-right:35px}
# .bu_logo img{display:block; max-height: 45px;}
# .bu_logo_mobile{width: unset; }
# .bu_logo_mobile img{display:none}
#
#
# .jour_logo{width: unset;}
# .jour_logo img{max-height: 45px;}
# .jour_logo_mobile{width: unset;}
# .jour_logo_mobile img{display:none}
#
# .comf_logo{width: unset; margin-right:35px}
# .comf_logo img{display:block; max-height: 45px;}
# .comf_logo_mobile{width: unset;}
# .comf_logo_mobile img{display:none}
#
#
# @media only screen and (max-width: 1199px) {
# 	.jour_logo{width: unset;}
# 	.jour_logo img{display:none}
# 	.jour_logo_mobile{width: unset; margin-right:20px}
# 	.jour_logo_mobile img{display:block; height: 45px;}
#
# 	.bu_logo img{display:block; max-height: 40px;}
# 	.comf_logo img{display:block; max-height: 40px;}
# }
#
#
# @media only screen and (max-width: 992px) {
# 	.bu_logo{width: unset; margin-right:0px}
# 	.bu_logo img{display:none}
# 	.bu_logo_mobile{width: unset; margin-right:25px}
# 	.bu_logo_mobile img{display:block; max-height: 38px;}
#
# 	.comf_logo{width: unset; margin-right:0px}
# 	.comf_logo img{display:none}
# 	.comf_logo_mobile{width: unset; margin-right:25px}
# 	.comf_logo_mobile img{display:block; max-height: 38px;}
#
# 	.jour_logo_mobile img{display:block; max-height: 38px;}
# }
#
#
#
#
#
#
# .btn_more {font-size: 12px; font-weight: bold; border-radius: 6px;
#     background-clip: padding-box; -webkit-background-clip: padding-box; -moz-background-clip: padding;
#     padding: 6px 16px; transition: all .3s ease-out; box-sizing: content-box;
#     zoom: 1; -webkit-backface-visibility: hidden; text-decoration: None;
#     cursor: pointer; text-align: center; margin-bottom: 40px;
# }
# .btn_pink{background: #d61773; color: #fff; border: 2px solid transparent;}
# .btn_pink:hover, .btn_pink:focus{background: #fff; color: #d61773; border: 2px solid #d61773; text-decoration:None}
#
# .btn_blue{background: #00529c; color: #fff; border: 2px solid transparent;}
# .btn_blue:hover, .btn_blue:focus{background: #fff; color: #00529c; border: 2px solid #00529c; text-decoration:None}
#
# .btn_green{background: #7ca44c; color: #fff; border: 2px solid transparent;}
# .btn_green:hover, .btn_green:focus{background: #fff; color: #7ca44c; border: 2px solid #7ca44c; text-decoration:None}
#
# .hader_padding{padding-top:50px}
#
# .navbar-inverse .navbar-brand {line-height:40px}
# @media (min-width: 968px) and (max-width: 1199px) {
# 	.hader_padding{padding-top:74px}
# }
#
# @media (max-width: 991px) and (max-width: 967px) {
# 	.hader_padding{padding-top:104px}
# }
# @media (max-width: 767px) {
# 	.hader_padding{padding-top:0px}
# }
#
#
# </style>
# </link></link></link></meta></meta></meta></head>
# <body class="page-template page-template-page-templates page-template-page-faculty page-template-page-templatespage-faculty-php page page-id-26 parent-faculty group-blog" id="faculty">
# <!-- SCROLL TOP BUTTON -->
# <a class="scrollToTop" href="#">
# <div class="btn-top">TOP</div>
# </a>
# <!-- END SCROLL TOP BUTTON -->
# <header id="header">
# <div class="top-bar">
# <div class="container">
# <nav class="navbar navbar-inverse">
# <div class="container-fluid">
# <div class="navbar-header">
# <button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" type="button">
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <a class="navbar-brand bu_logo" href="https://www.hkbu.edu.hk/eng/main/index.jsp" target="_blank">
# <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/hkbu.png"/>
# </a>
# <a class="navbar-brand bu_logo_mobile" href="https://www.hkbu.edu.hk/eng/main/index.jsp" target="_blank">
# <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/logo_hkbu_mobile.png"/>
# </a>
# <a class="navbar-brand comf_logo" href="https://www.comm.hkbu.edu.hk/comd-www/english/front/index.htm" target="_blank">
# <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/comm.png"/>
# </a>
# <a class="navbar-brand comf_logo_mobile" href="https://www.comm.hkbu.edu.hk/comd-www/english/front/index.htm" target="_blank">
# <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/COMF_2021-white_small_short.png"/>
# </a>
# <a class="navbar-brand jour_logo" href="https://jour.hkbu.edu.hk">
# <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/logo_hkbu-journalism_small.png"/>
# </a>
# <a class="navbar-brand jour_logo_mobile" href="https://jour.hkbu.edu.hk">
# <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/logo_hkbu-journalism_small_short.png"/>
# </a>
# </div>
# <div class="collapse navbar-collapse" id="navigation">
# <ul class="nav navbar-nav visible-xs">
# <li><a href="https://jour.hkbu.edu.hk">Home</a></li>
# <li><a href="https://jour.hkbu.edu.hk/about-us">About</a>
# </li>
# <li class="dropdown">
# <a class="dropdown-toggle" data-target="drop-programmes" data-toggle="dropdown" href="#drop-programmes" type="button">
# 																Study Path
# 															<b class="caret"></b>
# </a>
# <ul class="dropdown-menu" id="drop-programmes">
# <li style="display:none">
# <a href="https://jour.hkbu.edu.hk/programmes/programme-structure">
# 																			Programme Structure
# 																		</a>
# </li>
# <li style="padding:8px 12px; color:#fff; font-weight:600">								Undergraduate Programmes
# 															</li>
# <ul class="sub_ul" style="list-style:none; font-size:12px;">
# <!-- <li><a href="https://jour.hkbu.edu.hk/programmes/chinese-journalism">Chinese Journalism</a></li>-->
# <li><a href="https://jour.hkbu.edu.hk/programmes/journalism">								Journalism
# 								</a></li>
# <li><a href="http://bu-dmc.hkbu.edu.hk/" target="_blank">Data and Media Communication</a></li>
# </ul>
# <li><a href="http://comd.hkbu.edu.hk/masters/en/maijs.html" target="_blank">Postgraduate Studies</a></li>
# </ul>
# </li>
# <li><a href="https://jour.hkbu.edu.hk/research">Research</a></li>
# <li><a href="https://jour.hkbu.edu.hk/faculty">Faculty</a>
# </li>
# <li><a href="https://jour.hkbu.edu.hk/students-and-alumni">Students &amp; Alumni</a>
# </li>
# <li><a href="https://jour.hkbu.edu.hk/news-events">News &amp; Events</a>
# </li>
# <li><a href="https://jour.hkbu.edu.hk/highlights">Highlights</a>
# </li>
# <li class="dropdown">
# <a class="dropdown-toggle" data-target="drop-programmes" data-toggle="dropdown" href="#drop-programmes" type="button">
# 						Community<b class="caret"></b>
# </a>
# <ul class="dropdown-menu" id="drop-community">
# <li><a href="http://ijs.hkbu.edu.hk" target="_blank">Institute For Journalism &amp; Society</a></li>
# <li><a href="https://dnnsociety.org/" target="_blank">Data &amp; News Society</a></li>
# </ul>
# </li>
# <li><a href="https://jour.hkbu.edu.hk/contact-us">Contact Us</a></li>
# </ul>
# <ul class="nav navbar-nav navbar-right">
# <div class="social">
# <div id="languages">
# <div class="wpml-ls-statics-shortcode_actions wpml-ls wpml-ls-legacy-list-horizontal">
# <ul><li class="wpml-ls-slot-shortcode_actions wpml-ls-item wpml-ls-item-en wpml-ls-current-language wpml-ls-first-item wpml-ls-item-legacy-list-horizontal">
# <a class="wpml-ls-link" href="https://jour.hkbu.edu.hk/faculty/"><span class="wpml-ls-native">EN</span></a>
# </li><li class="wpml-ls-slot-shortcode_actions wpml-ls-item wpml-ls-item-zh-hant wpml-ls-item-legacy-list-horizontal">
# <a class="wpml-ls-link" href="https://jour.hkbu.edu.hk/zh-hant/faculty/"><span class="wpml-ls-display">繁</span></a>
# </li><li class="wpml-ls-slot-shortcode_actions wpml-ls-item wpml-ls-item-zh-hans wpml-ls-last-item wpml-ls-item-legacy-list-horizontal">
# <a class="wpml-ls-link" href="https://jour.hkbu.edu.hk/zh-hans/faculty/"><span class="wpml-ls-display">简</span></a>
# </li></ul>
# </div></div>
# <div class="hidden-xs" id="search"><i class="fa fa-search" data-placement="bottom" data-toggle="tooltip" title="Site Search"></i></div>
# <a href="https://jour.hkbu.edu.hk/searching">
# <div class="visible-xs" id="mobile-search"><i class="fa fa-search"></i></div>
# </a>
# <ul class="social-share fa-lg">
# <li><a href="https://www.facebook.com/hkbujournalism/" target="_blank"><i class="fa fa-facebook" data-placement="bottom" data-toggle="tooltip" title="Facebook"></i></a>
# </li>
# <li><a href="https://www.youtube.com/hkbujournalism" target="_blank"><i class="fa fa-youtube-play" data-placement="bottom" data-toggle="tooltip" title="YouTube"></i></a>
# </li>
# <li><a href="https://www.instagram.com/HKBU_Journalism/" target="_blank"><i class="fab fa-instagram" data-placement="bottom" data-toggle="tooltip" title="Instagram"></i></a>
# </li>
# <li><a href="https://jour.hkbu.edu.hk/contact-us"><i class="fas fa-phone" data-placement="bottom" data-toggle="tooltip" title="Contact Us"></i></a>
# </li>
# </ul>
# <div class="menu-bars">
# <button class="navbar-toggle03 hidden-xs" type="button">
# <div class="icon-bar"></div>
# <div class="icon-bar"></div>
# <div class="icon-bar"></div>
# </button>
# </div>
# </div>
# </ul>
# </div>
# </div>
# </nav>
# </div>
# <!--/container-->
# </div>
# <!--/top-bar-->
# <nav class="navbar2 navbar-inverse navbar-fixed-top" role="banner">
# <div class="container">
# <div class="collapse navbar-collapse">
# <ul class="nav navbar-nav">
# <li><a href="https://jour.hkbu.edu.hk">Home</a></li>
# <li><a href="https://jour.hkbu.edu.hk/about-us">About</a></li>
# <li class="dropdown">
# <a class="dropdown-toggle" data-target="drop-programmes" data-toggle="dropdown" href="#drop-programmes" type="button">
#
# 														Study Path
#
# 						<b class="caret"></b>
# </a>
# <style>
# ul.sub_ul{padding:0}
# ul.sub_ul li{padding-left:30px}
# ul.sub_ul li a, ul.sub_ul li a:hover{color:#fff;}
# ul.sub_ul li:hover{background-color:#0173ba}
# </style>
# <ul class="dropdown-menu" id="drop-programmes" style="min-width:250px">
# <li style="display:none">
# <a href="https://jour.hkbu.edu.hk/programmes/programme-structure">
# 																			Programme Structure
# 																		</a></li>
# <li style="padding:8px 12px; color:#fff; font-weight:600">										Undergraduate Programmes
# 										</li>
# <ul class="sub_ul" style="list-style:none; font-size:12px;">
# <!--<li><a href="https://jour.hkbu.edu.hk/programmes/chinese-journalism">Chinese Journalism</a></li>-->
# <li><a href="https://jour.hkbu.edu.hk/programmes/journalism">								Journalism
# 								</a></li>
# <li><a href="http://bu-dmc.hkbu.edu.hk/" target="_blank">Data and Media Communication</a></li>
# </ul>
# <li><a href="http://comd.hkbu.edu.hk/masters/en/maijs.html" target="_blank">Postgraduate Studies</a></li>
# </ul>
# </li>
# <li><a href="https://jour.hkbu.edu.hk/students-and-alumni/practicum">Practicum</a></li>
# <li><a href="https://jour.hkbu.edu.hk/research">Research</a></li>
# <li><a href="https://jour.hkbu.edu.hk/faculty">Faculty</a></li>
# <li><a href="https://jour.hkbu.edu.hk/students-and-alumni">Students &amp; Alumni</a></li>
# <li class="menu-news"><a href="https://jour.hkbu.edu.hk/news-events">News &amp; Events</a></li>
# <li class="menu-highlights"><a href="https://jour.hkbu.edu.hk/highlights">Highlights</a></li>
# <li class="dropdown menu-community" style="margin-left: 8px;">
# <a class="dropdown-toggle" data-target="drop-programmes" data-toggle="dropdown" href="#drop-programmes" type="button">
# 						Community<b class="caret"></b>
# </a>
# <ul class="dropdown-menu" id="drop-programmes">
# <li><a href="http://ijs.hkbu.edu.hk" target="_blank">Institute For Journalism &amp; Society</a></li>
# <li><a href="https://dnnsociety.org/" target="_blank">Data &amp; News Society</a></li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <div class="search-bar">
# <div class="container">
# <div class="row">
# <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12">
# <div class="col-search-icon">
# <div id="search"><i class="fas fa-search"></i></div>
# </div>
# <div class="col-lg-11 col-md-10 col-sm-10 col-xs-10">
# <form action="https://jour.hkbu.edu.hk/" id="searchform" method="get" role="search">
# <input autocomplete="off" class="search" id="s" name="s" placeholder="Site Search" type="search" value=""/>
# </form>
# </div>
# <div class="close-search"><i class="fas fa-times"></i></div>
# </div>
# </div>
# </div>
# </div> <!-- Search Bar -->
# </header>
# <div class="site-content" id="content"> <section id="top-image">
# <div class="col-lg-12 col-md-12">
# <div class="row">
# <img class="img-responsive visible-lg" id="bg-people" src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/bg_people.jpg">
# <img class="img-responsive hidden-lg" id="bg-people" src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/bg_people2.jpg">
# <div class="container">
# <div class="col-lg-12 col-md-12 in-content">
# <h2 class="slider-title">Faculty</h2>
# <p <p="" class="slide-description">Our faculty members have rich experience in the news industry, media education and journalism research. We also invite a number of frontline reporters and senior media professionals as adjunct lecturers and professors.</p>
#
# </div>
# </div>
# </img></img></div>
# </div>
# </section>
# <!--#top-image-->
# <section class="container" id="filter">
# <div class="row">
# <div class="col-lg-12 col-md-12 col-sm-12 filter">
# <a href="#faculty-members">
# <div class="icon-members">Faculty Members</div>
# </a>
# <a href="#pt-colleagues">
# <div class="icon-ptc">Part-Time Colleagues</div>
# </a>
# <a href="#visiting-scholars" style="display:none">
# <div class="icon-vs">Visiting Scholars</div>
# </a>
# <a href="#supporting-staff">
# <div class="icon-support-staff">Supporting Staff</div>
# </a>
# <a href="https://comd.hkbu.edu.hk/masters/en/maijs.html#section4">
# <div class="icon-vs">
# 													MAIJS Course Instructors
# 											</div>
# </a>
# </div>
# </div></section><!-- Filter -->
# <!--#faculty-staff-->
# <div class="anchor" id="faculty-members"></div>
# <section id="faculty-staff">
# <div class="container">
# <div class="row">
# <div class="col-lg-12 wow fadeInDown">
# <h3>Faculty Members</h3>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/raymond-li/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="Mr. Raymond Li" class="img-responsive wp-post-image" height="400" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/03/ppl_ray-li.jpg" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Prof. Raymond Li                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor of Practice<br/>
# Department Head</p>
# </h5>
# <div class="visible-lg">
# <p>A veteran journalist working at the BBC for over 24 years. Mr. Li was also the first native Chinese to be appointed the Head of Chinese at the BBC.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/luwei-rose-luqiu/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="Dr. Luwei Rose Luqiu" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-120x120.jpg 120w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose.jpg 600w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. Luwei Rose Luqiu                                    </h4>
# <h5 class="hidden-xs">
# <p>Associate Professor<br/>
# Associate Head</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Luqiu had been a television journalist for 20 years. She has covered many major international events ranging from the wars and also reported on Chinese political news and interviewed several Chinese leaders.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/prof-chan-king-cheung/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/03/Screenshot-2022-03-08-at-8.15.03-PM-400x400.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/03/Screenshot-2022-03-08-at-8.15.03-PM-400x400.png 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/03/Screenshot-2022-03-08-at-8.15.03-PM-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/03/Screenshot-2022-03-08-at-8.15.03-PM-120x120.png 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         PROF. CHAN King Cheung                                    </h4>
# <h5 class="hidden-xs">
# <p>Raymond R. Wong Endowed Professor in Media Ethics<br/>
# Professor of Practice</p>
# </h5>
# <div class="visible-lg">
# <p>A veteran journalist with more than 30 years of experience, Professor CHAN King Cheung received his Bachelor degree in Arts, Master degree in Communication and MBA degree from the Chinese University of Hong Kong. He was also a Fellow in Media Management of the Poynter Institute for Media Studies in the United States.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/steve-guo/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="PROF. STEVE GUO" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_steve-guo.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_steve-guo.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_steve-guo-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_steve-guo-300x300.jpg 300w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Prof. Steve Guo                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor<br/>
# Interim Dean, School of Communication</p>
# </h5>
# <div class="visible-lg">
# <p>Prof. Guo has spent his career in journalism and academia, including working at China Daily and researching news production and its social impact. He has been with university for more than 20 years.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/cherian-george/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/Cherian-George-2018-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/Cherian-George-2018-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/Cherian-George-2018-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/Cherian-George-2018-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Prof. Cherian George                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Professor George has spent his career in journalism practice, education, research and advocacy, including working at the Straits Times, editing journals and founding a newspaper for children.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/daya-thussu/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2019/07/Professor-Daya-Thussu-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2019/07/Professor-Daya-Thussu-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2019/07/Professor-Daya-Thussu-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2019/07/Professor-Daya-Thussu-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Prof. Daya Thussu                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Daya Thussu is Professor of International Communication. He was Visiting Professor and inaugural Disney Chair in Global Media at Schwarzman College, Tsinghua University in Beijing. </p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/prof-kennth-paul-tan/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-120x120.jpg 120w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan.jpg 480w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Prof. Kenneth Paul TAN                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Prof. Tan is a tenured Professor at Hong Kong Baptist University, which hired him under its Talent100 initiative in February 2021.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/wang-xiangwei/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="320" sizes="(max-width: 320px) 100vw, 320px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei.png 320w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei-300x300.png 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei-120x120.png 120w" width="320"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Mr. Wang Xiangwei                                    </h4>
# <h5 class="hidden-xs">
# <p>Mr. Wang Xiangwei<br/>
# Associate Professor of Practice</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/robin-ewing/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="MS. EWING ROBIN" class="img-responsive wp-post-image" height="305" sizes="(max-width: 305px) 100vw, 305px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/08/ppl_robin-ewing.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/08/ppl_robin-ewing.jpg 305w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/08/ppl_robin-ewing-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/08/ppl_robin-ewing-300x300.jpg 300w" width="305"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Ms. Robin Ewing                                    </h4>
# <h5 class="hidden-xs">
# <p>Senior Lecturer<br/>
# Director of International Journalism Concentration, BComm (Hons.) in Journalism</p>
# </h5>
# <div class="visible-lg">
# <p>Ms. Ewing has worked as a journalist and educator in Asia for most of the last 18 years with a focus on feature writing, narrative nonfiction and digital journalism.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/dr-brian-so/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-400x400.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-400x400.png 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-300x300.png 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-120x120.png 120w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM.png 684w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         DR. BRIAN SO                                    </h4>
# <h5 class="hidden-xs">
# <p>Associate Professor of Practice<br/>
# Coordinator of Financial Journalism Stream, Undergraduate Studies</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/mr-pun-wai-lam/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Pun-Wai-Lam-Profile-Picture--400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Pun-Wai-Lam-Profile-Picture--400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Pun-Wai-Lam-Profile-Picture--150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Pun-Wai-Lam-Profile-Picture--120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Mr. Pun Wai Lam                                    </h4>
# <h5 class="hidden-xs">
# <p>Associate Professor of Practice</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/dr-bess-wang-yue/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/02/Bess-Wang-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/02/Bess-Wang-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/02/Bess-Wang-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/02/Bess-Wang-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. Bess WANG Yue                                    </h4>
# <h5 class="hidden-xs">
# <p>Senior lecturer<br/>
# Programme Director of Data and Media Communication Concentration (DMC)<br/>
# Associate director of HKBU Fact Check</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/xiaoyi-fu/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-768x768.jpg 768w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-120x120.jpg 120w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo.jpg 950w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. Xiaoyi Fu                                    </h4>
# <h5 class="hidden-xs">
# <p>Lecturer I</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Fu holds a Ph.D. degree in Computer Science from Hong Kong Baptist University. She works in the fields of databases, location-based services, geo-social computing and geo-spatial recommendation. </p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/janet-lo/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="Dr. Janet Lo" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. Janet Lo                                    </h4>
# <h5 class="hidden-xs">
# <p>Assistant Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Lo has published in a number of peer-reviewed journals, and received top research paper awards in international conferences.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/dr-wang-dan/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="353" sizes="(max-width: 353px) 100vw, 353px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan.png 353w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan-300x300.png 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan-120x120.png 120w" width="353"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. WANG DAN (Angela)                                    </h4>
# <h5 class="hidden-xs">
# <p>Research Assistant Professor<br/>
# Programme Director, MSocSc in Media Management</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Wang’s doctoral dissertation was about how a Communist Party newspaper organisation responded to the impact of digital media. Her main research interest lies in reconciling macro political economy with micro-sociological details</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/dr-yu-wenting/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/YuWenting-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/YuWenting-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/YuWenting-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/YuWenting-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. YU Wenting                                    </h4>
# <h5 class="hidden-xs">
# <p>Research Assistant Professor</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/nick-zhang/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-768x768.jpg 768w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-1024x1024.jpg 1024w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. Nick Yin ZHANG                                    </h4>
# <h5 class="hidden-xs">
# <p>Assistant Professor<br/>
# Programme Director of Bachelor of Arts, Science and Technology (Hons) in Individualised Major</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Zhang is an interdisciplinary researcher of social science, humanities, and computer science. His research focuses on CMC, social networks, big data, and quality of life.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/dr-sheng-zou/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400.png 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400-300x300.png 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400-120x120.png 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         DR. SHENG ZOU                                    </h4>
# <h5 class="hidden-xs">
# <p>Assistant Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Sheng Zou is an interdisciplinary media scholar whose research interests span such areas as critical theory, political aesthetics, digital media and society, cultural industries, and global communication. </p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/bonnie-chiu/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="MS. BONNIE CHIU" class="img-responsive wp-post-image" height="400" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/03/ppl_bonnie-chiu.jpg" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Ms. CHIU Lai Yu Bonnie                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Teaching Fellow</p>
# </h5>
# <div class="visible-lg">
# <p>Ms. Chiu has extensive experience in broadcast journalism, including at RTHK, Cable TV and TVB, as well as a being a solicitor admitted in the High Court of Hong Kong.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/clemence-poon/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="Mr. Clemence Poon" class="img-responsive wp-post-image" height="400" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/03/ppl_clemence.jpg" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Mr. Clemence Poon                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Lecturer</p>
# </h5>
# <div class="visible-lg">
# <p>Mr. Poon started off as a financial journalist and moved into financial analysis career, with more than 20 years’ experience in management accounting, financial analysis, business planning and investment appraisal.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/jenny-lam/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="Ms. Jenny Lam" class="img-responsive wp-post-image" height="300" sizes="(max-width: 300px) 100vw, 300px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_jenny-lam.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_jenny-lam.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_jenny-lam-150x150.jpg 150w" width="300"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Ms. Jenny Lam                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Lecturer</p>
# </h5>
# <div class="visible-lg">
# <p>Ms. Lam has extensive experience in broadcast news journalism, including work at TVB and the BBC. She anchored the news for more than 20 years.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/ms-lam-wing-yan/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/01/Lam-Wing-Yan-1-400x400.jpeg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/01/Lam-Wing-Yan-1-400x400.jpeg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/01/Lam-Wing-Yan-1-150x150.jpeg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/01/Lam-Wing-Yan-1-120x120.jpeg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         MS. LAM WING YAN                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Lecturer</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/alison-leung/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/08/IMG_8901.png" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         DR.  ALISON LEUNG                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Lecturer</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Leung has taught journalism at universities in Hong Kong. Before that she was a Senior Correspondent and Deputy Chief of Thomson Reuters’ Hong Kong Bureau.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# </div>
# <!-- Faculty Members -->
# <div id="pt-colleagues" style="margin-bottom: 20px;">
# <div class="row">
# <div class="col-lg-12 wow fadeInDown">
# <h3>Part-Time Colleagues</h3>
# </div>
# <div class="container">
# <div class="row hidden-xs hidden-sm" style="padding: 10px 0; border-bottom:1px solid #ddd">
# <div class="col-md-4" style="color: #0173ba; font-size: 18px;"> </div>
# <div class="col-md-8" style="font-size:18px">
# <b> Course Taught:</b>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">PROF. CK LAU</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Current Issues and Case Studies in International News</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Prof. Alice Y. L. Lee</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Media Communication in the AI Era</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MS. AU KA KEI KITTY</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>News Translation<br/>
# Chinese News Writing and Reporting</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MR. BURTON-BRADLEY ROBERT</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>English News Reporting and Writing</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MS. CHAN KA HANG EMILY</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Financial Data and Market Sentiment Analysis</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MS. CHAN WAI MAN CARMEN</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Reporting Business and Financial News in Chinese</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MR. CHEUNG SIU WAI</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p><strong>Courses taught in Taught Postgraduate Programs:</strong></p>
# <p>Media and Communication in Chinese Societies<br/>
# Issues and Cases in Mass Communication<br/>
# Advanced PR Writing for Multimedia<br/>
# International Relations Theory and Practice<br/>
# Globalization, Economics and Finance</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MR. CHEUNG HIN YU JIMMY</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>English News Reporting and Writing</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MS. CHOI CHRISTY</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>English News Reporting and Writing</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MR. HO KA TAT</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Introduction to Photojournalism</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MR. HO SIU CHUNG BILLY</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Multimedia Storytelling</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MS. HUI CHAU HA</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Chinese News Writing and Reporting</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MS. HUI FUNG YI POLLY</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>English News Reporting and Writing</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MR. LAU ANDREW CHRISTOPHER</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Law and Ethics for Journalists</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MS. LEUNG HOI NING MAGGIE</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>News Anchoring</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MR. LI HANG KEI MATTHEW</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Sport and Disability in the Hong Kong Chinese Media</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MS. MOY PHAIK SEE PATSY</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Law and Ethics for Journalists</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MR. SIU CHI YUI PHILA</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Reporting in English</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MR. SUM WAN WAH</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Broadcast News Production</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MR. WONG HO WA</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Integrated Data-driven Storytelling</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MR. WU HONG CHUN DANIEL</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Social Media Content Management</p>
# </div>
# </div>
# <script>
# 					$(document).ready(function(){
# 						$('.pt-colleagues-title').each(function() {
# 							var text = $(this).text();
# 							$(this).text(text.replace('Private: ', ''));
# 						});
# 					});
# 					</script>
# </div>
# </div>
# </div>
# <!-- PT Colleagues -->
# <div id="visiting-scholars" style="display:none">
# <div class="row">
# <div class="col-lg-12 wow fadeInDown">
# <h3>Visiting Scholars</h3>
# </div>
# </div>
# </div>
# <!-- Visiting Scholars -->
# <div id="supporting-staff">
# <div class="row" id="other-officers">
# <div class="col-lg-12 wow fadeInDown">
# <h3>Supporting Staff</h3>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-xs-12">
# <div class="supporting-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail">
# <img class="img-responsive" src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/bg_support-staff.svg"/>
# </div>
# <div class="staff-info">
# <h4>
#                                         Ms. Bobo WEI                                    </h4>
# <h5 class="member-title hidden-xs">
# <p>Executive Officer</p>
# </h5>
# <div class="member-info">
# <a href="mailto:bobowei@hkbu.edu.hk" title="bobowei@hkbu.edu.hk">bobowei@hkbu.edu.hk</a><br/>
#                                         (852) 3411 7889                                    </div>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-xs-12">
# <div class="supporting-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail">
# <img class="img-responsive" src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/bg_support-staff.svg"/>
# </div>
# <div class="staff-info">
# <h4>
#                                         Mr. Joe Ying                                    </h4>
# <h5 class="member-title hidden-xs">
# <p>Executive Assistant</p>
# </h5>
# <div class="member-info">
# <a href="mailto:joeying@hkbu.edu.hk" title="joeying@hkbu.edu.hk">joeying@hkbu.edu.hk</a><br/>
#                                         (852) 3411 7490                                    </div>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-xs-12">
# <div class="supporting-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail">
# <img class="img-responsive" src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/bg_support-staff.svg"/>
# </div>
# <div class="staff-info">
# <h4>
#                                         Mr. Cheng Kin Chung                                    </h4>
# <h5 class="member-title hidden-xs">
# <p>Technical Officer</p>
# </h5>
# <div class="member-info">
# <a href="mailto:kccheng@hkbu.edu.hk" title="kccheng@hkbu.edu.hk">kccheng@hkbu.edu.hk</a><br/>
#                                         (852) 3411 5069                                    </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- Supporting Staff -->
# </div>
# <!--/.container-->
# </section>
# </div><!-- #content -->
# <footer id="footer">
# <div class="container footer-bar">
# <div class="row">
# <div class="col-lg-6 col-md-6 hidden-sm hidden-xs">
# <button class="toggle-menu quick-links">Quick Links</button>
# </div>
# <div class="col-lg-6 col-md-6 col-sm-12 col-xs-12 copyright" style="padding-right:0">
# 					© HKBU |
# 					<a href="https://www.hkbu.edu.hk/eng/about/privacy.jsp" style="color:#fff" target="_blank">Privacy Policy</a> |
# 					<a href="http://jour.hkbu.edu.hk/home/disclaimer/" style="color:#fff">Disclaimer</a> | All rights reserved.
#
# 				</div>
# </div>
# </div>
# <div class="footer-menu-bottom">
# <!-- Bottom menu element-->
# <div class="container">
# <!-- Row 1 -->
# <div class="col-xs-12 col-sm-6 col-md-4">
# <div class="row"><a href="https://jour.hkbu.edu.hk/contact-us" target="_blank">Contact Us<i class="fa fa-angle-right redirect"></i></a>
# </div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-4">
# <div class="row"><a href="https://jour.hkbu.edu.hk/students-and-alumni/study-trips/">Study Trips<i class="fa fa-angle-right redirect"></i></a>
# </div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-4">
# <div class="row"><a href="http://admissions.hkbu.edu.hk/en/hkdse.html" target="_blank">HKBU Admissions<i class="fa fa-angle-right redirect"></i></a>
# </div>
# </div>
# <!-- Row 2 -->
# <div class="col-xs-12 col-sm-6 col-md-4">
# <div class="row"><a href="https://www.youtube.com/embed/GhmzdbjrGuI?autoplay=1" target="_blank">Department Video<i class="fa fa-angle-right redirect"></i></a>
# </div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-4">
# <div class="row"><a href="https://jour.hkbu.edu.hk/students-and-alumni/exchange-programmes/">Student Exchange<i class="fa fa-angle-right redirect"></i></a>
# </div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-4">
# <div class="row"><a href="http://sa.hkbu.edu.hk/home/" target="_blank">Office of Student Affairs<i class="fa fa-angle-right redirect"></i></a>
# </div>
# </div>
# <!-- Row 3 -->
# <div class="col-xs-12 col-sm-6 col-md-4">
# <div class="row"><a href="https://jour.hkbu.edu.hk/faculty">Faculty<i class="fa fa-angle-right redirect"></i></a>
# </div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-4">
# <div class="row"><a href="https://sa.hkbu.edu.hk/sfa/scholarships/scholarships-for-undergraduate-students/for-school-of-communication" target="_blank">Student Scholarships<i class="fa fa-angle-right redirect"></i></a>
# </div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-4">
# <div class="row">​</div>
# </div>
# <!-- Row 4 -->
# <div class="col-xs-12 col-sm-6 col-md-4">
# <div class="row"><a href="https://jour.hkbu.edu.hk/students-and-alumni/achievements/">Student Achievements<i class="fa fa-angle-right redirect"></i></a>
# </div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-4">
# <div class="row"><a href="https://jour.hkbu.edu.hk/practicum">Practicum<i class="fa fa-angle-right redirect"></i></a>
# </div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-4">
# <div class="row">​</div>
# </div>
# </div>
# </div>
# </footer>
# <!--/#footer-->
# <script src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/js/wow.min.js"></script>
# <script src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/js/lightcase.js"></script>
# <script src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/js/flickity.pkgd.js"></script>
# <script src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/js/modernizr.js"></script>
# </body>
# </html>

# %%
print(soup.prettify())  # make it more readable
# Out:
# <!DOCTYPE html>
# <html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    Faculty | HKBU | Department of Journalism
#   </title>
#   <meta content="Hong Kong Baptist University - Department of Journalism was the first of its kind in Hong Kong when it was founded in 1968." name="description">
#    <meta content="Faculty | HKBU | Department of Journalism" property="og:title">
#     <meta content="HKBU Journalism was the first of its kind in Hong Kong when it was founded in 1968." property="og:description"/>
#     <meta content="website" property="og:type"/>
#     <meta content="http://jour.hkbu.edu.hk" property="og:url">
#      <meta content="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/fb-image.jpg" property="og:image"/>
#      <link href="http://gmpg.org/xfn/11" rel="profile"/>
#      <link href="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/favicon.png" rel="icon" type="image/png"/>
#      <link href="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/favicon.png" rel="shortcut icon" type="image/png">
#       <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.0.13/css/all.css" integrity="sha384-DNOHZ68U8hZfKXOrtjWvjxusGo9WQnrNx2sqG0tfsghAvtVlRW3tvkXWZh58N9jp" rel="stylesheet"/>
#       <script src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/js/jquery.js">
#       </script>
#       <script src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/js/bootstrap.min.js">
#       </script>
#       <script src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/js/custom.js">
#       </script>
#       <link href="https://jour.hkbu.edu.hk/faculty/" hreflang="en" rel="alternate">
#        <link href="https://jour.hkbu.edu.hk/zh-hant/faculty/" hreflang="zh-hant" rel="alternate">
#         <link href="https://jour.hkbu.edu.hk/zh-hans/faculty/" hreflang="zh-hans" rel="alternate"/>
#         <link href="//s.w.org" rel="dns-prefetch"/>
#         <link href="http://jour.hkbu.edu.hk/home/wp-content/plugins/LayerSlider/static/layerslider/css/layerslider.css?ver=6.7.1" id="layerslider-css" media="all" rel="stylesheet" type="text/css"/>
#         <link href="//jour.hkbu.edu.hk/home/wp-content/plugins/sitepress-multilingual-cms/templates/language-switchers/legacy-list-horizontal/style.css?ver=1" id="wpml-legacy-horizontal-list-0-css" media="all" rel="stylesheet" type="text/css"/>
#         <link href="http://jour.hkbu.edu.hk/home/wp-content/plugins/wp-pagenavi/pagenavi-css.css?ver=2.70" id="wp-pagenavi-css" media="all" rel="stylesheet" type="text/css"/>
#         <link href="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/style.css?ver=4.9.6" id="journalism-style-css" media="all" rel="stylesheet" type="text/css"/>
#         <link href="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/css/faculty.css?ver=4.9.6" id="faculty-css" media="all" rel="stylesheet" type="text/css"/>
#         <meta content="Powered by LayerSlider 6.7.1 - Multi-Purpose, Responsive, Parallax, Mobile-Friendly Slider Plugin for WordPress." name="generator"/>
#         <!-- LayerSlider updates and docs at: https://layerslider.kreaturamedia.com -->
#         <link href="https://jour.hkbu.edu.hk/faculty/" rel="canonical"/>
#         <link href="https://jour.hkbu.edu.hk/?p=26" rel="shortlink"/>
#         <meta content="WPML ver:4.0.2 stt:60,62,1;" name="generator"/>
#         <!-- Google tag (gtag.js) -->
#         <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-FZJSBGM7DL">
#         </script>
#         <script>
#          window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-FZJSBGM7DL');
#         </script>
#         <style>
#          .bu_logo{width: unset; margin-right:35px}
# .bu_logo img{display:block; max-height: 45px;}
# .bu_logo_mobile{width: unset; }
# .bu_logo_mobile img{display:none}
#
#
# .jour_logo{width: unset;}
# .jour_logo img{max-height: 45px;}
# .jour_logo_mobile{width: unset;}
# .jour_logo_mobile img{display:none}
#
# .comf_logo{width: unset; margin-right:35px}
# .comf_logo img{display:block; max-height: 45px;}
# .comf_logo_mobile{width: unset;}
# .comf_logo_mobile img{display:none}
#
#
# @media only screen and (max-width: 1199px) {
# 	.jour_logo{width: unset;}
# 	.jour_logo img{display:none}
# 	.jour_logo_mobile{width: unset; margin-right:20px}
# 	.jour_logo_mobile img{display:block; height: 45px;}
#
# 	.bu_logo img{display:block; max-height: 40px;}
# 	.comf_logo img{display:block; max-height: 40px;}
# }
#
#
# @media only screen and (max-width: 992px) {
# 	.bu_logo{width: unset; margin-right:0px}
# 	.bu_logo img{display:none}
# 	.bu_logo_mobile{width: unset; margin-right:25px}
# 	.bu_logo_mobile img{display:block; max-height: 38px;}
#
# 	.comf_logo{width: unset; margin-right:0px}
# 	.comf_logo img{display:none}
# 	.comf_logo_mobile{width: unset; margin-right:25px}
# 	.comf_logo_mobile img{display:block; max-height: 38px;}
#
# 	.jour_logo_mobile img{display:block; max-height: 38px;}
# }
#
#
#
#
#
#
# .btn_more {font-size: 12px; font-weight: bold; border-radius: 6px;
#     background-clip: padding-box; -webkit-background-clip: padding-box; -moz-background-clip: padding;
#     padding: 6px 16px; transition: all .3s ease-out; box-sizing: content-box;
#     zoom: 1; -webkit-backface-visibility: hidden; text-decoration: None;
#     cursor: pointer; text-align: center; margin-bottom: 40px;
# }
# .btn_pink{background: #d61773; color: #fff; border: 2px solid transparent;}
# .btn_pink:hover, .btn_pink:focus{background: #fff; color: #d61773; border: 2px solid #d61773; text-decoration:None}
#
# .btn_blue{background: #00529c; color: #fff; border: 2px solid transparent;}
# .btn_blue:hover, .btn_blue:focus{background: #fff; color: #00529c; border: 2px solid #00529c; text-decoration:None}
#
# .btn_green{background: #7ca44c; color: #fff; border: 2px solid transparent;}
# .btn_green:hover, .btn_green:focus{background: #fff; color: #7ca44c; border: 2px solid #7ca44c; text-decoration:None}
#
# .hader_padding{padding-top:50px}
#
# .navbar-inverse .navbar-brand {line-height:40px}
# @media (min-width: 968px) and (max-width: 1199px) {
# 	.hader_padding{padding-top:74px}
# }
#
# @media (max-width: 991px) and (max-width: 967px) {
# 	.hader_padding{padding-top:104px}
# }
# @media (max-width: 767px) {
# 	.hader_padding{padding-top:0px}
# }
#         </style>
#        </link>
#       </link>
#      </link>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body class="page-template page-template-page-templates page-template-page-faculty page-template-page-templatespage-faculty-php page page-id-26 parent-faculty group-blog" id="faculty">
#   <!-- SCROLL TOP BUTTON -->
#   <a class="scrollToTop" href="#">
#    <div class="btn-top">
#     TOP
#    </div>
#   </a>
#   <!-- END SCROLL TOP BUTTON -->
#   <header id="header">
#    <div class="top-bar">
#     <div class="container">
#      <nav class="navbar navbar-inverse">
#       <div class="container-fluid">
#        <div class="navbar-header">
#         <button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" type="button">
#          <span class="icon-bar">
#          </span>
#          <span class="icon-bar">
#          </span>
#          <span class="icon-bar">
#          </span>
#         </button>
#         <a class="navbar-brand bu_logo" href="https://www.hkbu.edu.hk/eng/main/index.jsp" target="_blank">
#          <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/hkbu.png"/>
#         </a>
#         <a class="navbar-brand bu_logo_mobile" href="https://www.hkbu.edu.hk/eng/main/index.jsp" target="_blank">
#          <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/logo_hkbu_mobile.png"/>
#         </a>
#         <a class="navbar-brand comf_logo" href="https://www.comm.hkbu.edu.hk/comd-www/english/front/index.htm" target="_blank">
#          <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/comm.png"/>
#         </a>
#         <a class="navbar-brand comf_logo_mobile" href="https://www.comm.hkbu.edu.hk/comd-www/english/front/index.htm" target="_blank">
#          <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/COMF_2021-white_small_short.png"/>
#         </a>
#         <a class="navbar-brand jour_logo" href="https://jour.hkbu.edu.hk">
#          <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/logo_hkbu-journalism_small.png"/>
#         </a>
#         <a class="navbar-brand jour_logo_mobile" href="https://jour.hkbu.edu.hk">
#          <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/logo_hkbu-journalism_small_short.png"/>
#         </a>
#        </div>
#        <div class="collapse navbar-collapse" id="navigation">
#         <ul class="nav navbar-nav visible-xs">
#          <li>
#           <a href="https://jour.hkbu.edu.hk">
#            Home
#           </a>
#          </li>
#          <li>
#           <a href="https://jour.hkbu.edu.hk/about-us">
#            About
#           </a>
#          </li>
#          <li class="dropdown">
#           <a class="dropdown-toggle" data-target="drop-programmes" data-toggle="dropdown" href="#drop-programmes" type="button">
#            Study Path
#            <b class="caret">
#            </b>
#           </a>
#           <ul class="dropdown-menu" id="drop-programmes">
#            <li style="display:none">
#             <a href="https://jour.hkbu.edu.hk/programmes/programme-structure">
#              Programme Structure
#             </a>
#            </li>
#            <li style="padding:8px 12px; color:#fff; font-weight:600">
#             Undergraduate Programmes
#            </li>
#            <ul class="sub_ul" style="list-style:none; font-size:12px;">
#             <!-- <li><a href="https://jour.hkbu.edu.hk/programmes/chinese-journalism">Chinese Journalism</a></li>-->
#             <li>
#              <a href="https://jour.hkbu.edu.hk/programmes/journalism">
#               Journalism
#              </a>
#             </li>
#             <li>
#              <a href="http://bu-dmc.hkbu.edu.hk/" target="_blank">
#               Data and Media Communication
#              </a>
#             </li>
#            </ul>
#            <li>
#             <a href="http://comd.hkbu.edu.hk/masters/en/maijs.html" target="_blank">
#              Postgraduate Studies
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="https://jour.hkbu.edu.hk/research">
#            Research
#           </a>
#          </li>
#          <li>
#           <a href="https://jour.hkbu.edu.hk/faculty">
#            Faculty
#           </a>
#          </li>
#          <li>
#           <a href="https://jour.hkbu.edu.hk/students-and-alumni">
#            Students &amp; Alumni
#           </a>
#          </li>
#          <li>
#           <a href="https://jour.hkbu.edu.hk/news-events">
#            News &amp; Events
#           </a>
#          </li>
#          <li>
#           <a href="https://jour.hkbu.edu.hk/highlights">
#            Highlights
#           </a>
#          </li>
#          <li class="dropdown">
#           <a class="dropdown-toggle" data-target="drop-programmes" data-toggle="dropdown" href="#drop-programmes" type="button">
#            Community
#            <b class="caret">
#            </b>
#           </a>
#           <ul class="dropdown-menu" id="drop-community">
#            <li>
#             <a href="http://ijs.hkbu.edu.hk" target="_blank">
#              Institute For Journalism &amp; Society
#             </a>
#            </li>
#            <li>
#             <a href="https://dnnsociety.org/" target="_blank">
#              Data &amp; News Society
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="https://jour.hkbu.edu.hk/contact-us">
#            Contact Us
#           </a>
#          </li>
#         </ul>
#         <ul class="nav navbar-nav navbar-right">
#          <div class="social">
#           <div id="languages">
#            <div class="wpml-ls-statics-shortcode_actions wpml-ls wpml-ls-legacy-list-horizontal">
#             <ul>
#              <li class="wpml-ls-slot-shortcode_actions wpml-ls-item wpml-ls-item-en wpml-ls-current-language wpml-ls-first-item wpml-ls-item-legacy-list-horizontal">
#               <a class="wpml-ls-link" href="https://jour.hkbu.edu.hk/faculty/">
#                <span class="wpml-ls-native">
#                 EN
#                </span>
#               </a>
#              </li>
#              <li class="wpml-ls-slot-shortcode_actions wpml-ls-item wpml-ls-item-zh-hant wpml-ls-item-legacy-list-horizontal">
#               <a class="wpml-ls-link" href="https://jour.hkbu.edu.hk/zh-hant/faculty/">
#                <span class="wpml-ls-display">
#                 繁
#                </span>
#               </a>
#              </li>
#              <li class="wpml-ls-slot-shortcode_actions wpml-ls-item wpml-ls-item-zh-hans wpml-ls-last-item wpml-ls-item-legacy-list-horizontal">
#               <a class="wpml-ls-link" href="https://jour.hkbu.edu.hk/zh-hans/faculty/">
#                <span class="wpml-ls-display">
#                 简
#                </span>
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#           <div class="hidden-xs" id="search">
#            <i class="fa fa-search" data-placement="bottom" data-toggle="tooltip" title="Site Search">
#            </i>
#           </div>
#           <a href="https://jour.hkbu.edu.hk/searching">
#            <div class="visible-xs" id="mobile-search">
#             <i class="fa fa-search">
#             </i>
#            </div>
#           </a>
#           <ul class="social-share fa-lg">
#            <li>
#             <a href="https://www.facebook.com/hkbujournalism/" target="_blank">
#              <i class="fa fa-facebook" data-placement="bottom" data-toggle="tooltip" title="Facebook">
#              </i>
#             </a>
#            </li>
#            <li>
#             <a href="https://www.youtube.com/hkbujournalism" target="_blank">
#              <i class="fa fa-youtube-play" data-placement="bottom" data-toggle="tooltip" title="YouTube">
#              </i>
#             </a>
#            </li>
#            <li>
#             <a href="https://www.instagram.com/HKBU_Journalism/" target="_blank">
#              <i class="fab fa-instagram" data-placement="bottom" data-toggle="tooltip" title="Instagram">
#              </i>
#             </a>
#            </li>
#            <li>
#             <a href="https://jour.hkbu.edu.hk/contact-us">
#              <i class="fas fa-phone" data-placement="bottom" data-toggle="tooltip" title="Contact Us">
#              </i>
#             </a>
#            </li>
#           </ul>
#           <div class="menu-bars">
#            <button class="navbar-toggle03 hidden-xs" type="button">
#             <div class="icon-bar">
#             </div>
#             <div class="icon-bar">
#             </div>
#             <div class="icon-bar">
#             </div>
#            </button>
#           </div>
#          </div>
#         </ul>
#        </div>
#       </div>
#      </nav>
#     </div>
#     <!--/container-->
#    </div>
#    <!--/top-bar-->
#    <nav class="navbar2 navbar-inverse navbar-fixed-top" role="banner">
#     <div class="container">
#      <div class="collapse navbar-collapse">
#       <ul class="nav navbar-nav">
#        <li>
#         <a href="https://jour.hkbu.edu.hk">
#          Home
#         </a>
#        </li>
#        <li>
#         <a href="https://jour.hkbu.edu.hk/about-us">
#          About
#         </a>
#        </li>
#        <li class="dropdown">
#         <a class="dropdown-toggle" data-target="drop-programmes" data-toggle="dropdown" href="#drop-programmes" type="button">
#          Study Path
#          <b class="caret">
#          </b>
#         </a>
#         <style>
#          ul.sub_ul{padding:0}
# ul.sub_ul li{padding-left:30px}
# ul.sub_ul li a, ul.sub_ul li a:hover{color:#fff;}
# ul.sub_ul li:hover{background-color:#0173ba}
#         </style>
#         <ul class="dropdown-menu" id="drop-programmes" style="min-width:250px">
#          <li style="display:none">
#           <a href="https://jour.hkbu.edu.hk/programmes/programme-structure">
#            Programme Structure
#           </a>
#          </li>
#          <li style="padding:8px 12px; color:#fff; font-weight:600">
#           Undergraduate Programmes
#          </li>
#          <ul class="sub_ul" style="list-style:none; font-size:12px;">
#           <!--<li><a href="https://jour.hkbu.edu.hk/programmes/chinese-journalism">Chinese Journalism</a></li>-->
#           <li>
#            <a href="https://jour.hkbu.edu.hk/programmes/journalism">
#             Journalism
#            </a>
#           </li>
#           <li>
#            <a href="http://bu-dmc.hkbu.edu.hk/" target="_blank">
#             Data and Media Communication
#            </a>
#           </li>
#          </ul>
#          <li>
#           <a href="http://comd.hkbu.edu.hk/masters/en/maijs.html" target="_blank">
#            Postgraduate Studies
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li>
#         <a href="https://jour.hkbu.edu.hk/students-and-alumni/practicum">
#          Practicum
#         </a>
#        </li>
#        <li>
#         <a href="https://jour.hkbu.edu.hk/research">
#          Research
#         </a>
#        </li>
#        <li>
#         <a href="https://jour.hkbu.edu.hk/faculty">
#          Faculty
#         </a>
#        </li>
#        <li>
#         <a href="https://jour.hkbu.edu.hk/students-and-alumni">
#          Students &amp; Alumni
#         </a>
#        </li>
#        <li class="menu-news">
#         <a href="https://jour.hkbu.edu.hk/news-events">
#          News &amp; Events
#         </a>
#        </li>
#        <li class="menu-highlights">
#         <a href="https://jour.hkbu.edu.hk/highlights">
#          Highlights
#         </a>
#        </li>
#        <li class="dropdown menu-community" style="margin-left: 8px;">
#         <a class="dropdown-toggle" data-target="drop-programmes" data-toggle="dropdown" href="#drop-programmes" type="button">
#          Community
#          <b class="caret">
#          </b>
#         </a>
#         <ul class="dropdown-menu" id="drop-programmes">
#          <li>
#           <a href="http://ijs.hkbu.edu.hk" target="_blank">
#            Institute For Journalism &amp; Society
#           </a>
#          </li>
#          <li>
#           <a href="https://dnnsociety.org/" target="_blank">
#            Data &amp; News Society
#           </a>
#          </li>
#         </ul>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </nav>
#    <div class="search-bar">
#     <div class="container">
#      <div class="row">
#       <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12">
#        <div class="col-search-icon">
#         <div id="search">
#          <i class="fas fa-search">
#          </i>
#         </div>
#        </div>
#        <div class="col-lg-11 col-md-10 col-sm-10 col-xs-10">
#         <form action="https://jour.hkbu.edu.hk/" id="searchform" method="get" role="search">
#          <input autocomplete="off" class="search" id="s" name="s" placeholder="Site Search" type="search" value=""/>
#         </form>
#        </div>
#        <div class="close-search">
#         <i class="fas fa-times">
#         </i>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- Search Bar -->
#   </header>
#   <div class="site-content" id="content">
#    <section id="top-image">
#     <div class="col-lg-12 col-md-12">
#      <div class="row">
#       <img class="img-responsive visible-lg" id="bg-people" src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/bg_people.jpg">
#        <img class="img-responsive hidden-lg" id="bg-people" src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/bg_people2.jpg">
#         <div class="container">
#          <div class="col-lg-12 col-md-12 in-content">
#           <h2 class="slider-title">
#            Faculty
#           </h2>
#           <p <p="" class="slide-description">
#            Our faculty members have rich experience in the news industry, media education and journalism research. We also invite a number of frontline reporters and senior media professionals as adjunct lecturers and professors.
#           </p>
#          </div>
#         </div>
#        </img>
#       </img>
#      </div>
#     </div>
#    </section>
#    <!--#top-image-->
#    <section class="container" id="filter">
#     <div class="row">
#      <div class="col-lg-12 col-md-12 col-sm-12 filter">
#       <a href="#faculty-members">
#        <div class="icon-members">
#         Faculty Members
#        </div>
#       </a>
#       <a href="#pt-colleagues">
#        <div class="icon-ptc">
#         Part-Time Colleagues
#        </div>
#       </a>
#       <a href="#visiting-scholars" style="display:none">
#        <div class="icon-vs">
#         Visiting Scholars
#        </div>
#       </a>
#       <a href="#supporting-staff">
#        <div class="icon-support-staff">
#         Supporting Staff
#        </div>
#       </a>
#       <a href="https://comd.hkbu.edu.hk/masters/en/maijs.html#section4">
#        <div class="icon-vs">
#         MAIJS Course Instructors
#        </div>
#       </a>
#      </div>
#     </div>
#    </section>
#    <!-- Filter -->
#    <!--#faculty-staff-->
#    <div class="anchor" id="faculty-members">
#    </div>
#    <section id="faculty-staff">
#     <div class="container">
#      <div class="row">
#       <div class="col-lg-12 wow fadeInDown">
#        <h3>
#         Faculty Members
#        </h3>
#       </div>
#       <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
#        <a href="https://jour.hkbu.edu.hk/faculty-member/raymond-li/">
#         <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
#          <div class="featured-thumbnail">
#           <img alt="Mr. Raymond Li" class="img-responsive wp-post-image" height="400" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/03/ppl_ray-li.jpg" width="400"/>
#          </div>
#          <div class="overlay">
#           <div class="staff-inner">
#            <h4>
#             Prof. Raymond Li
#            </h4>
#            <h5 class="hidden-xs">
#             <p>
#              Professor of Practice
#              <br/>
#              Department Head
#             </p>
#            </h5>
#            <div class="visible-lg">
#             <p>
#              A veteran journalist working at the BBC for over 24 years. Mr. Li was also the first native Chinese to be appointed the Head of Chinese at the BBC.
#             </p>
#            </div>
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
#        <a href="https://jour.hkbu.edu.hk/faculty-member/luwei-rose-luqiu/">
#         <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
#          <div class="featured-thumbnail">
#           <img alt="Dr. Luwei Rose Luqiu" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-120x120.jpg 120w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose.jpg 600w" width="400"/>
#          </div>
#          <div class="overlay">
#           <div class="staff-inner">
#            <h4>
#             Dr. Luwei Rose Luqiu
#            </h4>
#            <h5 class="hidden-xs">
#             <p>
#              Associate Professor
#              <br/>
#              Associate Head
#             </p>
#            </h5>
#            <div class="visible-lg">
#             <p>
#              Dr. Luqiu had been a television journalist for 20 years. She has covered many major international events ranging from the wars and also reported on Chinese political news and interviewed several Chinese leaders.
#             </p>
#            </div>
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
#        <a href="https://jour.hkbu.edu.hk/faculty-member/prof-chan-king-cheung/">
#         <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
#          <div class="featured-thumbnail">
#           <img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/03/Screenshot-2022-03-08-at-8.15.03-PM-400x400.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/03/Screenshot-2022-03-08-at-8.15.03-PM-400x400.png 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/03/Screenshot-2022-03-08-at-8.15.03-PM-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/03/Screenshot-2022-03-08-at-8.15.03-PM-120x120.png 120w" width="400"/>
#          </div>
#          <div class="overlay">
#           <div class="staff-inner">
#            <h4>
#             PROF. CHAN King Cheung
#            </h4>
#            <h5 class="hidden-xs">
#             <p>
#              Raymond R. Wong Endowed Professor in Media Ethics
#              <br/>
#              Professor of Practice
#             </p>
#            </h5>
#            <div class="visible-lg">
#             <p>
#              A veteran journalist with more than 30 years of experience, Professor CHAN King Cheung received his Bachelor degree in Arts, Master degree in Communication and MBA degree from the Chinese University of Hong Kong. He was also a Fellow in Media Management of the Poynter Institute for Media Studies in the United States.
#             </p>
#            </div>
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
#        <a href="https://jour.hkbu.edu.hk/faculty-member/steve-guo/">
#         <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
#          <div class="featured-thumbnail">
#           <img alt="PROF. STEVE GUO" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_steve-guo.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_steve-guo.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_steve-guo-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_steve-guo-300x300.jpg 300w" width="400"/>
#          </div>
#          <div class="overlay">
#           <div class="staff-inner">
#            <h4>
#             Prof. Steve Guo
#            </h4>
#            <h5 class="hidden-xs">
#             <p>
#              Professor
#              <br/>
#              Interim Dean, School of Communication
#             </p>
#            </h5>
#            <div class="visible-lg">
#             <p>
#              Prof. Guo has spent his career in journalism and academia, including working at China Daily and researching news production and its social impact. He has been with university for more than 20 years.
#             </p>
#            </div>
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
#        <a href="https://jour.hkbu.edu.hk/faculty-member/cherian-george/">
#         <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
#          <div class="featured-thumbnail">
#           <img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/Cherian-George-2018-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/Cherian-George-2018-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/Cherian-George-2018-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/Cherian-George-2018-120x120.jpg 120w" width="400"/>
#          </div>
#          <div class="overlay">
#           <div class="staff-inner">
#            <h4>
#             Prof. Cherian George
#            </h4>
#            <h5 class="hidden-xs">
#             <p>
#              Professor
#             </p>
#            </h5>
#            <div class="visible-lg">
#             <p>
#              Professor George has spent his career in journalism practice, education, research and advocacy, including working at the Straits Times, editing journals and founding a newspaper for children.
#             </p>
#            </div>
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
#        <a href="https://jour.hkbu.edu.hk/faculty-member/daya-thussu/">
#         <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
#          <div class="featured-thumbnail">
#           <img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2019/07/Professor-Daya-Thussu-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2019/07/Professor-Daya-Thussu-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2019/07/Professor-Daya-Thussu-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2019/07/Professor-Daya-Thussu-120x120.jpg 120w" width="400"/>
#          </div>
#          <div class="overlay">
#           <div class="staff-inner">
#            <h4>
#             Prof. Daya Thussu
#            </h4>
#            <h5 class="hidden-xs">
#             <p>
#              Professor
#             </p>
#            </h5>
#            <div class="visible-lg">
#             <p>
#              Daya Thussu is Professor of International Communication. He was Visiting Professor and inaugural Disney Chair in Global Media at Schwarzman College, Tsinghua University in Beijing.
#             </p>
#            </div>
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
#        <a href="https://jour.hkbu.edu.hk/faculty-member/prof-kennth-paul-tan/">
#         <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
#          <div class="featured-thumbnail">
#           <img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-120x120.jpg 120w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan.jpg 480w" width="400"/>
#          </div>
#          <div class="overlay">
#           <div class="staff-inner">
#            <h4>
#             Prof. Kenneth Paul TAN
#            </h4>
#            <h5 class="hidden-xs">
#             <p>
#              Professor
#             </p>
#            </h5>
#            <div class="visible-lg">
#             <p>
#              Prof. Tan is a tenured Professor at Hong Kong Baptist University, which hired him under its Talent100 initiative in February 2021.
#             </p>
#            </div>
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
#        <a href="https://jour.hkbu.edu.hk/faculty-member/wang-xiangwei/">
#         <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
#          <div class="featured-thumbnail">
#           <img alt="" class="img-responsive wp-post-image" height="320" sizes="(max-width: 320px) 100vw, 320px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei.png 320w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei-300x300.png 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei-120x120.png 120w" width="320"/>
#          </div>
#          <div class="overlay">
#           <div class="staff-inner">
#            <h4>
#             Mr. Wang Xiangwei
#            </h4>
#            <h5 class="hidden-xs">
#             <p>
#              Mr. Wang Xiangwei
#              <br/>
#              Associate Professor of Practice
#             </p>
#            </h5>
#            <div class="visible-lg">
#            </div>
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
#        <a href="https://jour.hkbu.edu.hk/faculty-member/robin-ewing/">
#         <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
#          <div class="featured-thumbnail">
#           <img alt="MS. EWING ROBIN" class="img-responsive wp-post-image" height="305" sizes="(max-width: 305px) 100vw, 305px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/08/ppl_robin-ewing.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/08/ppl_robin-ewing.jpg 305w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/08/ppl_robin-ewing-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/08/ppl_robin-ewing-300x300.jpg 300w" width="305"/>
#          </div>
#          <div class="overlay">
#           <div class="staff-inner">
#            <h4>
#             Ms. Robin Ewing
#            </h4>
#            <h5 class="hidden-xs">
#             <p>
#              Senior Lecturer
#              <br/>
#              Director of International Journalism Concentration, BComm (Hons.) in Journalism
#             </p>
#            </h5>
#            <div class="visible-lg">
#             <p>
#              Ms. Ewing has worked as a journalist and educator in Asia for most of the last 18 years with a focus on feature writing, narrative nonfiction and digital journalism.
#             </p>
#            </div>
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
#        <a href="https://jour.hkbu.edu.hk/faculty-member/dr-brian-so/">
#         <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
#          <div class="featured-thumbnail">
#           <img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-400x400.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-400x400.png 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-300x300.png 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-120x120.png 120w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM.png 684w" width="400"/>
#          </div>
#          <div class="overlay">
#           <div class="staff-inner">
#            <h4>
#             DR. BRIAN SO
#            </h4>
#            <h5 class="hidden-xs">
#             <p>
#              Associate Professor of Practice
#              <br/>
#              Coordinator of Financial Journalism Stream, Undergraduate Studies
#             </p>
#            </h5>
#            <div class="visible-lg">
#            </div>
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
#        <a href="https://jour.hkbu.edu.hk/faculty-member/mr-pun-wai-lam/">
#         <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
#          <div class="featured-thumbnail">
#           <img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Pun-Wai-Lam-Profile-Picture--400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Pun-Wai-Lam-Profile-Picture--400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Pun-Wai-Lam-Profile-Picture--150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Pun-Wai-Lam-Profile-Picture--120x120.jpg 120w" width="400"/>
#          </div>
#          <div class="overlay">
#           <div class="staff-inner">
#            <h4>
#             Mr. Pun Wai Lam
#            </h4>
#            <h5 class="hidden-xs">
#             <p>
#              Associate Professor of Practice
#             </p>
#            </h5>
#            <div class="visible-lg">
#            </div>
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
#        <a href="https://jour.hkbu.edu.hk/faculty-member/dr-bess-wang-yue/">
#         <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
#          <div class="featured-thumbnail">
#           <img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/02/Bess-Wang-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/02/Bess-Wang-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/02/Bess-Wang-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/02/Bess-Wang-120x120.jpg 120w" width="400"/>
#          </div>
#          <div class="overlay">
#           <div class="staff-inner">
#            <h4>
#             Dr. Bess WANG Yue
#            </h4>
#            <h5 class="hidden-xs">
#             <p>
#              Senior lecturer
#              <br/>
#              Programme Director of Data and Media Communication Concentration (DMC)
#              <br/>
#              Associate director of HKBU Fact Check
#             </p>
#            </h5>
#            <div class="visible-lg">
#            </div>
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
#        <a href="https://jour.hkbu.edu.hk/faculty-member/xiaoyi-fu/">
#         <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
#          <div class="featured-thumbnail">
#           <img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-768x768.jpg 768w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-120x120.jpg 120w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo.jpg 950w" width="400"/>
#          </div>
#          <div class="overlay">
#           <div class="staff-inner">
#            <h4>
#             Dr. Xiaoyi Fu
#            </h4>
#            <h5 class="hidden-xs">
#             <p>
#              Lecturer I
#             </p>
#            </h5>
#            <div class="visible-lg">
#             <p>
#              Dr. Fu holds a Ph.D. degree in Computer Science from Hong Kong Baptist University. She works in the fields of databases, location-based services, geo-social computing and geo-spatial recommendation.
#             </p>
#            </div>
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
#        <a href="https://jour.hkbu.edu.hk/faculty-member/janet-lo/">
#         <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
#          <div class="featured-thumbnail">
#           <img alt="Dr. Janet Lo" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo-120x120.jpg 120w" width="400"/>
#          </div>
#          <div class="overlay">
#           <div class="staff-inner">
#            <h4>
#             Dr. Janet Lo
#            </h4>
#            <h5 class="hidden-xs">
#             <p>
#              Assistant Professor
#             </p>
#            </h5>
#            <div class="visible-lg">
#             <p>
#              Dr. Lo has published in a number of peer-reviewed journals, and received top research paper awards in international conferences.
#             </p>
#            </div>
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
#        <a href="https://jour.hkbu.edu.hk/faculty-member/dr-wang-dan/">
#         <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
#          <div class="featured-thumbnail">
#           <img alt="" class="img-responsive wp-post-image" height="353" sizes="(max-width: 353px) 100vw, 353px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan.png 353w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan-300x300.png 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan-120x120.png 120w" width="353"/>
#          </div>
#          <div class="overlay">
#           <div class="staff-inner">
#            <h4>
#             Dr. WANG DAN (Angela)
#            </h4>
#            <h5 class="hidden-xs">
#             <p>
#              Research Assistant Professor
#              <br/>
#              Programme Director, MSocSc in Media Management
#             </p>
#            </h5>
#            <div class="visible-lg">
#             <p>
#              Dr. Wang’s doctoral dissertation was about how a Communist Party newspaper organisation responded to the impact of digital media. Her main research interest lies in reconciling macro political economy with micro-sociological details
#             </p>
#            </div>
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
#        <a href="https://jour.hkbu.edu.hk/faculty-member/dr-yu-wenting/">
#         <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
#          <div class="featured-thumbnail">
#           <img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/YuWenting-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/YuWenting-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/YuWenting-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/YuWenting-120x120.jpg 120w" width="400"/>
#          </div>
#          <div class="overlay">
#           <div class="staff-inner">
#            <h4>
#             Dr. YU Wenting
#            </h4>
#            <h5 class="hidden-xs">
#             <p>
#              Research Assistant Professor
#             </p>
#            </h5>
#            <div class="visible-lg">
#            </div>
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
#        <a href="https://jour.hkbu.edu.hk/faculty-member/nick-zhang/">
#         <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
#          <div class="featured-thumbnail">
#           <img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-768x768.jpg 768w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-1024x1024.jpg 1024w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-120x120.jpg 120w" width="400"/>
#          </div>
#          <div class="overlay">
#           <div class="staff-inner">
#            <h4>
#             Dr. Nick Yin ZHANG
#            </h4>
#            <h5 class="hidden-xs">
#             <p>
#              Assistant Professor
#              <br/>
#              Programme Director of Bachelor of Arts, Science and Technology (Hons) in Individualised Major
#             </p>
#            </h5>
#            <div class="visible-lg">
#             <p>
#              Dr. Zhang is an interdisciplinary researcher of social science, humanities, and computer science. His research focuses on CMC, social networks, big data, and quality of life.
#             </p>
#            </div>
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
#        <a href="https://jour.hkbu.edu.hk/faculty-member/dr-sheng-zou/">
#         <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
#          <div class="featured-thumbnail">
#           <img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400.png 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400-300x300.png 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400-120x120.png 120w" width="400"/>
#          </div>
#          <div class="overlay">
#           <div class="staff-inner">
#            <h4>
#             DR. SHENG ZOU
#            </h4>
#            <h5 class="hidden-xs">
#             <p>
#              Assistant Professor
#             </p>
#            </h5>
#            <div class="visible-lg">
#             <p>
#              Dr. Sheng Zou is an interdisciplinary media scholar whose research interests span such areas as critical theory, political aesthetics, digital media and society, cultural industries, and global communication.
#             </p>
#            </div>
#           </div>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
#        <a href="https://jour.hkbu.edu.hk/faculty-member/bonnie-chiu/">
#         <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
#          <div class="featured-thumbnail">
#           <img alt="MS. BONNIE CHIU" class="img-responsive wp-post-image" height="400" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/03/ppl_bonnie-chiu.jpg" width="400"/>
#          </div>
#          <div class="overlay">
#           <div class="staff-inner">
#            <h4>
#             Ms. CHIU Lai Yu Bonnie
#            </h4>
#            <h5 class="hidden-xs">
#             <p>
#              Visiting Senior Teaching Fellow
#             </p>
#            </h5>
#            <div class="visible-lg">
#             <p>
# ...
#          <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">
#           Private: MR. CHEUNG SIU WAI
#          </div>
#          <div class="col-md-8">
#           <span class="hidden-md hidden-lg">
#            <br/>
#            Course Taught:
#            <br/>
#           </span>
#           <p>
#            <strong>
#             Courses taught in Taught Postgraduate Programs:
#            </strong>
#           </p>
#           <p>
#            Media and Communication in Chinese Societies
#            <br/>
#            Issues and Cases in Mass Communication
#            <br/>
#            Advanced PR Writing for Multimedia
#            <br/>
#            International Relations Theory and Practice
#            <br/>
#            Globalization, Economics and Finance
#           </p>
#          </div>
#         </div>
#         <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
#          <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">
#           Private: MR. CHEUNG HIN YU JIMMY
#          </div>
#          <div class="col-md-8">
#           <span class="hidden-md hidden-lg">
#            <br/>
#            Course Taught:
#            <br/>
#           </span>
#           <p>
#            English News Reporting and Writing
#           </p>
#          </div>
#         </div>
#         <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
#          <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">
#           Private: MS. CHOI CHRISTY
#          </div>
#          <div class="col-md-8">
#           <span class="hidden-md hidden-lg">
#            <br/>
#            Course Taught:
#            <br/>
#           </span>
#           <p>
#            English News Reporting and Writing
#           </p>
#          </div>
#         </div>
#         <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
#          <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">
#           Private: MR. HO KA TAT
#          </div>
#          <div class="col-md-8">
#           <span class="hidden-md hidden-lg">
#            <br/>
#            Course Taught:
#            <br/>
#           </span>
#           <p>
#            Introduction to Photojournalism
#           </p>
#          </div>
#         </div>
#         <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
#          <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">
#           Private: MR. HO SIU CHUNG BILLY
#          </div>
#          <div class="col-md-8">
#           <span class="hidden-md hidden-lg">
#            <br/>
#            Course Taught:
#            <br/>
#           </span>
#           <p>
#            Multimedia Storytelling
#           </p>
#          </div>
#         </div>
#         <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
#          <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">
#           Private: MS. HUI CHAU HA
#          </div>
#          <div class="col-md-8">
#           <span class="hidden-md hidden-lg">
#            <br/>
#            Course Taught:
#            <br/>
#           </span>
#           <p>
#            Chinese News Writing and Reporting
#           </p>
#          </div>
#         </div>
#         <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
#          <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">
#           Private: MS. HUI FUNG YI POLLY
#          </div>
#          <div class="col-md-8">
#           <span class="hidden-md hidden-lg">
#            <br/>
#            Course Taught:
#            <br/>
#           </span>
#           <p>
#            English News Reporting and Writing
#           </p>
#          </div>
#         </div>
#         <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
#          <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">
#           Private: MR. LAU ANDREW CHRISTOPHER
#          </div>
#          <div class="col-md-8">
#           <span class="hidden-md hidden-lg">
#            <br/>
#            Course Taught:
#            <br/>
#           </span>
#           <p>
#            Law and Ethics for Journalists
#           </p>
#          </div>
#         </div>
#         <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
#          <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">
#           Private: MS. LEUNG HOI NING MAGGIE
#          </div>
#          <div class="col-md-8">
#           <span class="hidden-md hidden-lg">
#            <br/>
#            Course Taught:
#            <br/>
#           </span>
#           <p>
#            News Anchoring
#           </p>
#          </div>
#         </div>
#         <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
#          <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">
#           Private: MR. LI HANG KEI MATTHEW
#          </div>
#          <div class="col-md-8">
#           <span class="hidden-md hidden-lg">
#            <br/>
#            Course Taught:
#            <br/>
#           </span>
#           <p>
#            Sport and Disability in the Hong Kong Chinese Media
#           </p>
#          </div>
#         </div>
#         <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
#          <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">
#           Private: MS. MOY PHAIK SEE PATSY
#          </div>
#          <div class="col-md-8">
#           <span class="hidden-md hidden-lg">
#            <br/>
#            Course Taught:
#            <br/>
#           </span>
#           <p>
#            Law and Ethics for Journalists
#           </p>
#          </div>
#         </div>
#         <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
#          <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">
#           Private: MR. SIU CHI YUI PHILA
#          </div>
#          <div class="col-md-8">
#           <span class="hidden-md hidden-lg">
#            <br/>
#            Course Taught:
#            <br/>
#           </span>
#           <p>
#            Reporting in English
#           </p>
#          </div>
#         </div>
#         <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
#          <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">
#           Private: MR. SUM WAN WAH
#          </div>
#          <div class="col-md-8">
#           <span class="hidden-md hidden-lg">
#            <br/>
#            Course Taught:
#            <br/>
#           </span>
#           <p>
#            Broadcast News Production
#           </p>
#          </div>
#         </div>
#         <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
#          <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">
#           Private: MR. WONG HO WA
#          </div>
#          <div class="col-md-8">
#           <span class="hidden-md hidden-lg">
#            <br/>
#            Course Taught:
#            <br/>
#           </span>
#           <p>
#            Integrated Data-driven Storytelling
#           </p>
#          </div>
#         </div>
#         <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
#          <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">
#           Private: MR. WU HONG CHUN DANIEL
#          </div>
#          <div class="col-md-8">
#           <span class="hidden-md hidden-lg">
#            <br/>
#            Course Taught:
#            <br/>
#           </span>
#           <p>
#            Social Media Content Management
#           </p>
#          </div>
#         </div>
#         <script>
#          $(document).ready(function(){
# 						$('.pt-colleagues-title').each(function() {
# 							var text = $(this).text();
# 							$(this).text(text.replace('Private: ', ''));
# 						});
# 					});
#         </script>
#        </div>
#       </div>
#      </div>
#      <!-- PT Colleagues -->
#      <div id="visiting-scholars" style="display:none">
#       <div class="row">
#        <div class="col-lg-12 wow fadeInDown">
#         <h3>
#          Visiting Scholars
#         </h3>
#        </div>
#       </div>
#      </div>
#      <!-- Visiting Scholars -->
#      <div id="supporting-staff">
#       <div class="row" id="other-officers">
#        <div class="col-lg-12 wow fadeInDown">
#         <h3>
#          Supporting Staff
#         </h3>
#        </div>
#        <div class="col-lg-3 col-md-4 col-sm-6 col-xs-12">
#         <div class="supporting-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
#          <div class="featured-thumbnail">
#           <img class="img-responsive" src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/bg_support-staff.svg"/>
#          </div>
#          <div class="staff-info">
#           <h4>
#            Ms. Bobo WEI
#           </h4>
#           <h5 class="member-title hidden-xs">
#            <p>
#             Executive Officer
#            </p>
#           </h5>
#           <div class="member-info">
#            <a href="mailto:bobowei@hkbu.edu.hk" title="bobowei@hkbu.edu.hk">
#             bobowei@hkbu.edu.hk
#            </a>
#            <br/>
#            (852) 3411 7889
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="col-lg-3 col-md-4 col-sm-6 col-xs-12">
#         <div class="supporting-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
#          <div class="featured-thumbnail">
#           <img class="img-responsive" src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/bg_support-staff.svg"/>
#          </div>
#          <div class="staff-info">
#           <h4>
#            Mr. Joe Ying
#           </h4>
#           <h5 class="member-title hidden-xs">
#            <p>
#             Executive Assistant
#            </p>
#           </h5>
#           <div class="member-info">
#            <a href="mailto:joeying@hkbu.edu.hk" title="joeying@hkbu.edu.hk">
#             joeying@hkbu.edu.hk
#            </a>
#            <br/>
#            (852) 3411 7490
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="col-lg-3 col-md-4 col-sm-6 col-xs-12">
#         <div class="supporting-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
#          <div class="featured-thumbnail">
#           <img class="img-responsive" src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/bg_support-staff.svg"/>
#          </div>
#          <div class="staff-info">
#           <h4>
#            Mr. Cheng Kin Chung
#           </h4>
#           <h5 class="member-title hidden-xs">
#            <p>
#             Technical Officer
#            </p>
#           </h5>
#           <div class="member-info">
#            <a href="mailto:kccheng@hkbu.edu.hk" title="kccheng@hkbu.edu.hk">
#             kccheng@hkbu.edu.hk
#            </a>
#            <br/>
#            (852) 3411 5069
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <!-- Supporting Staff -->
#     </div>
#     <!--/.container-->
#    </section>
#   </div>
#   <!-- #content -->
#   <footer id="footer">
#    <div class="container footer-bar">
#     <div class="row">
#      <div class="col-lg-6 col-md-6 hidden-sm hidden-xs">
#       <button class="toggle-menu quick-links">
#        Quick Links
#       </button>
#      </div>
#      <div class="col-lg-6 col-md-6 col-sm-12 col-xs-12 copyright" style="padding-right:0">
#       © HKBU |
#       <a href="https://www.hkbu.edu.hk/eng/about/privacy.jsp" style="color:#fff" target="_blank">
#        Privacy Policy
#       </a>
#       |
#       <a href="http://jour.hkbu.edu.hk/home/disclaimer/" style="color:#fff">
#        Disclaimer
#       </a>
#       | All rights reserved.
#      </div>
#     </div>
#    </div>
#    <div class="footer-menu-bottom">
#     <!-- Bottom menu element-->
#     <div class="container">
#      <!-- Row 1 -->
#      <div class="col-xs-12 col-sm-6 col-md-4">
#       <div class="row">
#        <a href="https://jour.hkbu.edu.hk/contact-us" target="_blank">
#         Contact Us
#         <i class="fa fa-angle-right redirect">
#         </i>
#        </a>
#       </div>
#      </div>
#      <div class="col-xs-12 col-sm-6 col-md-4">
#       <div class="row">
#        <a href="https://jour.hkbu.edu.hk/students-and-alumni/study-trips/">
#         Study Trips
#         <i class="fa fa-angle-right redirect">
#         </i>
#        </a>
#       </div>
#      </div>
#      <div class="col-xs-12 col-sm-6 col-md-4">
#       <div class="row">
#        <a href="http://admissions.hkbu.edu.hk/en/hkdse.html" target="_blank">
#         HKBU Admissions
#         <i class="fa fa-angle-right redirect">
#         </i>
#        </a>
#       </div>
#      </div>
#      <!-- Row 2 -->
#      <div class="col-xs-12 col-sm-6 col-md-4">
#       <div class="row">
#        <a href="https://www.youtube.com/embed/GhmzdbjrGuI?autoplay=1" target="_blank">
#         Department Video
#         <i class="fa fa-angle-right redirect">
#         </i>
#        </a>
#       </div>
#      </div>
#      <div class="col-xs-12 col-sm-6 col-md-4">
#       <div class="row">
#        <a href="https://jour.hkbu.edu.hk/students-and-alumni/exchange-programmes/">
#         Student Exchange
#         <i class="fa fa-angle-right redirect">
#         </i>
#        </a>
#       </div>
#      </div>
#      <div class="col-xs-12 col-sm-6 col-md-4">
#       <div class="row">
#        <a href="http://sa.hkbu.edu.hk/home/" target="_blank">
#         Office of Student Affairs
#         <i class="fa fa-angle-right redirect">
#         </i>
#        </a>
#       </div>
#      </div>
#      <!-- Row 3 -->
#      <div class="col-xs-12 col-sm-6 col-md-4">
#       <div class="row">
#        <a href="https://jour.hkbu.edu.hk/faculty">
#         Faculty
#         <i class="fa fa-angle-right redirect">
#         </i>
#        </a>
#       </div>
#      </div>
#      <div class="col-xs-12 col-sm-6 col-md-4">
#       <div class="row">
#        <a href="https://sa.hkbu.edu.hk/sfa/scholarships/scholarships-for-undergraduate-students/for-school-of-communication" target="_blank">
#         Student Scholarships
#         <i class="fa fa-angle-right redirect">
#         </i>
#        </a>
#       </div>
#      </div>
#      <div class="col-xs-12 col-sm-6 col-md-4">
#       <div class="row">
#        ​
#       </div>
#      </div>
#      <!-- Row 4 -->
#      <div class="col-xs-12 col-sm-6 col-md-4">
#       <div class="row">
#        <a href="https://jour.hkbu.edu.hk/students-and-alumni/achievements/">
#         Student Achievements
#         <i class="fa fa-angle-right redirect">
#         </i>
#        </a>
#       </div>
#      </div>
#      <div class="col-xs-12 col-sm-6 col-md-4">
#       <div class="row">
#        <a href="https://jour.hkbu.edu.hk/practicum">
#         Practicum
#         <i class="fa fa-angle-right redirect">
#         </i>
#        </a>
#       </div>
#      </div>
#      <div class="col-xs-12 col-sm-6 col-md-4">
#       <div class="row">
#        ​
#       </div>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <!--/#footer-->
#   <script src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/js/wow.min.js">
#   </script>
#   <script src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/js/lightcase.js">
#   </script>
#   <script src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/js/flickity.pkgd.js">
#   </script>
#   <script src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/js/modernizr.js">
#   </script>
#  </body>
# </html>

# %% [markdown]
# Above we printed the HTML code of the website,
# decoded as a beautiful soup object
# `<xxx> </xxx>`: are the tags, for more info:
# https://www.w3schools.com/tags/ref_byfunc.asp
#
# **class and id: **used as hooks to give unique styling and id to elements in HTML
#
# Full list of HTML tags: https://developer.mozilla.org/en-US/docs/Web/HTML/Element

# %% [markdown]
# ### Extracting contents (understanding the HTML)
# ** working with tags, attributes, ```find```, and ```find_all``` **
#
# 1. extracting the title
# 2. extracting the body
# 3. extracting the paragraphs
# 4. extracting the URLs

# %%
print(soup.title) #including tag,title.text can extract text
# Title of the website, used for check whether it is the proper webpage to work on
# Out:
# <title>Faculty | HKBU | Department of Journalism</title>

# %%
print(soup.body)
# Out:
# <body class="page-template page-template-page-templates page-template-page-faculty page-template-page-templatespage-faculty-php page page-id-26 parent-faculty group-blog" id="faculty">
# <!-- SCROLL TOP BUTTON -->
# <a class="scrollToTop" href="#">
# <div class="btn-top">TOP</div>
# </a>
# <!-- END SCROLL TOP BUTTON -->
# <header id="header">
# <div class="top-bar">
# <div class="container">
# <nav class="navbar navbar-inverse">
# <div class="container-fluid">
# <div class="navbar-header">
# <button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" type="button">
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <a class="navbar-brand bu_logo" href="https://www.hkbu.edu.hk/eng/main/index.jsp" target="_blank">
# <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/hkbu.png"/>
# </a>
# <a class="navbar-brand bu_logo_mobile" href="https://www.hkbu.edu.hk/eng/main/index.jsp" target="_blank">
# <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/logo_hkbu_mobile.png"/>
# </a>
# <a class="navbar-brand comf_logo" href="https://www.comm.hkbu.edu.hk/comd-www/english/front/index.htm" target="_blank">
# <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/comm.png"/>
# </a>
# <a class="navbar-brand comf_logo_mobile" href="https://www.comm.hkbu.edu.hk/comd-www/english/front/index.htm" target="_blank">
# <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/COMF_2021-white_small_short.png"/>
# </a>
# <a class="navbar-brand jour_logo" href="https://jour.hkbu.edu.hk">
# <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/logo_hkbu-journalism_small.png"/>
# </a>
# <a class="navbar-brand jour_logo_mobile" href="https://jour.hkbu.edu.hk">
# <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/logo_hkbu-journalism_small_short.png"/>
# </a>
# </div>
# <div class="collapse navbar-collapse" id="navigation">
# <ul class="nav navbar-nav visible-xs">
# <li><a href="https://jour.hkbu.edu.hk">Home</a></li>
# <li><a href="https://jour.hkbu.edu.hk/about-us">About</a>
# </li>
# <li class="dropdown">
# <a class="dropdown-toggle" data-target="drop-programmes" data-toggle="dropdown" href="#drop-programmes" type="button">
# 																Study Path
# 															<b class="caret"></b>
# </a>
# <ul class="dropdown-menu" id="drop-programmes">
# <li style="display:none">
# <a href="https://jour.hkbu.edu.hk/programmes/programme-structure">
# 																			Programme Structure
# 																		</a>
# </li>
# <li style="padding:8px 12px; color:#fff; font-weight:600">								Undergraduate Programmes
# 															</li>
# <ul class="sub_ul" style="list-style:none; font-size:12px;">
# <!-- <li><a href="https://jour.hkbu.edu.hk/programmes/chinese-journalism">Chinese Journalism</a></li>-->
# <li><a href="https://jour.hkbu.edu.hk/programmes/journalism">								Journalism
# 								</a></li>
# <li><a href="http://bu-dmc.hkbu.edu.hk/" target="_blank">Data and Media Communication</a></li>
# </ul>
# <li><a href="http://comd.hkbu.edu.hk/masters/en/maijs.html" target="_blank">Postgraduate Studies</a></li>
# </ul>
# </li>
# <li><a href="https://jour.hkbu.edu.hk/research">Research</a></li>
# <li><a href="https://jour.hkbu.edu.hk/faculty">Faculty</a>
# </li>
# <li><a href="https://jour.hkbu.edu.hk/students-and-alumni">Students &amp; Alumni</a>
# </li>
# <li><a href="https://jour.hkbu.edu.hk/news-events">News &amp; Events</a>
# </li>
# <li><a href="https://jour.hkbu.edu.hk/highlights">Highlights</a>
# </li>
# <li class="dropdown">
# <a class="dropdown-toggle" data-target="drop-programmes" data-toggle="dropdown" href="#drop-programmes" type="button">
# 						Community<b class="caret"></b>
# </a>
# <ul class="dropdown-menu" id="drop-community">
# <li><a href="http://ijs.hkbu.edu.hk" target="_blank">Institute For Journalism &amp; Society</a></li>
# <li><a href="https://dnnsociety.org/" target="_blank">Data &amp; News Society</a></li>
# </ul>
# </li>
# <li><a href="https://jour.hkbu.edu.hk/contact-us">Contact Us</a></li>
# </ul>
# <ul class="nav navbar-nav navbar-right">
# <div class="social">
# <div id="languages">
# <div class="wpml-ls-statics-shortcode_actions wpml-ls wpml-ls-legacy-list-horizontal">
# <ul><li class="wpml-ls-slot-shortcode_actions wpml-ls-item wpml-ls-item-en wpml-ls-current-language wpml-ls-first-item wpml-ls-item-legacy-list-horizontal">
# <a class="wpml-ls-link" href="https://jour.hkbu.edu.hk/faculty/"><span class="wpml-ls-native">EN</span></a>
# </li><li class="wpml-ls-slot-shortcode_actions wpml-ls-item wpml-ls-item-zh-hant wpml-ls-item-legacy-list-horizontal">
# <a class="wpml-ls-link" href="https://jour.hkbu.edu.hk/zh-hant/faculty/"><span class="wpml-ls-display">繁</span></a>
# </li><li class="wpml-ls-slot-shortcode_actions wpml-ls-item wpml-ls-item-zh-hans wpml-ls-last-item wpml-ls-item-legacy-list-horizontal">
# <a class="wpml-ls-link" href="https://jour.hkbu.edu.hk/zh-hans/faculty/"><span class="wpml-ls-display">简</span></a>
# </li></ul>
# </div></div>
# <div class="hidden-xs" id="search"><i class="fa fa-search" data-placement="bottom" data-toggle="tooltip" title="Site Search"></i></div>
# <a href="https://jour.hkbu.edu.hk/searching">
# <div class="visible-xs" id="mobile-search"><i class="fa fa-search"></i></div>
# </a>
# <ul class="social-share fa-lg">
# <li><a href="https://www.facebook.com/hkbujournalism/" target="_blank"><i class="fa fa-facebook" data-placement="bottom" data-toggle="tooltip" title="Facebook"></i></a>
# </li>
# <li><a href="https://www.youtube.com/hkbujournalism" target="_blank"><i class="fa fa-youtube-play" data-placement="bottom" data-toggle="tooltip" title="YouTube"></i></a>
# </li>
# <li><a href="https://www.instagram.com/HKBU_Journalism/" target="_blank"><i class="fab fa-instagram" data-placement="bottom" data-toggle="tooltip" title="Instagram"></i></a>
# </li>
# <li><a href="https://jour.hkbu.edu.hk/contact-us"><i class="fas fa-phone" data-placement="bottom" data-toggle="tooltip" title="Contact Us"></i></a>
# </li>
# </ul>
# <div class="menu-bars">
# <button class="navbar-toggle03 hidden-xs" type="button">
# <div class="icon-bar"></div>
# <div class="icon-bar"></div>
# <div class="icon-bar"></div>
# </button>
# </div>
# </div>
# </ul>
# </div>
# </div>
# </nav>
# </div>
# <!--/container-->
# </div>
# <!--/top-bar-->
# <nav class="navbar2 navbar-inverse navbar-fixed-top" role="banner">
# <div class="container">
# <div class="collapse navbar-collapse">
# <ul class="nav navbar-nav">
# <li><a href="https://jour.hkbu.edu.hk">Home</a></li>
# <li><a href="https://jour.hkbu.edu.hk/about-us">About</a></li>
# <li class="dropdown">
# <a class="dropdown-toggle" data-target="drop-programmes" data-toggle="dropdown" href="#drop-programmes" type="button">
#
# 														Study Path
#
# 						<b class="caret"></b>
# </a>
# <style>
# ul.sub_ul{padding:0}
# ul.sub_ul li{padding-left:30px}
# ul.sub_ul li a, ul.sub_ul li a:hover{color:#fff;}
# ul.sub_ul li:hover{background-color:#0173ba}
# </style>
# <ul class="dropdown-menu" id="drop-programmes" style="min-width:250px">
# <li style="display:none">
# <a href="https://jour.hkbu.edu.hk/programmes/programme-structure">
# 																			Programme Structure
# 																		</a></li>
# <li style="padding:8px 12px; color:#fff; font-weight:600">										Undergraduate Programmes
# 										</li>
# <ul class="sub_ul" style="list-style:none; font-size:12px;">
# <!--<li><a href="https://jour.hkbu.edu.hk/programmes/chinese-journalism">Chinese Journalism</a></li>-->
# <li><a href="https://jour.hkbu.edu.hk/programmes/journalism">								Journalism
# 								</a></li>
# <li><a href="http://bu-dmc.hkbu.edu.hk/" target="_blank">Data and Media Communication</a></li>
# </ul>
# <li><a href="http://comd.hkbu.edu.hk/masters/en/maijs.html" target="_blank">Postgraduate Studies</a></li>
# </ul>
# </li>
# <li><a href="https://jour.hkbu.edu.hk/students-and-alumni/practicum">Practicum</a></li>
# <li><a href="https://jour.hkbu.edu.hk/research">Research</a></li>
# <li><a href="https://jour.hkbu.edu.hk/faculty">Faculty</a></li>
# <li><a href="https://jour.hkbu.edu.hk/students-and-alumni">Students &amp; Alumni</a></li>
# <li class="menu-news"><a href="https://jour.hkbu.edu.hk/news-events">News &amp; Events</a></li>
# <li class="menu-highlights"><a href="https://jour.hkbu.edu.hk/highlights">Highlights</a></li>
# <li class="dropdown menu-community" style="margin-left: 8px;">
# <a class="dropdown-toggle" data-target="drop-programmes" data-toggle="dropdown" href="#drop-programmes" type="button">
# 						Community<b class="caret"></b>
# </a>
# <ul class="dropdown-menu" id="drop-programmes">
# <li><a href="http://ijs.hkbu.edu.hk" target="_blank">Institute For Journalism &amp; Society</a></li>
# <li><a href="https://dnnsociety.org/" target="_blank">Data &amp; News Society</a></li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <div class="search-bar">
# <div class="container">
# <div class="row">
# <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12">
# <div class="col-search-icon">
# <div id="search"><i class="fas fa-search"></i></div>
# </div>
# <div class="col-lg-11 col-md-10 col-sm-10 col-xs-10">
# <form action="https://jour.hkbu.edu.hk/" id="searchform" method="get" role="search">
# <input autocomplete="off" class="search" id="s" name="s" placeholder="Site Search" type="search" value=""/>
# </form>
# </div>
# <div class="close-search"><i class="fas fa-times"></i></div>
# </div>
# </div>
# </div>
# </div> <!-- Search Bar -->
# </header>
# <div class="site-content" id="content"> <section id="top-image">
# <div class="col-lg-12 col-md-12">
# <div class="row">
# <img class="img-responsive visible-lg" id="bg-people" src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/bg_people.jpg">
# <img class="img-responsive hidden-lg" id="bg-people" src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/bg_people2.jpg">
# <div class="container">
# <div class="col-lg-12 col-md-12 in-content">
# <h2 class="slider-title">Faculty</h2>
# <p <p="" class="slide-description">Our faculty members have rich experience in the news industry, media education and journalism research. We also invite a number of frontline reporters and senior media professionals as adjunct lecturers and professors.</p>
#
# </div>
# </div>
# </img></img></div>
# </div>
# </section>
# <!--#top-image-->
# <section class="container" id="filter">
# <div class="row">
# <div class="col-lg-12 col-md-12 col-sm-12 filter">
# <a href="#faculty-members">
# <div class="icon-members">Faculty Members</div>
# </a>
# <a href="#pt-colleagues">
# <div class="icon-ptc">Part-Time Colleagues</div>
# </a>
# <a href="#visiting-scholars" style="display:none">
# <div class="icon-vs">Visiting Scholars</div>
# </a>
# <a href="#supporting-staff">
# <div class="icon-support-staff">Supporting Staff</div>
# </a>
# <a href="https://comd.hkbu.edu.hk/masters/en/maijs.html#section4">
# <div class="icon-vs">
# 													MAIJS Course Instructors
# 											</div>
# </a>
# </div>
# </div></section><!-- Filter -->
# <!--#faculty-staff-->
# <div class="anchor" id="faculty-members"></div>
# <section id="faculty-staff">
# <div class="container">
# <div class="row">
# <div class="col-lg-12 wow fadeInDown">
# <h3>Faculty Members</h3>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/raymond-li/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="Mr. Raymond Li" class="img-responsive wp-post-image" height="400" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/03/ppl_ray-li.jpg" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Prof. Raymond Li                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor of Practice<br/>
# Department Head</p>
# </h5>
# <div class="visible-lg">
# <p>A veteran journalist working at the BBC for over 24 years. Mr. Li was also the first native Chinese to be appointed the Head of Chinese at the BBC.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/luwei-rose-luqiu/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="Dr. Luwei Rose Luqiu" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-120x120.jpg 120w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose.jpg 600w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. Luwei Rose Luqiu                                    </h4>
# <h5 class="hidden-xs">
# <p>Associate Professor<br/>
# Associate Head</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Luqiu had been a television journalist for 20 years. She has covered many major international events ranging from the wars and also reported on Chinese political news and interviewed several Chinese leaders.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/prof-chan-king-cheung/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/03/Screenshot-2022-03-08-at-8.15.03-PM-400x400.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/03/Screenshot-2022-03-08-at-8.15.03-PM-400x400.png 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/03/Screenshot-2022-03-08-at-8.15.03-PM-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/03/Screenshot-2022-03-08-at-8.15.03-PM-120x120.png 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         PROF. CHAN King Cheung                                    </h4>
# <h5 class="hidden-xs">
# <p>Raymond R. Wong Endowed Professor in Media Ethics<br/>
# Professor of Practice</p>
# </h5>
# <div class="visible-lg">
# <p>A veteran journalist with more than 30 years of experience, Professor CHAN King Cheung received his Bachelor degree in Arts, Master degree in Communication and MBA degree from the Chinese University of Hong Kong. He was also a Fellow in Media Management of the Poynter Institute for Media Studies in the United States.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/steve-guo/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="PROF. STEVE GUO" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_steve-guo.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_steve-guo.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_steve-guo-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_steve-guo-300x300.jpg 300w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Prof. Steve Guo                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor<br/>
# Interim Dean, School of Communication</p>
# </h5>
# <div class="visible-lg">
# <p>Prof. Guo has spent his career in journalism and academia, including working at China Daily and researching news production and its social impact. He has been with university for more than 20 years.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/cherian-george/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/Cherian-George-2018-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/Cherian-George-2018-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/Cherian-George-2018-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/Cherian-George-2018-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Prof. Cherian George                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Professor George has spent his career in journalism practice, education, research and advocacy, including working at the Straits Times, editing journals and founding a newspaper for children.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/daya-thussu/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2019/07/Professor-Daya-Thussu-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2019/07/Professor-Daya-Thussu-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2019/07/Professor-Daya-Thussu-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2019/07/Professor-Daya-Thussu-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Prof. Daya Thussu                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Daya Thussu is Professor of International Communication. He was Visiting Professor and inaugural Disney Chair in Global Media at Schwarzman College, Tsinghua University in Beijing. </p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/prof-kennth-paul-tan/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-120x120.jpg 120w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan.jpg 480w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Prof. Kenneth Paul TAN                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Prof. Tan is a tenured Professor at Hong Kong Baptist University, which hired him under its Talent100 initiative in February 2021.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/wang-xiangwei/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="320" sizes="(max-width: 320px) 100vw, 320px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei.png 320w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei-300x300.png 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei-120x120.png 120w" width="320"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Mr. Wang Xiangwei                                    </h4>
# <h5 class="hidden-xs">
# <p>Mr. Wang Xiangwei<br/>
# Associate Professor of Practice</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/robin-ewing/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="MS. EWING ROBIN" class="img-responsive wp-post-image" height="305" sizes="(max-width: 305px) 100vw, 305px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/08/ppl_robin-ewing.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/08/ppl_robin-ewing.jpg 305w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/08/ppl_robin-ewing-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/08/ppl_robin-ewing-300x300.jpg 300w" width="305"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Ms. Robin Ewing                                    </h4>
# <h5 class="hidden-xs">
# <p>Senior Lecturer<br/>
# Director of International Journalism Concentration, BComm (Hons.) in Journalism</p>
# </h5>
# <div class="visible-lg">
# <p>Ms. Ewing has worked as a journalist and educator in Asia for most of the last 18 years with a focus on feature writing, narrative nonfiction and digital journalism.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/dr-brian-so/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-400x400.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-400x400.png 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-300x300.png 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-120x120.png 120w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM.png 684w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         DR. BRIAN SO                                    </h4>
# <h5 class="hidden-xs">
# <p>Associate Professor of Practice<br/>
# Coordinator of Financial Journalism Stream, Undergraduate Studies</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/mr-pun-wai-lam/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Pun-Wai-Lam-Profile-Picture--400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Pun-Wai-Lam-Profile-Picture--400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Pun-Wai-Lam-Profile-Picture--150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Pun-Wai-Lam-Profile-Picture--120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Mr. Pun Wai Lam                                    </h4>
# <h5 class="hidden-xs">
# <p>Associate Professor of Practice</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/dr-bess-wang-yue/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/02/Bess-Wang-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/02/Bess-Wang-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/02/Bess-Wang-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/02/Bess-Wang-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. Bess WANG Yue                                    </h4>
# <h5 class="hidden-xs">
# <p>Senior lecturer<br/>
# Programme Director of Data and Media Communication Concentration (DMC)<br/>
# Associate director of HKBU Fact Check</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/xiaoyi-fu/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-768x768.jpg 768w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-120x120.jpg 120w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo.jpg 950w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. Xiaoyi Fu                                    </h4>
# <h5 class="hidden-xs">
# <p>Lecturer I</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Fu holds a Ph.D. degree in Computer Science from Hong Kong Baptist University. She works in the fields of databases, location-based services, geo-social computing and geo-spatial recommendation. </p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/janet-lo/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="Dr. Janet Lo" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. Janet Lo                                    </h4>
# <h5 class="hidden-xs">
# <p>Assistant Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Lo has published in a number of peer-reviewed journals, and received top research paper awards in international conferences.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/dr-wang-dan/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="353" sizes="(max-width: 353px) 100vw, 353px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan.png 353w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan-300x300.png 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan-120x120.png 120w" width="353"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. WANG DAN (Angela)                                    </h4>
# <h5 class="hidden-xs">
# <p>Research Assistant Professor<br/>
# Programme Director, MSocSc in Media Management</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Wang’s doctoral dissertation was about how a Communist Party newspaper organisation responded to the impact of digital media. Her main research interest lies in reconciling macro political economy with micro-sociological details</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/dr-yu-wenting/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/YuWenting-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/YuWenting-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/YuWenting-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/YuWenting-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. YU Wenting                                    </h4>
# <h5 class="hidden-xs">
# <p>Research Assistant Professor</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/nick-zhang/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-768x768.jpg 768w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-1024x1024.jpg 1024w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. Nick Yin ZHANG                                    </h4>
# <h5 class="hidden-xs">
# <p>Assistant Professor<br/>
# Programme Director of Bachelor of Arts, Science and Technology (Hons) in Individualised Major</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Zhang is an interdisciplinary researcher of social science, humanities, and computer science. His research focuses on CMC, social networks, big data, and quality of life.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/dr-sheng-zou/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400.png 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400-300x300.png 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400-120x120.png 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         DR. SHENG ZOU                                    </h4>
# <h5 class="hidden-xs">
# <p>Assistant Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Sheng Zou is an interdisciplinary media scholar whose research interests span such areas as critical theory, political aesthetics, digital media and society, cultural industries, and global communication. </p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/bonnie-chiu/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="MS. BONNIE CHIU" class="img-responsive wp-post-image" height="400" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/03/ppl_bonnie-chiu.jpg" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Ms. CHIU Lai Yu Bonnie                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Teaching Fellow</p>
# </h5>
# <div class="visible-lg">
# <p>Ms. Chiu has extensive experience in broadcast journalism, including at RTHK, Cable TV and TVB, as well as a being a solicitor admitted in the High Court of Hong Kong.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/clemence-poon/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="Mr. Clemence Poon" class="img-responsive wp-post-image" height="400" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/03/ppl_clemence.jpg" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Mr. Clemence Poon                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Lecturer</p>
# </h5>
# <div class="visible-lg">
# <p>Mr. Poon started off as a financial journalist and moved into financial analysis career, with more than 20 years’ experience in management accounting, financial analysis, business planning and investment appraisal.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/jenny-lam/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="Ms. Jenny Lam" class="img-responsive wp-post-image" height="300" sizes="(max-width: 300px) 100vw, 300px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_jenny-lam.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_jenny-lam.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_jenny-lam-150x150.jpg 150w" width="300"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Ms. Jenny Lam                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Lecturer</p>
# </h5>
# <div class="visible-lg">
# <p>Ms. Lam has extensive experience in broadcast news journalism, including work at TVB and the BBC. She anchored the news for more than 20 years.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/ms-lam-wing-yan/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/01/Lam-Wing-Yan-1-400x400.jpeg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/01/Lam-Wing-Yan-1-400x400.jpeg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/01/Lam-Wing-Yan-1-150x150.jpeg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/01/Lam-Wing-Yan-1-120x120.jpeg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         MS. LAM WING YAN                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Lecturer</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/alison-leung/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/08/IMG_8901.png" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         DR.  ALISON LEUNG                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Lecturer</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Leung has taught journalism at universities in Hong Kong. Before that she was a Senior Correspondent and Deputy Chief of Thomson Reuters’ Hong Kong Bureau.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# </div>
# <!-- Faculty Members -->
# <div id="pt-colleagues" style="margin-bottom: 20px;">
# <div class="row">
# <div class="col-lg-12 wow fadeInDown">
# <h3>Part-Time Colleagues</h3>
# </div>
# <div class="container">
# <div class="row hidden-xs hidden-sm" style="padding: 10px 0; border-bottom:1px solid #ddd">
# <div class="col-md-4" style="color: #0173ba; font-size: 18px;"> </div>
# <div class="col-md-8" style="font-size:18px">
# <b> Course Taught:</b>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">PROF. CK LAU</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Current Issues and Case Studies in International News</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Prof. Alice Y. L. Lee</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Media Communication in the AI Era</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MS. AU KA KEI KITTY</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>News Translation<br/>
# Chinese News Writing and Reporting</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MR. BURTON-BRADLEY ROBERT</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>English News Reporting and Writing</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MS. CHAN KA HANG EMILY</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Financial Data and Market Sentiment Analysis</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MS. CHAN WAI MAN CARMEN</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Reporting Business and Financial News in Chinese</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MR. CHEUNG SIU WAI</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p><strong>Courses taught in Taught Postgraduate Programs:</strong></p>
# <p>Media and Communication in Chinese Societies<br/>
# Issues and Cases in Mass Communication<br/>
# Advanced PR Writing for Multimedia<br/>
# International Relations Theory and Practice<br/>
# Globalization, Economics and Finance</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MR. CHEUNG HIN YU JIMMY</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>English News Reporting and Writing</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MS. CHOI CHRISTY</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>English News Reporting and Writing</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MR. HO KA TAT</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Introduction to Photojournalism</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MR. HO SIU CHUNG BILLY</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Multimedia Storytelling</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MS. HUI CHAU HA</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Chinese News Writing and Reporting</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MS. HUI FUNG YI POLLY</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>English News Reporting and Writing</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MR. LAU ANDREW CHRISTOPHER</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Law and Ethics for Journalists</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MS. LEUNG HOI NING MAGGIE</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>News Anchoring</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MR. LI HANG KEI MATTHEW</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Sport and Disability in the Hong Kong Chinese Media</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MS. MOY PHAIK SEE PATSY</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Law and Ethics for Journalists</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MR. SIU CHI YUI PHILA</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Reporting in English</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MR. SUM WAN WAH</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Broadcast News Production</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MR. WONG HO WA</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Integrated Data-driven Storytelling</p>
# </div>
# </div>
# <div class="row" style="padding: 10px 0; border-bottom:1px solid #ddd; ">
# <div class="col-md-4 pt-colleagues-title" style="color: #0173ba; font-size: 18px; font-weight: 600; text-transform: capitalize;">Private: MR. WU HONG CHUN DANIEL</div>
# <div class="col-md-8">
# <span class="hidden-md hidden-lg"><br/>Course Taught:<br/></span>
# <p>Social Media Content Management</p>
# </div>
# </div>
# <script>
# 					$(document).ready(function(){
# 						$('.pt-colleagues-title').each(function() {
# 							var text = $(this).text();
# 							$(this).text(text.replace('Private: ', ''));
# 						});
# 					});
# 					</script>
# </div>
# </div>
# </div>
# <!-- PT Colleagues -->
# <div id="visiting-scholars" style="display:none">
# <div class="row">
# <div class="col-lg-12 wow fadeInDown">
# <h3>Visiting Scholars</h3>
# </div>
# </div>
# </div>
# <!-- Visiting Scholars -->
# <div id="supporting-staff">
# <div class="row" id="other-officers">
# <div class="col-lg-12 wow fadeInDown">
# <h3>Supporting Staff</h3>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-xs-12">
# <div class="supporting-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail">
# <img class="img-responsive" src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/bg_support-staff.svg"/>
# </div>
# <div class="staff-info">
# <h4>
#                                         Ms. Bobo WEI                                    </h4>
# <h5 class="member-title hidden-xs">
# <p>Executive Officer</p>
# </h5>
# <div class="member-info">
# <a href="mailto:bobowei@hkbu.edu.hk" title="bobowei@hkbu.edu.hk">bobowei@hkbu.edu.hk</a><br/>
#                                         (852) 3411 7889                                    </div>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-xs-12">
# <div class="supporting-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail">
# <img class="img-responsive" src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/bg_support-staff.svg"/>
# </div>
# <div class="staff-info">
# <h4>
#                                         Mr. Joe Ying                                    </h4>
# <h5 class="member-title hidden-xs">
# <p>Executive Assistant</p>
# </h5>
# <div class="member-info">
# <a href="mailto:joeying@hkbu.edu.hk" title="joeying@hkbu.edu.hk">joeying@hkbu.edu.hk</a><br/>
#                                         (852) 3411 7490                                    </div>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-xs-12">
# <div class="supporting-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail">
# <img class="img-responsive" src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/bg_support-staff.svg"/>
# </div>
# <div class="staff-info">
# <h4>
#                                         Mr. Cheng Kin Chung                                    </h4>
# <h5 class="member-title hidden-xs">
# <p>Technical Officer</p>
# </h5>
# <div class="member-info">
# <a href="mailto:kccheng@hkbu.edu.hk" title="kccheng@hkbu.edu.hk">kccheng@hkbu.edu.hk</a><br/>
#                                         (852) 3411 5069                                    </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- Supporting Staff -->
# </div>
# <!--/.container-->
# </section>
# </div><!-- #content -->
# <footer id="footer">
# <div class="container footer-bar">
# <div class="row">
# <div class="col-lg-6 col-md-6 hidden-sm hidden-xs">
# <button class="toggle-menu quick-links">Quick Links</button>
# </div>
# <div class="col-lg-6 col-md-6 col-sm-12 col-xs-12 copyright" style="padding-right:0">
# 					© HKBU |
# 					<a href="https://www.hkbu.edu.hk/eng/about/privacy.jsp" style="color:#fff" target="_blank">Privacy Policy</a> |
# 					<a href="http://jour.hkbu.edu.hk/home/disclaimer/" style="color:#fff">Disclaimer</a> | All rights reserved.
#
# 				</div>
# </div>
# </div>
# <div class="footer-menu-bottom">
# <!-- Bottom menu element-->
# <div class="container">
# <!-- Row 1 -->
# <div class="col-xs-12 col-sm-6 col-md-4">
# <div class="row"><a href="https://jour.hkbu.edu.hk/contact-us" target="_blank">Contact Us<i class="fa fa-angle-right redirect"></i></a>
# </div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-4">
# <div class="row"><a href="https://jour.hkbu.edu.hk/students-and-alumni/study-trips/">Study Trips<i class="fa fa-angle-right redirect"></i></a>
# </div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-4">
# <div class="row"><a href="http://admissions.hkbu.edu.hk/en/hkdse.html" target="_blank">HKBU Admissions<i class="fa fa-angle-right redirect"></i></a>
# </div>
# </div>
# <!-- Row 2 -->
# <div class="col-xs-12 col-sm-6 col-md-4">
# <div class="row"><a href="https://www.youtube.com/embed/GhmzdbjrGuI?autoplay=1" target="_blank">Department Video<i class="fa fa-angle-right redirect"></i></a>
# </div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-4">
# <div class="row"><a href="https://jour.hkbu.edu.hk/students-and-alumni/exchange-programmes/">Student Exchange<i class="fa fa-angle-right redirect"></i></a>
# </div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-4">
# <div class="row"><a href="http://sa.hkbu.edu.hk/home/" target="_blank">Office of Student Affairs<i class="fa fa-angle-right redirect"></i></a>
# </div>
# </div>
# <!-- Row 3 -->
# <div class="col-xs-12 col-sm-6 col-md-4">
# <div class="row"><a href="https://jour.hkbu.edu.hk/faculty">Faculty<i class="fa fa-angle-right redirect"></i></a>
# </div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-4">
# <div class="row"><a href="https://sa.hkbu.edu.hk/sfa/scholarships/scholarships-for-undergraduate-students/for-school-of-communication" target="_blank">Student Scholarships<i class="fa fa-angle-right redirect"></i></a>
# </div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-4">
# <div class="row">​</div>
# </div>
# <!-- Row 4 -->
# <div class="col-xs-12 col-sm-6 col-md-4">
# <div class="row"><a href="https://jour.hkbu.edu.hk/students-and-alumni/achievements/">Student Achievements<i class="fa fa-angle-right redirect"></i></a>
# </div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-4">
# <div class="row"><a href="https://jour.hkbu.edu.hk/practicum">Practicum<i class="fa fa-angle-right redirect"></i></a>
# </div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-4">
# <div class="row">​</div>
# </div>
# </div>
# </div>
# </footer>
# <!--/#footer-->
# <script src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/js/wow.min.js"></script>
# <script src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/js/lightcase.js"></script>
# <script src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/js/flickity.pkgd.js"></script>
# <script src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/js/modernizr.js"></script>
# </body>

# %%
# If we want to extract specific text
print(soup.find('h2')) # will only return first <h2> tag
# Out:
# <h2 class="slider-title">Faculty</h2>

# %%
print(soup.find('h2').text) # will return all the <h2> tag (although this page only has one)
# Out:
# Faculty

# %%
# If we want to extract specific text
print(soup.find('p')) # will only return first <p> tag
# Out:
# <p <p="" class="slide-description">Our faculty members have rich experience in the news industry, media education and journalism research. We also invite a number of frontline reporters and senior media professionals as adjunct lecturers and professors.</p>

# %%
#print(soup.find('p').text)   # extracts the string within the <p> tag
print( soup.find('p').get_text()  )
# Out:
# Our faculty members have rich experience in the news industry, media education and journalism research. We also invite a number of frontline reporters and senior media professionals as adjunct lecturers and professors.

# %%
# If we want to extract all <p> tags
print(soup.find_all('p')) # returns list of all <p> tags
# Output Format [p,p,p,p]
# Out:
# [<p <p="" class="slide-description">Our faculty members have rich experience in the news industry, media education and journalism research. We also invite a number of frontline reporters and senior media professionals as adjunct lecturers and professors.</p>, <p>Professor of Practice<br/>
# Department Head</p>, <p>A veteran journalist working at the BBC for over 24 years. Mr. Li was also the first native Chinese to be appointed the Head of Chinese at the BBC.</p>, <p>Associate Professor<br/>
# Associate Head</p>, <p>Dr. Luqiu had been a television journalist for 20 years. She has covered many major international events ranging from the wars and also reported on Chinese political news and interviewed several Chinese leaders.</p>, <p>Raymond R. Wong Endowed Professor in Media Ethics<br/>
# Professor of Practice</p>, <p>A veteran journalist with more than 30 years of experience, Professor CHAN King Cheung received his Bachelor degree in Arts, Master degree in Communication and MBA degree from the Chinese University of Hong Kong. He was also a Fellow in Media Management of the Poynter Institute for Media Studies in the United States.</p>, <p>Professor<br/>
# Interim Dean, School of Communication</p>, <p>Prof. Guo has spent his career in journalism and academia, including working at China Daily and researching news production and its social impact. He has been with university for more than 20 years.</p>, <p>Professor</p>, <p>Professor George has spent his career in journalism practice, education, research and advocacy, including working at the Straits Times, editing journals and founding a newspaper for children.</p>, <p>Professor</p>, <p>Daya Thussu is Professor of International Communication. He was Visiting Professor and inaugural Disney Chair in Global Media at Schwarzman College, Tsinghua University in Beijing. </p>, <p>Professor</p>, <p>Prof. Tan is a tenured Professor at Hong Kong Baptist University, which hired him under its Talent100 initiative in February 2021.</p>, <p>Mr. Wang Xiangwei<br/>
# Associate Professor of Practice</p>, <p>Senior Lecturer<br/>
# Director of International Journalism Concentration, BComm (Hons.) in Journalism</p>, <p>Ms. Ewing has worked as a journalist and educator in Asia for most of the last 18 years with a focus on feature writing, narrative nonfiction and digital journalism.</p>, <p>Associate Professor of Practice<br/>
# Coordinator of Financial Journalism Stream, Undergraduate Studies</p>, <p>Associate Professor of Practice</p>, <p>Senior lecturer<br/>
# Programme Director of Data and Media Communication Concentration (DMC)<br/>
# Associate director of HKBU Fact Check</p>, <p>Lecturer I</p>, <p>Dr. Fu holds a Ph.D. degree in Computer Science from Hong Kong Baptist University. She works in the fields of databases, location-based services, geo-social computing and geo-spatial recommendation. </p>, <p>Assistant Professor</p>, <p>Dr. Lo has published in a number of peer-reviewed journals, and received top research paper awards in international conferences.</p>, <p>Research Assistant Professor<br/>
# Programme Director, MSocSc in Media Management</p>, <p>Dr. Wang’s doctoral dissertation was about how a Communist Party newspaper organisation responded to the impact of digital media. Her main research interest lies in reconciling macro political economy with micro-sociological details</p>, <p>Research Assistant Professor</p>, <p>Assistant Professor<br/>
# Programme Director of Bachelor of Arts, Science and Technology (Hons) in Individualised Major</p>, <p>Dr. Zhang is an interdisciplinary researcher of social science, humanities, and computer science. His research focuses on CMC, social networks, big data, and quality of life.</p>, <p>Assistant Professor</p>, <p>Dr. Sheng Zou is an interdisciplinary media scholar whose research interests span such areas as critical theory, political aesthetics, digital media and society, cultural industries, and global communication. </p>, <p>Visiting Senior Teaching Fellow</p>, <p>Ms. Chiu has extensive experience in broadcast journalism, including at RTHK, Cable TV and TVB, as well as a being a solicitor admitted in the High Court of Hong Kong.</p>, <p>Visiting Senior Lecturer</p>, <p>Mr. Poon started off as a financial journalist and moved into financial analysis career, with more than 20 years’ experience in management accounting, financial analysis, business planning and investment appraisal.</p>, <p>Visiting Senior Lecturer</p>, <p>Ms. Lam has extensive experience in broadcast news journalism, including work at TVB and the BBC. She anchored the news for more than 20 years.</p>, <p>Visiting Senior Lecturer</p>, <p>Visiting Senior Lecturer</p>, <p>Dr. Leung has taught journalism at universities in Hong Kong. Before that she was a Senior Correspondent and Deputy Chief of Thomson Reuters’ Hong Kong Bureau.</p>, <p>Current Issues and Case Studies in International News</p>, <p>Media Communication in the AI Era</p>, <p>News Translation<br/>
# Chinese News Writing and Reporting</p>, <p>English News Reporting and Writing</p>, <p>Financial Data and Market Sentiment Analysis</p>, <p>Reporting Business and Financial News in Chinese</p>, <p><strong>Courses taught in Taught Postgraduate Programs:</strong></p>, <p>Media and Communication in Chinese Societies<br/>
# Issues and Cases in Mass Communication<br/>
# Advanced PR Writing for Multimedia<br/>
# International Relations Theory and Practice<br/>
# Globalization, Economics and Finance</p>, <p>English News Reporting and Writing</p>, <p>English News Reporting and Writing</p>, <p>Introduction to Photojournalism</p>, <p>Multimedia Storytelling</p>, <p>Chinese News Writing and Reporting</p>, <p>English News Reporting and Writing</p>, <p>Law and Ethics for Journalists</p>, <p>News Anchoring</p>, <p>Sport and Disability in the Hong Kong Chinese Media</p>, <p>Law and Ethics for Journalists</p>, <p>Reporting in English</p>, <p>Broadcast News Production</p>, <p>Integrated Data-driven Storytelling</p>, <p>Social Media Content Management</p>, <p>Executive Officer</p>, <p>Executive Assistant</p>, <p>Technical Officer</p>]

# %%
# using loop to print all the "text" under the "p" (paragraphes)

for p in soup.find_all('p'):
    print(p.text)
# Out:
# Our faculty members have rich experience in the news industry, media education and journalism research. We also invite a number of frontline reporters and senior media professionals as adjunct lecturers and professors.
# Professor of Practice
# Department Head
# A veteran journalist working at the BBC for over 24 years. Mr. Li was also the first native Chinese to be appointed the Head of Chinese at the BBC.
# Associate Professor
# Associate Head
# Dr. Luqiu had been a television journalist for 20 years. She has covered many major international events ranging from the wars and also reported on Chinese political news and interviewed several Chinese leaders.
# Raymond R. Wong Endowed Professor in Media Ethics
# Professor of Practice
# A veteran journalist with more than 30 years of experience, Professor CHAN King Cheung received his Bachelor degree in Arts, Master degree in Communication and MBA degree from the Chinese University of Hong Kong. He was also a Fellow in Media Management of the Poynter Institute for Media Studies in the United States.
# Professor
# Interim Dean, School of Communication
# Prof. Guo has spent his career in journalism and academia, including working at China Daily and researching news production and its social impact. He has been with university for more than 20 years.
# Professor
# Professor George has spent his career in journalism practice, education, research and advocacy, including working at the Straits Times, editing journals and founding a newspaper for children.
# Professor
# Daya Thussu is Professor of International Communication. He was Visiting Professor and inaugural Disney Chair in Global Media at Schwarzman College, Tsinghua University in Beijing.
# Professor
# Prof. Tan is a tenured Professor at Hong Kong Baptist University, which hired him under its Talent100 initiative in February 2021.
# Mr. Wang Xiangwei
# Associate Professor of Practice
# Senior Lecturer
# Director of International Journalism Concentration, BComm (Hons.) in Journalism
# Ms. Ewing has worked as a journalist and educator in Asia for most of the last 18 years with a focus on feature writing, narrative nonfiction and digital journalism.
# Associate Professor of Practice
# Coordinator of Financial Journalism Stream, Undergraduate Studies
# Associate Professor of Practice
# Senior lecturer
# Programme Director of Data and Media Communication Concentration (DMC)
# Associate director of HKBU Fact Check
# Lecturer I
# Dr. Fu holds a Ph.D. degree in Computer Science from Hong Kong Baptist University. She works in the fields of databases, location-based services, geo-social computing and geo-spatial recommendation.
# Assistant Professor
# Dr. Lo has published in a number of peer-reviewed journals, and received top research paper awards in international conferences.
# Research Assistant Professor
# Programme Director, MSocSc in Media Management
# Dr. Wang’s doctoral dissertation was about how a Communist Party newspaper organisation responded to the impact of digital media. Her main research interest lies in reconciling macro political economy with micro-sociological details
# Research Assistant Professor
# Assistant Professor
# Programme Director of Bachelor of Arts, Science and Technology (Hons) in Individualised Major
# Dr. Zhang is an interdisciplinary researcher of social science, humanities, and computer science. His research focuses on CMC, social networks, big data, and quality of life.
# Assistant Professor
# Dr. Sheng Zou is an interdisciplinary media scholar whose research interests span such areas as critical theory, political aesthetics, digital media and society, cultural industries, and global communication.
# Visiting Senior Teaching Fellow
# Ms. Chiu has extensive experience in broadcast journalism, including at RTHK, Cable TV and TVB, as well as a being a solicitor admitted in the High Court of Hong Kong.
# Visiting Senior Lecturer
# Mr. Poon started off as a financial journalist and moved into financial analysis career, with more than 20 years’ experience in management accounting, financial analysis, business planning and investment appraisal.
# Visiting Senior Lecturer
# Ms. Lam has extensive experience in broadcast news journalism, including work at TVB and the BBC. She anchored the news for more than 20 years.
# Visiting Senior Lecturer
# Visiting Senior Lecturer
# Dr. Leung has taught journalism at universities in Hong Kong. Before that she was a Senior Correspondent and Deputy Chief of Thomson Reuters’ Hong Kong Bureau.
# Current Issues and Case Studies in International News
# Media Communication in the AI Era
# News Translation
# Chinese News Writing and Reporting
# English News Reporting and Writing
# Financial Data and Market Sentiment Analysis
# Reporting Business and Financial News in Chinese
# Courses taught in Taught Postgraduate Programs:
# Media and Communication in Chinese Societies
# Issues and Cases in Mass Communication
# Advanced PR Writing for Multimedia
# International Relations Theory and Practice
# Globalization, Economics and Finance
# English News Reporting and Writing
# English News Reporting and Writing
# Introduction to Photojournalism
# Multimedia Storytelling
# Chinese News Writing and Reporting
# English News Reporting and Writing
# Law and Ethics for Journalists
# News Anchoring
# Sport and Disability in the Hong Kong Chinese Media
# Law and Ethics for Journalists
# Reporting in English
# Broadcast News Production
# Integrated Data-driven Storytelling
# Social Media Content Management
# Executive Officer
# Executive Assistant
# Technical Officer

# %%
# Extract all the navigation bars
navigation_bar = soup.find('nav')
print(navigation_bar)
# Out:
# <nav class="navbar navbar-inverse">
# <div class="container-fluid">
# <div class="navbar-header">
# <button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" type="button">
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <a class="navbar-brand bu_logo" href="https://www.hkbu.edu.hk/eng/main/index.jsp" target="_blank">
# <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/hkbu.png"/>
# </a>
# <a class="navbar-brand bu_logo_mobile" href="https://www.hkbu.edu.hk/eng/main/index.jsp" target="_blank">
# <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/logo_hkbu_mobile.png"/>
# </a>
# <a class="navbar-brand comf_logo" href="https://www.comm.hkbu.edu.hk/comd-www/english/front/index.htm" target="_blank">
# <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/comm.png"/>
# </a>
# <a class="navbar-brand comf_logo_mobile" href="https://www.comm.hkbu.edu.hk/comd-www/english/front/index.htm" target="_blank">
# <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/COMF_2021-white_small_short.png"/>
# </a>
# <a class="navbar-brand jour_logo" href="https://jour.hkbu.edu.hk">
# <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/logo_hkbu-journalism_small.png"/>
# </a>
# <a class="navbar-brand jour_logo_mobile" href="https://jour.hkbu.edu.hk">
# <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/logo_hkbu-journalism_small_short.png"/>
# </a>
# </div>
# <div class="collapse navbar-collapse" id="navigation">
# <ul class="nav navbar-nav visible-xs">
# <li><a href="https://jour.hkbu.edu.hk">Home</a></li>
# <li><a href="https://jour.hkbu.edu.hk/about-us">About</a>
# </li>
# <li class="dropdown">
# <a class="dropdown-toggle" data-target="drop-programmes" data-toggle="dropdown" href="#drop-programmes" type="button">
# 																Study Path
# 															<b class="caret"></b>
# </a>
# <ul class="dropdown-menu" id="drop-programmes">
# <li style="display:none">
# <a href="https://jour.hkbu.edu.hk/programmes/programme-structure">
# 																			Programme Structure
# 																		</a>
# </li>
# <li style="padding:8px 12px; color:#fff; font-weight:600">								Undergraduate Programmes
# 															</li>
# <ul class="sub_ul" style="list-style:none; font-size:12px;">
# <!-- <li><a href="https://jour.hkbu.edu.hk/programmes/chinese-journalism">Chinese Journalism</a></li>-->
# <li><a href="https://jour.hkbu.edu.hk/programmes/journalism">								Journalism
# 								</a></li>
# <li><a href="http://bu-dmc.hkbu.edu.hk/" target="_blank">Data and Media Communication</a></li>
# </ul>
# <li><a href="http://comd.hkbu.edu.hk/masters/en/maijs.html" target="_blank">Postgraduate Studies</a></li>
# </ul>
# </li>
# <li><a href="https://jour.hkbu.edu.hk/research">Research</a></li>
# <li><a href="https://jour.hkbu.edu.hk/faculty">Faculty</a>
# </li>
# <li><a href="https://jour.hkbu.edu.hk/students-and-alumni">Students &amp; Alumni</a>
# </li>
# <li><a href="https://jour.hkbu.edu.hk/news-events">News &amp; Events</a>
# </li>
# <li><a href="https://jour.hkbu.edu.hk/highlights">Highlights</a>
# </li>
# <li class="dropdown">
# <a class="dropdown-toggle" data-target="drop-programmes" data-toggle="dropdown" href="#drop-programmes" type="button">
# 						Community<b class="caret"></b>
# </a>
# <ul class="dropdown-menu" id="drop-community">
# <li><a href="http://ijs.hkbu.edu.hk" target="_blank">Institute For Journalism &amp; Society</a></li>
# <li><a href="https://dnnsociety.org/" target="_blank">Data &amp; News Society</a></li>
# </ul>
# </li>
# <li><a href="https://jour.hkbu.edu.hk/contact-us">Contact Us</a></li>
# </ul>
# <ul class="nav navbar-nav navbar-right">
# <div class="social">
# <div id="languages">
# <div class="wpml-ls-statics-shortcode_actions wpml-ls wpml-ls-legacy-list-horizontal">
# <ul><li class="wpml-ls-slot-shortcode_actions wpml-ls-item wpml-ls-item-en wpml-ls-current-language wpml-ls-first-item wpml-ls-item-legacy-list-horizontal">
# <a class="wpml-ls-link" href="https://jour.hkbu.edu.hk/faculty/"><span class="wpml-ls-native">EN</span></a>
# </li><li class="wpml-ls-slot-shortcode_actions wpml-ls-item wpml-ls-item-zh-hant wpml-ls-item-legacy-list-horizontal">
# <a class="wpml-ls-link" href="https://jour.hkbu.edu.hk/zh-hant/faculty/"><span class="wpml-ls-display">繁</span></a>
# </li><li class="wpml-ls-slot-shortcode_actions wpml-ls-item wpml-ls-item-zh-hans wpml-ls-last-item wpml-ls-item-legacy-list-horizontal">
# <a class="wpml-ls-link" href="https://jour.hkbu.edu.hk/zh-hans/faculty/"><span class="wpml-ls-display">简</span></a>
# </li></ul>
# </div></div>
# <div class="hidden-xs" id="search"><i class="fa fa-search" data-placement="bottom" data-toggle="tooltip" title="Site Search"></i></div>
# <a href="https://jour.hkbu.edu.hk/searching">
# <div class="visible-xs" id="mobile-search"><i class="fa fa-search"></i></div>
# </a>
# <ul class="social-share fa-lg">
# <li><a href="https://www.facebook.com/hkbujournalism/" target="_blank"><i class="fa fa-facebook" data-placement="bottom" data-toggle="tooltip" title="Facebook"></i></a>
# </li>
# <li><a href="https://www.youtube.com/hkbujournalism" target="_blank"><i class="fa fa-youtube-play" data-placement="bottom" data-toggle="tooltip" title="YouTube"></i></a>
# </li>
# <li><a href="https://www.instagram.com/HKBU_Journalism/" target="_blank"><i class="fab fa-instagram" data-placement="bottom" data-toggle="tooltip" title="Instagram"></i></a>
# </li>
# <li><a href="https://jour.hkbu.edu.hk/contact-us"><i class="fas fa-phone" data-placement="bottom" data-toggle="tooltip" title="Contact Us"></i></a>
# </li>
# </ul>
# <div class="menu-bars">
# <button class="navbar-toggle03 hidden-xs" type="button">
# <div class="icon-bar"></div>
# <div class="icon-bar"></div>
# <div class="icon-bar"></div>
# </button>
# </div>
# </div>
# </ul>
# </div>
# </div>
# </nav>

# %%
# Extract links / urls
# Links in html is usually coded as <a href="url">
# where the link is url

print(soup.find('a')) # find the first link

#Internal to the webpage link: <a href="#top">
#Internal to the website link: <a href="/alumni.html">
#External link: <a href="http://www.google.com">
# Out:
# <a class="scrollToTop" href="#">
# <div class="btn-top">TOP</div>
# </a>

# %%
soup.find('a').get('href')
# to get the link from href attribute
# Out:
# '#'

# %%
print(soup.find_all('a')) # find all the links - although we may not want to do this
# Out:
# [<a class="scrollToTop" href="#">
# <div class="btn-top">TOP</div>
# </a>, <a class="navbar-brand bu_logo" href="https://www.hkbu.edu.hk/eng/main/index.jsp" target="_blank">
# <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/hkbu.png"/>
# </a>, <a class="navbar-brand bu_logo_mobile" href="https://www.hkbu.edu.hk/eng/main/index.jsp" target="_blank">
# <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/logo_hkbu_mobile.png"/>
# </a>, <a class="navbar-brand comf_logo" href="https://www.comm.hkbu.edu.hk/comd-www/english/front/index.htm" target="_blank">
# <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/comm.png"/>
# </a>, <a class="navbar-brand comf_logo_mobile" href="https://www.comm.hkbu.edu.hk/comd-www/english/front/index.htm" target="_blank">
# <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/COMF_2021-white_small_short.png"/>
# </a>, <a class="navbar-brand jour_logo" href="https://jour.hkbu.edu.hk">
# <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/logo_hkbu-journalism_small.png"/>
# </a>, <a class="navbar-brand jour_logo_mobile" href="https://jour.hkbu.edu.hk">
# <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/logo_hkbu-journalism_small_short.png"/>
# </a>, <a href="https://jour.hkbu.edu.hk">Home</a>, <a href="https://jour.hkbu.edu.hk/about-us">About</a>, <a class="dropdown-toggle" data-target="drop-programmes" data-toggle="dropdown" href="#drop-programmes" type="button">
# 																Study Path
# 															<b class="caret"></b>
# </a>, <a href="https://jour.hkbu.edu.hk/programmes/programme-structure">
# 																			Programme Structure
# 																		</a>, <a href="https://jour.hkbu.edu.hk/programmes/journalism">								Journalism
# 								</a>, <a href="http://bu-dmc.hkbu.edu.hk/" target="_blank">Data and Media Communication</a>, <a href="http://comd.hkbu.edu.hk/masters/en/maijs.html" target="_blank">Postgraduate Studies</a>, <a href="https://jour.hkbu.edu.hk/research">Research</a>, <a href="https://jour.hkbu.edu.hk/faculty">Faculty</a>, <a href="https://jour.hkbu.edu.hk/students-and-alumni">Students &amp; Alumni</a>, <a href="https://jour.hkbu.edu.hk/news-events">News &amp; Events</a>, <a href="https://jour.hkbu.edu.hk/highlights">Highlights</a>, <a class="dropdown-toggle" data-target="drop-programmes" data-toggle="dropdown" href="#drop-programmes" type="button">
# 						Community<b class="caret"></b>
# </a>, <a href="http://ijs.hkbu.edu.hk" target="_blank">Institute For Journalism &amp; Society</a>, <a href="https://dnnsociety.org/" target="_blank">Data &amp; News Society</a>, <a href="https://jour.hkbu.edu.hk/contact-us">Contact Us</a>, <a class="wpml-ls-link" href="https://jour.hkbu.edu.hk/faculty/"><span class="wpml-ls-native">EN</span></a>, <a class="wpml-ls-link" href="https://jour.hkbu.edu.hk/zh-hant/faculty/"><span class="wpml-ls-display">繁</span></a>, <a class="wpml-ls-link" href="https://jour.hkbu.edu.hk/zh-hans/faculty/"><span class="wpml-ls-display">简</span></a>, <a href="https://jour.hkbu.edu.hk/searching">
# <div class="visible-xs" id="mobile-search"><i class="fa fa-search"></i></div>
# </a>, <a href="https://www.facebook.com/hkbujournalism/" target="_blank"><i class="fa fa-facebook" data-placement="bottom" data-toggle="tooltip" title="Facebook"></i></a>, <a href="https://www.youtube.com/hkbujournalism" target="_blank"><i class="fa fa-youtube-play" data-placement="bottom" data-toggle="tooltip" title="YouTube"></i></a>, <a href="https://www.instagram.com/HKBU_Journalism/" target="_blank"><i class="fab fa-instagram" data-placement="bottom" data-toggle="tooltip" title="Instagram"></i></a>, <a href="https://jour.hkbu.edu.hk/contact-us"><i class="fas fa-phone" data-placement="bottom" data-toggle="tooltip" title="Contact Us"></i></a>, <a href="https://jour.hkbu.edu.hk">Home</a>, <a href="https://jour.hkbu.edu.hk/about-us">About</a>, <a class="dropdown-toggle" data-target="drop-programmes" data-toggle="dropdown" href="#drop-programmes" type="button">
#
# 														Study Path
#
# 						<b class="caret"></b>
# </a>, <a href="https://jour.hkbu.edu.hk/programmes/programme-structure">
# 																			Programme Structure
# 																		</a>, <a href="https://jour.hkbu.edu.hk/programmes/journalism">								Journalism
# 								</a>, <a href="http://bu-dmc.hkbu.edu.hk/" target="_blank">Data and Media Communication</a>, <a href="http://comd.hkbu.edu.hk/masters/en/maijs.html" target="_blank">Postgraduate Studies</a>, <a href="https://jour.hkbu.edu.hk/students-and-alumni/practicum">Practicum</a>, <a href="https://jour.hkbu.edu.hk/research">Research</a>, <a href="https://jour.hkbu.edu.hk/faculty">Faculty</a>, <a href="https://jour.hkbu.edu.hk/students-and-alumni">Students &amp; Alumni</a>, <a href="https://jour.hkbu.edu.hk/news-events">News &amp; Events</a>, <a href="https://jour.hkbu.edu.hk/highlights">Highlights</a>, <a class="dropdown-toggle" data-target="drop-programmes" data-toggle="dropdown" href="#drop-programmes" type="button">
# 						Community<b class="caret"></b>
# </a>, <a href="http://ijs.hkbu.edu.hk" target="_blank">Institute For Journalism &amp; Society</a>, <a href="https://dnnsociety.org/" target="_blank">Data &amp; News Society</a>, <a href="#faculty-members">
# <div class="icon-members">Faculty Members</div>
# </a>, <a href="#pt-colleagues">
# <div class="icon-ptc">Part-Time Colleagues</div>
# </a>, <a href="#visiting-scholars" style="display:none">
# <div class="icon-vs">Visiting Scholars</div>
# </a>, <a href="#supporting-staff">
# <div class="icon-support-staff">Supporting Staff</div>
# </a>, <a href="https://comd.hkbu.edu.hk/masters/en/maijs.html#section4">
# <div class="icon-vs">
# 													MAIJS Course Instructors
# 											</div>
# </a>, <a href="https://jour.hkbu.edu.hk/faculty-member/raymond-li/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="Mr. Raymond Li" class="img-responsive wp-post-image" height="400" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/03/ppl_ray-li.jpg" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Prof. Raymond Li                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor of Practice<br/>
# Department Head</p>
# </h5>
# <div class="visible-lg">
# <p>A veteran journalist working at the BBC for over 24 years. Mr. Li was also the first native Chinese to be appointed the Head of Chinese at the BBC.</p>
# </div>
# </div>
# </div>
# </div>
# </a>, <a href="https://jour.hkbu.edu.hk/faculty-member/luwei-rose-luqiu/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="Dr. Luwei Rose Luqiu" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-120x120.jpg 120w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose.jpg 600w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. Luwei Rose Luqiu                                    </h4>
# <h5 class="hidden-xs">
# <p>Associate Professor<br/>
# Associate Head</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Luqiu had been a television journalist for 20 years. She has covered many major international events ranging from the wars and also reported on Chinese political news and interviewed several Chinese leaders.</p>
# </div>
# </div>
# </div>
# </div>
# </a>, <a href="https://jour.hkbu.edu.hk/faculty-member/prof-chan-king-cheung/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/03/Screenshot-2022-03-08-at-8.15.03-PM-400x400.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/03/Screenshot-2022-03-08-at-8.15.03-PM-400x400.png 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/03/Screenshot-2022-03-08-at-8.15.03-PM-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/03/Screenshot-2022-03-08-at-8.15.03-PM-120x120.png 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         PROF. CHAN King Cheung                                    </h4>
# <h5 class="hidden-xs">
# <p>Raymond R. Wong Endowed Professor in Media Ethics<br/>
# Professor of Practice</p>
# </h5>
# <div class="visible-lg">
# <p>A veteran journalist with more than 30 years of experience, Professor CHAN King Cheung received his Bachelor degree in Arts, Master degree in Communication and MBA degree from the Chinese University of Hong Kong. He was also a Fellow in Media Management of the Poynter Institute for Media Studies in the United States.</p>
# </div>
# </div>
# </div>
# </div>
# </a>, <a href="https://jour.hkbu.edu.hk/faculty-member/steve-guo/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="PROF. STEVE GUO" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_steve-guo.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_steve-guo.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_steve-guo-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_steve-guo-300x300.jpg 300w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Prof. Steve Guo                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor<br/>
# Interim Dean, School of Communication</p>
# </h5>
# <div class="visible-lg">
# <p>Prof. Guo has spent his career in journalism and academia, including working at China Daily and researching news production and its social impact. He has been with university for more than 20 years.</p>
# </div>
# </div>
# </div>
# </div>
# </a>, <a href="https://jour.hkbu.edu.hk/faculty-member/cherian-george/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/Cherian-George-2018-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/Cherian-George-2018-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/Cherian-George-2018-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/Cherian-George-2018-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Prof. Cherian George                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Professor George has spent his career in journalism practice, education, research and advocacy, including working at the Straits Times, editing journals and founding a newspaper for children.</p>
# </div>
# </div>
# </div>
# </div>
# </a>, <a href="https://jour.hkbu.edu.hk/faculty-member/daya-thussu/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2019/07/Professor-Daya-Thussu-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2019/07/Professor-Daya-Thussu-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2019/07/Professor-Daya-Thussu-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2019/07/Professor-Daya-Thussu-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Prof. Daya Thussu                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Daya Thussu is Professor of International Communication. He was Visiting Professor and inaugural Disney Chair in Global Media at Schwarzman College, Tsinghua University in Beijing. </p>
# </div>
# </div>
# </div>
# </div>
# </a>, <a href="https://jour.hkbu.edu.hk/faculty-member/prof-kennth-paul-tan/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-120x120.jpg 120w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan.jpg 480w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Prof. Kenneth Paul TAN                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Prof. Tan is a tenured Professor at Hong Kong Baptist University, which hired him under its Talent100 initiative in February 2021.</p>
# </div>
# </div>
# </div>
# </div>
# </a>, <a href="https://jour.hkbu.edu.hk/faculty-member/wang-xiangwei/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="320" sizes="(max-width: 320px) 100vw, 320px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei.png 320w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei-300x300.png 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei-120x120.png 120w" width="320"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Mr. Wang Xiangwei                                    </h4>
# <h5 class="hidden-xs">
# <p>Mr. Wang Xiangwei<br/>
# Associate Professor of Practice</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>, <a href="https://jour.hkbu.edu.hk/faculty-member/robin-ewing/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="MS. EWING ROBIN" class="img-responsive wp-post-image" height="305" sizes="(max-width: 305px) 100vw, 305px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/08/ppl_robin-ewing.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/08/ppl_robin-ewing.jpg 305w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/08/ppl_robin-ewing-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/08/ppl_robin-ewing-300x300.jpg 300w" width="305"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Ms. Robin Ewing                                    </h4>
# <h5 class="hidden-xs">
# <p>Senior Lecturer<br/>
# Director of International Journalism Concentration, BComm (Hons.) in Journalism</p>
# </h5>
# <div class="visible-lg">
# <p>Ms. Ewing has worked as a journalist and educator in Asia for most of the last 18 years with a focus on feature writing, narrative nonfiction and digital journalism.</p>
# </div>
# </div>
# </div>
# </div>
# </a>, <a href="https://jour.hkbu.edu.hk/faculty-member/dr-brian-so/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-400x400.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-400x400.png 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-300x300.png 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-120x120.png 120w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM.png 684w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         DR. BRIAN SO                                    </h4>
# <h5 class="hidden-xs">
# <p>Associate Professor of Practice<br/>
# Coordinator of Financial Journalism Stream, Undergraduate Studies</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>, <a href="https://jour.hkbu.edu.hk/faculty-member/mr-pun-wai-lam/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Pun-Wai-Lam-Profile-Picture--400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Pun-Wai-Lam-Profile-Picture--400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Pun-Wai-Lam-Profile-Picture--150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Pun-Wai-Lam-Profile-Picture--120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Mr. Pun Wai Lam                                    </h4>
# <h5 class="hidden-xs">
# <p>Associate Professor of Practice</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>, <a href="https://jour.hkbu.edu.hk/faculty-member/dr-bess-wang-yue/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/02/Bess-Wang-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/02/Bess-Wang-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/02/Bess-Wang-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/02/Bess-Wang-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. Bess WANG Yue                                    </h4>
# <h5 class="hidden-xs">
# <p>Senior lecturer<br/>
# Programme Director of Data and Media Communication Concentration (DMC)<br/>
# Associate director of HKBU Fact Check</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>, <a href="https://jour.hkbu.edu.hk/faculty-member/xiaoyi-fu/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-768x768.jpg 768w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-120x120.jpg 120w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo.jpg 950w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. Xiaoyi Fu                                    </h4>
# <h5 class="hidden-xs">
# <p>Lecturer I</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Fu holds a Ph.D. degree in Computer Science from Hong Kong Baptist University. She works in the fields of databases, location-based services, geo-social computing and geo-spatial recommendation. </p>
# </div>
# </div>
# </div>
# </div>
# </a>, <a href="https://jour.hkbu.edu.hk/faculty-member/janet-lo/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="Dr. Janet Lo" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. Janet Lo                                    </h4>
# <h5 class="hidden-xs">
# <p>Assistant Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Lo has published in a number of peer-reviewed journals, and received top research paper awards in international conferences.</p>
# </div>
# </div>
# </div>
# </div>
# </a>, <a href="https://jour.hkbu.edu.hk/faculty-member/dr-wang-dan/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="353" sizes="(max-width: 353px) 100vw, 353px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan.png 353w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan-300x300.png 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan-120x120.png 120w" width="353"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. WANG DAN (Angela)                                    </h4>
# <h5 class="hidden-xs">
# <p>Research Assistant Professor<br/>
# Programme Director, MSocSc in Media Management</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Wang’s doctoral dissertation was about how a Communist Party newspaper organisation responded to the impact of digital media. Her main research interest lies in reconciling macro political economy with micro-sociological details</p>
# </div>
# </div>
# </div>
# </div>
# </a>, <a href="https://jour.hkbu.edu.hk/faculty-member/dr-yu-wenting/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/YuWenting-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/YuWenting-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/YuWenting-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/YuWenting-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. YU Wenting                                    </h4>
# <h5 class="hidden-xs">
# <p>Research Assistant Professor</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>, <a href="https://jour.hkbu.edu.hk/faculty-member/nick-zhang/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-768x768.jpg 768w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-1024x1024.jpg 1024w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. Nick Yin ZHANG                                    </h4>
# <h5 class="hidden-xs">
# <p>Assistant Professor<br/>
# Programme Director of Bachelor of Arts, Science and Technology (Hons) in Individualised Major</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Zhang is an interdisciplinary researcher of social science, humanities, and computer science. His research focuses on CMC, social networks, big data, and quality of life.</p>
# </div>
# </div>
# </div>
# </div>
# </a>, <a href="https://jour.hkbu.edu.hk/faculty-member/dr-sheng-zou/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400.png 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400-300x300.png 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400-120x120.png 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         DR. SHENG ZOU                                    </h4>
# <h5 class="hidden-xs">
# <p>Assistant Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Sheng Zou is an interdisciplinary media scholar whose research interests span such areas as critical theory, political aesthetics, digital media and society, cultural industries, and global communication. </p>
# </div>
# </div>
# </div>
# </div>
# </a>, <a href="https://jour.hkbu.edu.hk/faculty-member/bonnie-chiu/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="MS. BONNIE CHIU" class="img-responsive wp-post-image" height="400" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/03/ppl_bonnie-chiu.jpg" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Ms. CHIU Lai Yu Bonnie                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Teaching Fellow</p>
# </h5>
# <div class="visible-lg">
# <p>Ms. Chiu has extensive experience in broadcast journalism, including at RTHK, Cable TV and TVB, as well as a being a solicitor admitted in the High Court of Hong Kong.</p>
# </div>
# </div>
# </div>
# </div>
# </a>, <a href="https://jour.hkbu.edu.hk/faculty-member/clemence-poon/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="Mr. Clemence Poon" class="img-responsive wp-post-image" height="400" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/03/ppl_clemence.jpg" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Mr. Clemence Poon                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Lecturer</p>
# </h5>
# <div class="visible-lg">
# <p>Mr. Poon started off as a financial journalist and moved into financial analysis career, with more than 20 years’ experience in management accounting, financial analysis, business planning and investment appraisal.</p>
# </div>
# </div>
# </div>
# </div>
# </a>, <a href="https://jour.hkbu.edu.hk/faculty-member/jenny-lam/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="Ms. Jenny Lam" class="img-responsive wp-post-image" height="300" sizes="(max-width: 300px) 100vw, 300px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_jenny-lam.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_jenny-lam.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_jenny-lam-150x150.jpg 150w" width="300"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Ms. Jenny Lam                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Lecturer</p>
# </h5>
# <div class="visible-lg">
# <p>Ms. Lam has extensive experience in broadcast news journalism, including work at TVB and the BBC. She anchored the news for more than 20 years.</p>
# </div>
# </div>
# </div>
# </div>
# </a>, <a href="https://jour.hkbu.edu.hk/faculty-member/ms-lam-wing-yan/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/01/Lam-Wing-Yan-1-400x400.jpeg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/01/Lam-Wing-Yan-1-400x400.jpeg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/01/Lam-Wing-Yan-1-150x150.jpeg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/01/Lam-Wing-Yan-1-120x120.jpeg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         MS. LAM WING YAN                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Lecturer</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>, <a href="https://jour.hkbu.edu.hk/faculty-member/alison-leung/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/08/IMG_8901.png" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         DR.  ALISON LEUNG                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Lecturer</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Leung has taught journalism at universities in Hong Kong. Before that she was a Senior Correspondent and Deputy Chief of Thomson Reuters’ Hong Kong Bureau.</p>
# </div>
# </div>
# </div>
# </div>
# </a>, <a href="mailto:bobowei@hkbu.edu.hk" title="bobowei@hkbu.edu.hk">bobowei@hkbu.edu.hk</a>, <a href="mailto:joeying@hkbu.edu.hk" title="joeying@hkbu.edu.hk">joeying@hkbu.edu.hk</a>, <a href="mailto:kccheng@hkbu.edu.hk" title="kccheng@hkbu.edu.hk">kccheng@hkbu.edu.hk</a>, <a href="https://www.hkbu.edu.hk/eng/about/privacy.jsp" style="color:#fff" target="_blank">Privacy Policy</a>, <a href="http://jour.hkbu.edu.hk/home/disclaimer/" style="color:#fff">Disclaimer</a>, <a href="https://jour.hkbu.edu.hk/contact-us" target="_blank">Contact Us<i class="fa fa-angle-right redirect"></i></a>, <a href="https://jour.hkbu.edu.hk/students-and-alumni/study-trips/">Study Trips<i class="fa fa-angle-right redirect"></i></a>, <a href="http://admissions.hkbu.edu.hk/en/hkdse.html" target="_blank">HKBU Admissions<i class="fa fa-angle-right redirect"></i></a>, <a href="https://www.youtube.com/embed/GhmzdbjrGuI?autoplay=1" target="_blank">Department Video<i class="fa fa-angle-right redirect"></i></a>, <a href="https://jour.hkbu.edu.hk/students-and-alumni/exchange-programmes/">Student Exchange<i class="fa fa-angle-right redirect"></i></a>, <a href="http://sa.hkbu.edu.hk/home/" target="_blank">Office of Student Affairs<i class="fa fa-angle-right redirect"></i></a>, <a href="https://jour.hkbu.edu.hk/faculty">Faculty<i class="fa fa-angle-right redirect"></i></a>, <a href="https://sa.hkbu.edu.hk/sfa/scholarships/scholarships-for-undergraduate-students/for-school-of-communication" target="_blank">Student Scholarships<i class="fa fa-angle-right redirect"></i></a>, <a href="https://jour.hkbu.edu.hk/students-and-alumni/achievements/">Student Achievements<i class="fa fa-angle-right redirect"></i></a>, <a href="https://jour.hkbu.edu.hk/practicum">Practicum<i class="fa fa-angle-right redirect"></i></a>]

# %%
links = soup.find_all('a')

# %%
# check the informaiton about URLs
links = soup.find_all('a')

for link in links:
    print("\nInfo about {}: ".format(link.text), \
    link.get('href'))
# Out:
# Info about
# TOP
# :  #
#
# Info about
#
# :  https://www.hkbu.edu.hk/eng/main/index.jsp
#
# Info about
#
# :  https://www.hkbu.edu.hk/eng/main/index.jsp
#
# Info about
#
# :  https://www.comm.hkbu.edu.hk/comd-www/english/front/index.htm
#
# Info about
#
# :  https://www.comm.hkbu.edu.hk/comd-www/english/front/index.htm
#
# Info about
#
# :  https://jour.hkbu.edu.hk
#
# Info about
#
# :  https://jour.hkbu.edu.hk
#
# Info about Home:  https://jour.hkbu.edu.hk
#
# Info about About:  https://jour.hkbu.edu.hk/about-us
#
# Info about
# 																Study Path
#
# :  #drop-programmes
#
# Info about
# 																			Programme Structure
# 																		:  https://jour.hkbu.edu.hk/programmes/programme-structure
#
# Info about 								Journalism
# 								:  https://jour.hkbu.edu.hk/programmes/journalism
#
# Info about Data and Media Communication:  http://bu-dmc.hkbu.edu.hk/
#
# Info about Postgraduate Studies:  http://comd.hkbu.edu.hk/masters/en/maijs.html
#
# Info about Research:  https://jour.hkbu.edu.hk/research
#
# Info about Faculty:  https://jour.hkbu.edu.hk/faculty
#
# Info about Students & Alumni:  https://jour.hkbu.edu.hk/students-and-alumni
#
# Info about News & Events:  https://jour.hkbu.edu.hk/news-events
#
# Info about Highlights:  https://jour.hkbu.edu.hk/highlights
#
# Info about
# 						Community
# :  #drop-programmes
#
# Info about Institute For Journalism & Society:  http://ijs.hkbu.edu.hk
#
# Info about Data & News Society:  https://dnnsociety.org/
#
# Info about Contact Us:  https://jour.hkbu.edu.hk/contact-us
#
# Info about EN:  https://jour.hkbu.edu.hk/faculty/
#
# Info about 繁:  https://jour.hkbu.edu.hk/zh-hant/faculty/
#
# Info about 简:  https://jour.hkbu.edu.hk/zh-hans/faculty/
#
# Info about
#
# :  https://jour.hkbu.edu.hk/searching
#
# Info about :  https://www.facebook.com/hkbujournalism/
#
# Info about :  https://www.youtube.com/hkbujournalism
#
# Info about :  https://www.instagram.com/HKBU_Journalism/
#
# Info about :  https://jour.hkbu.edu.hk/contact-us
#
# Info about Home:  https://jour.hkbu.edu.hk
#
# Info about About:  https://jour.hkbu.edu.hk/about-us
#
# Info about
#
# 														Study Path
#
#
# :  #drop-programmes
#
# Info about
# 																			Programme Structure
# 																		:  https://jour.hkbu.edu.hk/programmes/programme-structure
#
# Info about 								Journalism
# 								:  https://jour.hkbu.edu.hk/programmes/journalism
#
# Info about Data and Media Communication:  http://bu-dmc.hkbu.edu.hk/
#
# Info about Postgraduate Studies:  http://comd.hkbu.edu.hk/masters/en/maijs.html
#
# Info about Practicum:  https://jour.hkbu.edu.hk/students-and-alumni/practicum
#
# Info about Research:  https://jour.hkbu.edu.hk/research
#
# Info about Faculty:  https://jour.hkbu.edu.hk/faculty
#
# Info about Students & Alumni:  https://jour.hkbu.edu.hk/students-and-alumni
#
# Info about News & Events:  https://jour.hkbu.edu.hk/news-events
#
# Info about Highlights:  https://jour.hkbu.edu.hk/highlights
#
# Info about
# 						Community
# :  #drop-programmes
#
# Info about Institute For Journalism & Society:  http://ijs.hkbu.edu.hk
#
# Info about Data & News Society:  https://dnnsociety.org/
#
# Info about
# Faculty Members
# :  #faculty-members
#
# Info about
# Part-Time Colleagues
# :  #pt-colleagues
#
# Info about
# Visiting Scholars
# :  #visiting-scholars
#
# Info about
# Supporting Staff
# :  #supporting-staff
#
# Info about
#
# 													MAIJS Course Instructors
#
# :  https://comd.hkbu.edu.hk/masters/en/maijs.html#section4
#
# Info about
#
#
#
#
#                                         Prof. Raymond Li
#
# Professor of Practice
# Department Head
#
#
# A veteran journalist working at the BBC for over 24 years. Mr. Li was also the first native Chinese to be appointed the Head of Chinese at the BBC.
#
#
#
#
# :  https://jour.hkbu.edu.hk/faculty-member/raymond-li/
#
# Info about
#
#
#
#
#                                         Dr. Luwei Rose Luqiu
#
# Associate Professor
# Associate Head
#
#
# Dr. Luqiu had been a television journalist for 20 years. She has covered many major international events ranging from the wars and also reported on Chinese political news and interviewed several Chinese leaders.
#
#
#
#
# :  https://jour.hkbu.edu.hk/faculty-member/luwei-rose-luqiu/
#
# Info about
#
#
#
#
#                                         PROF. CHAN King Cheung
#
# Raymond R. Wong Endowed Professor in Media Ethics
# Professor of Practice
#
#
# A veteran journalist with more than 30 years of experience, Professor CHAN King Cheung received his Bachelor degree in Arts, Master degree in Communication and MBA degree from the Chinese University of Hong Kong. He was also a Fellow in Media Management of the Poynter Institute for Media Studies in the United States.
#
#
#
#
# :  https://jour.hkbu.edu.hk/faculty-member/prof-chan-king-cheung/
#
# Info about
#
#
#
#
#                                         Prof. Steve Guo
#
# Professor
# Interim Dean, School of Communication
#
#
# Prof. Guo has spent his career in journalism and academia, including working at China Daily and researching news production and its social impact. He has been with university for more than 20 years.
#
#
#
#
# :  https://jour.hkbu.edu.hk/faculty-member/steve-guo/
#
# Info about
#
#
#
#
#                                         Prof. Cherian George
#
# Professor
#
#
# Professor George has spent his career in journalism practice, education, research and advocacy, including working at the Straits Times, editing journals and founding a newspaper for children.
#
#
#
#
# :  https://jour.hkbu.edu.hk/faculty-member/cherian-george/
#
# Info about
#
#
#
#
#                                         Prof. Daya Thussu
#
# Professor
#
#
# Daya Thussu is Professor of International Communication. He was Visiting Professor and inaugural Disney Chair in Global Media at Schwarzman College, Tsinghua University in Beijing.
#
#
#
#
# :  https://jour.hkbu.edu.hk/faculty-member/daya-thussu/
#
# Info about
#
#
#
#
#                                         Prof. Kenneth Paul TAN
#
# Professor
#
#
# Prof. Tan is a tenured Professor at Hong Kong Baptist University, which hired him under its Talent100 initiative in February 2021.
#
#
#
#
# :  https://jour.hkbu.edu.hk/faculty-member/prof-kennth-paul-tan/
#
# Info about
#
#
#
#
#                                         Mr. Wang Xiangwei
#
# Mr. Wang Xiangwei
# Associate Professor of Practice
#
#
#
#
#
#
# :  https://jour.hkbu.edu.hk/faculty-member/wang-xiangwei/
#
# Info about
#
#
#
#
#                                         Ms. Robin Ewing
#
# Senior Lecturer
# Director of International Journalism Concentration, BComm (Hons.) in Journalism
#
#
# Ms. Ewing has worked as a journalist and educator in Asia for most of the last 18 years with a focus on feature writing, narrative nonfiction and digital journalism.
#
#
#
#
# :  https://jour.hkbu.edu.hk/faculty-member/robin-ewing/
#
# Info about
#
#
#
#
#                                         DR. BRIAN SO
#
# Associate Professor of Practice
# Coordinator of Financial Journalism Stream, Undergraduate Studies
#
#
#
#
#
#
# :  https://jour.hkbu.edu.hk/faculty-member/dr-brian-so/
#
# Info about
#
#
#
#
#                                         Mr. Pun Wai Lam
#
# Associate Professor of Practice
#
#
#
#
#
#
# :  https://jour.hkbu.edu.hk/faculty-member/mr-pun-wai-lam/
#
# Info about
#
#
#
#
#                                         Dr. Bess WANG Yue
#
# Senior lecturer
# Programme Director of Data and Media Communication Concentration (DMC)
# Associate director of HKBU Fact Check
#
#
#
#
#
#
# :  https://jour.hkbu.edu.hk/faculty-member/dr-bess-wang-yue/
#
# Info about
#
#
#
#
#                                         Dr. Xiaoyi Fu
#
# Lecturer I
#
#
# Dr. Fu holds a Ph.D. degree in Computer Science from Hong Kong Baptist University. She works in the fields of databases, location-based services, geo-social computing and geo-spatial recommendation.
#
#
#
#
# :  https://jour.hkbu.edu.hk/faculty-member/xiaoyi-fu/
#
# Info about
#
#
#
#
#                                         Dr. Janet Lo
#
# Assistant Professor
#
#
# Dr. Lo has published in a number of peer-reviewed journals, and received top research paper awards in international conferences.
#
#
#
#
# :  https://jour.hkbu.edu.hk/faculty-member/janet-lo/
#
# Info about
#
#
#
#
#                                         Dr. WANG DAN (Angela)
#
# Research Assistant Professor
# Programme Director, MSocSc in Media Management
#
#
# Dr. Wang’s doctoral dissertation was about how a Communist Party newspaper organisation responded to the impact of digital media. Her main research interest lies in reconciling macro political economy with micro-sociological details
#
#
#
#
# :  https://jour.hkbu.edu.hk/faculty-member/dr-wang-dan/
#
# Info about
#
#
#
#
#                                         Dr. YU Wenting
#
# Research Assistant Professor
#
#
#
#
#
#
# :  https://jour.hkbu.edu.hk/faculty-member/dr-yu-wenting/
#
# Info about
#
#
#
#
#                                         Dr. Nick Yin ZHANG
#
# Assistant Professor
# Programme Director of Bachelor of Arts, Science and Technology (Hons) in Individualised Major
#
#
# Dr. Zhang is an interdisciplinary researcher of social science, humanities, and computer science. His research focuses on CMC, social networks, big data, and quality of life.
#
#
#
#
# :  https://jour.hkbu.edu.hk/faculty-member/nick-zhang/
#
# Info about
#
#
#
#
#                                         DR. SHENG ZOU
#
# Assistant Professor
#
#
# Dr. Sheng Zou is an interdisciplinary media scholar whose research interests span such areas as critical theory, political aesthetics, digital media and society, cultural industries, and global communication.
#
#
#
#
# :  https://jour.hkbu.edu.hk/faculty-member/dr-sheng-zou/
#
# Info about
#
#
#
#
#                                         Ms. CHIU Lai Yu Bonnie
#
# Visiting Senior Teaching Fellow
#
#
# Ms. Chiu has extensive experience in broadcast journalism, including at RTHK, Cable TV and TVB, as well as a being a solicitor admitted in the High Court of Hong Kong.
#
#
#
#
# :  https://jour.hkbu.edu.hk/faculty-member/bonnie-chiu/
#
# Info about
#
#
#
#
#                                         Mr. Clemence Poon
#
# Visiting Senior Lecturer
#
#
# Mr. Poon started off as a financial journalist and moved into financial analysis career, with more than 20 years’ experience in management accounting, financial analysis, business planning and investment appraisal.
#
#
#
#
# :  https://jour.hkbu.edu.hk/faculty-member/clemence-poon/
#
# Info about
#
#
#
#
#                                         Ms. Jenny Lam
#
# Visiting Senior Lecturer
#
#
# Ms. Lam has extensive experience in broadcast news journalism, including work at TVB and the BBC. She anchored the news for more than 20 years.
#
#
#
#
# :  https://jour.hkbu.edu.hk/faculty-member/jenny-lam/
#
# Info about
#
#
#
#
#                                         MS. LAM WING YAN
#
# Visiting Senior Lecturer
#
#
#
#
#
#
# :  https://jour.hkbu.edu.hk/faculty-member/ms-lam-wing-yan/
#
# Info about
#
#
#
#
#                                         DR.  ALISON LEUNG
#
# Visiting Senior Lecturer
#
#
# Dr. Leung has taught journalism at universities in Hong Kong. Before that she was a Senior Correspondent and Deputy Chief of Thomson Reuters’ Hong Kong Bureau.
#
#
#
#
# :  https://jour.hkbu.edu.hk/faculty-member/alison-leung/
#
# Info about bobowei@hkbu.edu.hk:  mailto:bobowei@hkbu.edu.hk
#
# Info about joeying@hkbu.edu.hk:  mailto:joeying@hkbu.edu.hk
#
# Info about kccheng@hkbu.edu.hk:  mailto:kccheng@hkbu.edu.hk
#
# Info about Privacy Policy:  https://www.hkbu.edu.hk/eng/about/privacy.jsp
#
# Info about Disclaimer:  http://jour.hkbu.edu.hk/home/disclaimer/
#
# Info about Contact Us:  https://jour.hkbu.edu.hk/contact-us
#
# Info about Study Trips:  https://jour.hkbu.edu.hk/students-and-alumni/study-trips/
#
# Info about HKBU Admissions:  http://admissions.hkbu.edu.hk/en/hkdse.html
#
# Info about Department Video:  https://www.youtube.com/embed/GhmzdbjrGuI?autoplay=1
#
# Info about Student Exchange:  https://jour.hkbu.edu.hk/students-and-alumni/exchange-programmes/
#
# Info about Office of Student Affairs:  http://sa.hkbu.edu.hk/home/
#
# Info about Faculty:  https://jour.hkbu.edu.hk/faculty
#
# Info about Student Scholarships:  https://sa.hkbu.edu.hk/sfa/scholarships/scholarships-for-undergraduate-students/for-school-of-communication
#
# Info about Student Achievements:  https://jour.hkbu.edu.hk/students-and-alumni/achievements/
#
# Info about Practicum:  https://jour.hkbu.edu.hk/practicum

# %% [markdown]
# ### To locate the exact contents, we need an "Inspector"
#
# - ** Making your browser a development tool**
# - ** "inspect element" **

# %%
print(soup.find_all('div', attrs={'class': 'col-lg-3 col-xs-6 col-sm-4 col-md-3'}))
# Out:
# [<div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/raymond-li/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="Mr. Raymond Li" class="img-responsive wp-post-image" height="400" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/03/ppl_ray-li.jpg" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Prof. Raymond Li                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor of Practice<br/>
# Department Head</p>
# </h5>
# <div class="visible-lg">
# <p>A veteran journalist working at the BBC for over 24 years. Mr. Li was also the first native Chinese to be appointed the Head of Chinese at the BBC.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/luwei-rose-luqiu/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="Dr. Luwei Rose Luqiu" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-120x120.jpg 120w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose.jpg 600w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. Luwei Rose Luqiu                                    </h4>
# <h5 class="hidden-xs">
# <p>Associate Professor<br/>
# Associate Head</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Luqiu had been a television journalist for 20 years. She has covered many major international events ranging from the wars and also reported on Chinese political news and interviewed several Chinese leaders.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/prof-chan-king-cheung/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/03/Screenshot-2022-03-08-at-8.15.03-PM-400x400.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/03/Screenshot-2022-03-08-at-8.15.03-PM-400x400.png 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/03/Screenshot-2022-03-08-at-8.15.03-PM-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/03/Screenshot-2022-03-08-at-8.15.03-PM-120x120.png 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         PROF. CHAN King Cheung                                    </h4>
# <h5 class="hidden-xs">
# <p>Raymond R. Wong Endowed Professor in Media Ethics<br/>
# Professor of Practice</p>
# </h5>
# <div class="visible-lg">
# <p>A veteran journalist with more than 30 years of experience, Professor CHAN King Cheung received his Bachelor degree in Arts, Master degree in Communication and MBA degree from the Chinese University of Hong Kong. He was also a Fellow in Media Management of the Poynter Institute for Media Studies in the United States.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/steve-guo/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="PROF. STEVE GUO" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_steve-guo.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_steve-guo.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_steve-guo-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_steve-guo-300x300.jpg 300w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Prof. Steve Guo                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor<br/>
# Interim Dean, School of Communication</p>
# </h5>
# <div class="visible-lg">
# <p>Prof. Guo has spent his career in journalism and academia, including working at China Daily and researching news production and its social impact. He has been with university for more than 20 years.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/cherian-george/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/Cherian-George-2018-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/Cherian-George-2018-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/Cherian-George-2018-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/Cherian-George-2018-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Prof. Cherian George                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Professor George has spent his career in journalism practice, education, research and advocacy, including working at the Straits Times, editing journals and founding a newspaper for children.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/daya-thussu/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2019/07/Professor-Daya-Thussu-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2019/07/Professor-Daya-Thussu-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2019/07/Professor-Daya-Thussu-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2019/07/Professor-Daya-Thussu-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Prof. Daya Thussu                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Daya Thussu is Professor of International Communication. He was Visiting Professor and inaugural Disney Chair in Global Media at Schwarzman College, Tsinghua University in Beijing. </p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/prof-kennth-paul-tan/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-120x120.jpg 120w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan.jpg 480w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Prof. Kenneth Paul TAN                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Prof. Tan is a tenured Professor at Hong Kong Baptist University, which hired him under its Talent100 initiative in February 2021.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/wang-xiangwei/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="320" sizes="(max-width: 320px) 100vw, 320px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei.png 320w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei-300x300.png 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei-120x120.png 120w" width="320"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Mr. Wang Xiangwei                                    </h4>
# <h5 class="hidden-xs">
# <p>Mr. Wang Xiangwei<br/>
# Associate Professor of Practice</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/robin-ewing/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="MS. EWING ROBIN" class="img-responsive wp-post-image" height="305" sizes="(max-width: 305px) 100vw, 305px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/08/ppl_robin-ewing.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/08/ppl_robin-ewing.jpg 305w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/08/ppl_robin-ewing-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/08/ppl_robin-ewing-300x300.jpg 300w" width="305"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Ms. Robin Ewing                                    </h4>
# <h5 class="hidden-xs">
# <p>Senior Lecturer<br/>
# Director of International Journalism Concentration, BComm (Hons.) in Journalism</p>
# </h5>
# <div class="visible-lg">
# <p>Ms. Ewing has worked as a journalist and educator in Asia for most of the last 18 years with a focus on feature writing, narrative nonfiction and digital journalism.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/dr-brian-so/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-400x400.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-400x400.png 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-300x300.png 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-120x120.png 120w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM.png 684w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         DR. BRIAN SO                                    </h4>
# <h5 class="hidden-xs">
# <p>Associate Professor of Practice<br/>
# Coordinator of Financial Journalism Stream, Undergraduate Studies</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/mr-pun-wai-lam/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Pun-Wai-Lam-Profile-Picture--400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Pun-Wai-Lam-Profile-Picture--400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Pun-Wai-Lam-Profile-Picture--150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Pun-Wai-Lam-Profile-Picture--120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Mr. Pun Wai Lam                                    </h4>
# <h5 class="hidden-xs">
# <p>Associate Professor of Practice</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/dr-bess-wang-yue/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/02/Bess-Wang-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/02/Bess-Wang-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/02/Bess-Wang-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/02/Bess-Wang-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. Bess WANG Yue                                    </h4>
# <h5 class="hidden-xs">
# <p>Senior lecturer<br/>
# Programme Director of Data and Media Communication Concentration (DMC)<br/>
# Associate director of HKBU Fact Check</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/xiaoyi-fu/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-768x768.jpg 768w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-120x120.jpg 120w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo.jpg 950w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. Xiaoyi Fu                                    </h4>
# <h5 class="hidden-xs">
# <p>Lecturer I</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Fu holds a Ph.D. degree in Computer Science from Hong Kong Baptist University. She works in the fields of databases, location-based services, geo-social computing and geo-spatial recommendation. </p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/janet-lo/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="Dr. Janet Lo" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. Janet Lo                                    </h4>
# <h5 class="hidden-xs">
# <p>Assistant Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Lo has published in a number of peer-reviewed journals, and received top research paper awards in international conferences.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/dr-wang-dan/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="353" sizes="(max-width: 353px) 100vw, 353px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan.png 353w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan-300x300.png 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan-120x120.png 120w" width="353"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. WANG DAN (Angela)                                    </h4>
# <h5 class="hidden-xs">
# <p>Research Assistant Professor<br/>
# Programme Director, MSocSc in Media Management</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Wang’s doctoral dissertation was about how a Communist Party newspaper organisation responded to the impact of digital media. Her main research interest lies in reconciling macro political economy with micro-sociological details</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/dr-yu-wenting/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/YuWenting-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/YuWenting-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/YuWenting-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/YuWenting-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. YU Wenting                                    </h4>
# <h5 class="hidden-xs">
# <p>Research Assistant Professor</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/nick-zhang/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-768x768.jpg 768w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-1024x1024.jpg 1024w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. Nick Yin ZHANG                                    </h4>
# <h5 class="hidden-xs">
# <p>Assistant Professor<br/>
# Programme Director of Bachelor of Arts, Science and Technology (Hons) in Individualised Major</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Zhang is an interdisciplinary researcher of social science, humanities, and computer science. His research focuses on CMC, social networks, big data, and quality of life.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/dr-sheng-zou/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400.png 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400-300x300.png 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400-120x120.png 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         DR. SHENG ZOU                                    </h4>
# <h5 class="hidden-xs">
# <p>Assistant Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Sheng Zou is an interdisciplinary media scholar whose research interests span such areas as critical theory, political aesthetics, digital media and society, cultural industries, and global communication. </p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/bonnie-chiu/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="MS. BONNIE CHIU" class="img-responsive wp-post-image" height="400" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/03/ppl_bonnie-chiu.jpg" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Ms. CHIU Lai Yu Bonnie                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Teaching Fellow</p>
# </h5>
# <div class="visible-lg">
# <p>Ms. Chiu has extensive experience in broadcast journalism, including at RTHK, Cable TV and TVB, as well as a being a solicitor admitted in the High Court of Hong Kong.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/clemence-poon/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="Mr. Clemence Poon" class="img-responsive wp-post-image" height="400" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/03/ppl_clemence.jpg" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Mr. Clemence Poon                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Lecturer</p>
# </h5>
# <div class="visible-lg">
# <p>Mr. Poon started off as a financial journalist and moved into financial analysis career, with more than 20 years’ experience in management accounting, financial analysis, business planning and investment appraisal.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/jenny-lam/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="Ms. Jenny Lam" class="img-responsive wp-post-image" height="300" sizes="(max-width: 300px) 100vw, 300px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_jenny-lam.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_jenny-lam.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_jenny-lam-150x150.jpg 150w" width="300"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Ms. Jenny Lam                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Lecturer</p>
# </h5>
# <div class="visible-lg">
# <p>Ms. Lam has extensive experience in broadcast news journalism, including work at TVB and the BBC. She anchored the news for more than 20 years.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/ms-lam-wing-yan/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/01/Lam-Wing-Yan-1-400x400.jpeg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/01/Lam-Wing-Yan-1-400x400.jpeg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/01/Lam-Wing-Yan-1-150x150.jpeg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/01/Lam-Wing-Yan-1-120x120.jpeg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         MS. LAM WING YAN                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Lecturer</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/alison-leung/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/08/IMG_8901.png" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         DR.  ALISON LEUNG                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Lecturer</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Leung has taught journalism at universities in Hong Kong. Before that she was a Senior Correspondent and Deputy Chief of Thomson Reuters’ Hong Kong Bureau.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>]

# %%
#print(soup.find_all('div', attrs={'class': 'col-lg-3 col-xs-6 col-sm-4 col-md-3'}))
print(soup.find_all('div', class_ = 'col-lg-3 col-xs-6 col-sm-4 col-md-3'))
# Out:
# [<div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/raymond-li/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="Mr. Raymond Li" class="img-responsive wp-post-image" height="400" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/03/ppl_ray-li.jpg" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Prof. Raymond Li                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor of Practice<br/>
# Department Head</p>
# </h5>
# <div class="visible-lg">
# <p>A veteran journalist working at the BBC for over 24 years. Mr. Li was also the first native Chinese to be appointed the Head of Chinese at the BBC.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/luwei-rose-luqiu/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="Dr. Luwei Rose Luqiu" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-120x120.jpg 120w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose.jpg 600w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. Luwei Rose Luqiu                                    </h4>
# <h5 class="hidden-xs">
# <p>Associate Professor<br/>
# Associate Head</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Luqiu had been a television journalist for 20 years. She has covered many major international events ranging from the wars and also reported on Chinese political news and interviewed several Chinese leaders.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/prof-chan-king-cheung/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/03/Screenshot-2022-03-08-at-8.15.03-PM-400x400.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/03/Screenshot-2022-03-08-at-8.15.03-PM-400x400.png 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/03/Screenshot-2022-03-08-at-8.15.03-PM-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/03/Screenshot-2022-03-08-at-8.15.03-PM-120x120.png 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         PROF. CHAN King Cheung                                    </h4>
# <h5 class="hidden-xs">
# <p>Raymond R. Wong Endowed Professor in Media Ethics<br/>
# Professor of Practice</p>
# </h5>
# <div class="visible-lg">
# <p>A veteran journalist with more than 30 years of experience, Professor CHAN King Cheung received his Bachelor degree in Arts, Master degree in Communication and MBA degree from the Chinese University of Hong Kong. He was also a Fellow in Media Management of the Poynter Institute for Media Studies in the United States.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/steve-guo/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="PROF. STEVE GUO" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_steve-guo.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_steve-guo.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_steve-guo-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_steve-guo-300x300.jpg 300w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Prof. Steve Guo                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor<br/>
# Interim Dean, School of Communication</p>
# </h5>
# <div class="visible-lg">
# <p>Prof. Guo has spent his career in journalism and academia, including working at China Daily and researching news production and its social impact. He has been with university for more than 20 years.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/cherian-george/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/Cherian-George-2018-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/Cherian-George-2018-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/Cherian-George-2018-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/Cherian-George-2018-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Prof. Cherian George                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Professor George has spent his career in journalism practice, education, research and advocacy, including working at the Straits Times, editing journals and founding a newspaper for children.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/daya-thussu/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2019/07/Professor-Daya-Thussu-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2019/07/Professor-Daya-Thussu-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2019/07/Professor-Daya-Thussu-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2019/07/Professor-Daya-Thussu-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Prof. Daya Thussu                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Daya Thussu is Professor of International Communication. He was Visiting Professor and inaugural Disney Chair in Global Media at Schwarzman College, Tsinghua University in Beijing. </p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/prof-kennth-paul-tan/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-120x120.jpg 120w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan.jpg 480w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Prof. Kenneth Paul TAN                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Prof. Tan is a tenured Professor at Hong Kong Baptist University, which hired him under its Talent100 initiative in February 2021.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/wang-xiangwei/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="320" sizes="(max-width: 320px) 100vw, 320px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei.png 320w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei-300x300.png 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/08/Wang-Xiangwei-120x120.png 120w" width="320"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Mr. Wang Xiangwei                                    </h4>
# <h5 class="hidden-xs">
# <p>Mr. Wang Xiangwei<br/>
# Associate Professor of Practice</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/robin-ewing/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="MS. EWING ROBIN" class="img-responsive wp-post-image" height="305" sizes="(max-width: 305px) 100vw, 305px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/08/ppl_robin-ewing.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/08/ppl_robin-ewing.jpg 305w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/08/ppl_robin-ewing-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/08/ppl_robin-ewing-300x300.jpg 300w" width="305"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Ms. Robin Ewing                                    </h4>
# <h5 class="hidden-xs">
# <p>Senior Lecturer<br/>
# Director of International Journalism Concentration, BComm (Hons.) in Journalism</p>
# </h5>
# <div class="visible-lg">
# <p>Ms. Ewing has worked as a journalist and educator in Asia for most of the last 18 years with a focus on feature writing, narrative nonfiction and digital journalism.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/dr-brian-so/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-400x400.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-400x400.png 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-300x300.png 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM-120x120.png 120w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/08/Screenshot-2021-08-31-at-3.34.11-PM.png 684w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         DR. BRIAN SO                                    </h4>
# <h5 class="hidden-xs">
# <p>Associate Professor of Practice<br/>
# Coordinator of Financial Journalism Stream, Undergraduate Studies</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/mr-pun-wai-lam/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Pun-Wai-Lam-Profile-Picture--400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Pun-Wai-Lam-Profile-Picture--400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Pun-Wai-Lam-Profile-Picture--150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Pun-Wai-Lam-Profile-Picture--120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Mr. Pun Wai Lam                                    </h4>
# <h5 class="hidden-xs">
# <p>Associate Professor of Practice</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/dr-bess-wang-yue/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/02/Bess-Wang-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/02/Bess-Wang-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/02/Bess-Wang-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/02/Bess-Wang-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. Bess WANG Yue                                    </h4>
# <h5 class="hidden-xs">
# <p>Senior lecturer<br/>
# Programme Director of Data and Media Communication Concentration (DMC)<br/>
# Associate director of HKBU Fact Check</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/xiaoyi-fu/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-768x768.jpg 768w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-120x120.jpg 120w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo.jpg 950w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. Xiaoyi Fu                                    </h4>
# <h5 class="hidden-xs">
# <p>Lecturer I</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Fu holds a Ph.D. degree in Computer Science from Hong Kong Baptist University. She works in the fields of databases, location-based services, geo-social computing and geo-spatial recommendation. </p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/janet-lo/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="Dr. Janet Lo" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. Janet Lo                                    </h4>
# <h5 class="hidden-xs">
# <p>Assistant Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Lo has published in a number of peer-reviewed journals, and received top research paper awards in international conferences.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/dr-wang-dan/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="353" sizes="(max-width: 353px) 100vw, 353px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan.png 353w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan-300x300.png 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Wang_Dan-120x120.png 120w" width="353"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. WANG DAN (Angela)                                    </h4>
# <h5 class="hidden-xs">
# <p>Research Assistant Professor<br/>
# Programme Director, MSocSc in Media Management</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Wang’s doctoral dissertation was about how a Communist Party newspaper organisation responded to the impact of digital media. Her main research interest lies in reconciling macro political economy with micro-sociological details</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/dr-yu-wenting/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/YuWenting-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/YuWenting-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/YuWenting-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/YuWenting-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. YU Wenting                                    </h4>
# <h5 class="hidden-xs">
# <p>Research Assistant Professor</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/nick-zhang/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-400x400.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-400x400.jpg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-150x150.jpg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-300x300.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-768x768.jpg 768w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-1024x1024.jpg 1024w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-120x120.jpg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Dr. Nick Yin ZHANG                                    </h4>
# <h5 class="hidden-xs">
# <p>Assistant Professor<br/>
# Programme Director of Bachelor of Arts, Science and Technology (Hons) in Individualised Major</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Zhang is an interdisciplinary researcher of social science, humanities, and computer science. His research focuses on CMC, social networks, big data, and quality of life.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/dr-sheng-zou/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400.png" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400.png 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400-150x150.png 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400-300x300.png 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2022/09/sheng-400x400-120x120.png 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         DR. SHENG ZOU                                    </h4>
# <h5 class="hidden-xs">
# <p>Assistant Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Sheng Zou is an interdisciplinary media scholar whose research interests span such areas as critical theory, political aesthetics, digital media and society, cultural industries, and global communication. </p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/bonnie-chiu/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="MS. BONNIE CHIU" class="img-responsive wp-post-image" height="400" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/03/ppl_bonnie-chiu.jpg" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Ms. CHIU Lai Yu Bonnie                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Teaching Fellow</p>
# </h5>
# <div class="visible-lg">
# <p>Ms. Chiu has extensive experience in broadcast journalism, including at RTHK, Cable TV and TVB, as well as a being a solicitor admitted in the High Court of Hong Kong.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/clemence-poon/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="Mr. Clemence Poon" class="img-responsive wp-post-image" height="400" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/03/ppl_clemence.jpg" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Mr. Clemence Poon                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Lecturer</p>
# </h5>
# <div class="visible-lg">
# <p>Mr. Poon started off as a financial journalist and moved into financial analysis career, with more than 20 years’ experience in management accounting, financial analysis, business planning and investment appraisal.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/jenny-lam/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="Ms. Jenny Lam" class="img-responsive wp-post-image" height="300" sizes="(max-width: 300px) 100vw, 300px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_jenny-lam.jpg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_jenny-lam.jpg 300w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_jenny-lam-150x150.jpg 150w" width="300"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         Ms. Jenny Lam                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Lecturer</p>
# </h5>
# <div class="visible-lg">
# <p>Ms. Lam has extensive experience in broadcast news journalism, including work at TVB and the BBC. She anchored the news for more than 20 years.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/ms-lam-wing-yan/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/01/Lam-Wing-Yan-1-400x400.jpeg" srcset="https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/01/Lam-Wing-Yan-1-400x400.jpeg 400w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/01/Lam-Wing-Yan-1-150x150.jpeg 150w, https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/01/Lam-Wing-Yan-1-120x120.jpeg 120w" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         MS. LAM WING YAN                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Lecturer</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>, <div class="col-lg-3 col-xs-6 col-sm-4 col-md-3">
# <a href="https://jour.hkbu.edu.hk/faculty-member/alison-leung/">
# <div class="faculty-staff-wrap wow fadeIn animated" data-wow-delay="300ms" data-wow-duration="500ms">
# <div class="featured-thumbnail"><img alt="" class="img-responsive wp-post-image" height="400" src="https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/08/IMG_8901.png" width="400"/></div> <div class="overlay">
# <div class="staff-inner">
# <h4>
#                                         DR.  ALISON LEUNG                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Lecturer</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Leung has taught journalism at universities in Hong Kong. Before that she was a Senior Correspondent and Deputy Chief of Thomson Reuters’ Hong Kong Bureau.</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>]

# %%
div_faculty = soup.find_all('div', class_ = 'col-lg-3 col-xs-6 col-sm-4 col-md-3')

# %%
print(type(div_faculty))
# Out:
# <class 'bs4.element.ResultSet'>

# %%
for link in div_faculty:
    print(link.find('a').attrs['href'])

# how to avoid errors?
# Out:
# https://jour.hkbu.edu.hk/faculty-member/raymond-li/
# https://jour.hkbu.edu.hk/faculty-member/luwei-rose-luqiu/
# https://jour.hkbu.edu.hk/faculty-member/prof-chan-king-cheung/
# https://jour.hkbu.edu.hk/faculty-member/steve-guo/
# https://jour.hkbu.edu.hk/faculty-member/cherian-george/
# https://jour.hkbu.edu.hk/faculty-member/daya-thussu/
# https://jour.hkbu.edu.hk/faculty-member/prof-kennth-paul-tan/
# https://jour.hkbu.edu.hk/faculty-member/wang-xiangwei/
# https://jour.hkbu.edu.hk/faculty-member/robin-ewing/
# https://jour.hkbu.edu.hk/faculty-member/dr-brian-so/
# https://jour.hkbu.edu.hk/faculty-member/mr-pun-wai-lam/
# https://jour.hkbu.edu.hk/faculty-member/dr-bess-wang-yue/
# https://jour.hkbu.edu.hk/faculty-member/xiaoyi-fu/
# https://jour.hkbu.edu.hk/faculty-member/janet-lo/
# https://jour.hkbu.edu.hk/faculty-member/dr-wang-dan/
# https://jour.hkbu.edu.hk/faculty-member/dr-yu-wenting/
# https://jour.hkbu.edu.hk/faculty-member/nick-zhang/
# https://jour.hkbu.edu.hk/faculty-member/dr-sheng-zou/
# https://jour.hkbu.edu.hk/faculty-member/bonnie-chiu/
# https://jour.hkbu.edu.hk/faculty-member/clemence-poon/
# https://jour.hkbu.edu.hk/faculty-member/jenny-lam/
# https://jour.hkbu.edu.hk/faculty-member/ms-lam-wing-yan/
# https://jour.hkbu.edu.hk/faculty-member/alison-leung/

# %%
try:
    for link in div_faculty:
        a = link.find('a').get('href')
        print(a)
except:
    #print("error here")
    pass
# Out:
# https://jour.hkbu.edu.hk/faculty-member/raymond-li/
# https://jour.hkbu.edu.hk/faculty-member/luwei-rose-luqiu/
# https://jour.hkbu.edu.hk/faculty-member/prof-chan-king-cheung/
# https://jour.hkbu.edu.hk/faculty-member/steve-guo/
# https://jour.hkbu.edu.hk/faculty-member/cherian-george/
# https://jour.hkbu.edu.hk/faculty-member/daya-thussu/
# https://jour.hkbu.edu.hk/faculty-member/prof-kennth-paul-tan/
# https://jour.hkbu.edu.hk/faculty-member/wang-xiangwei/
# https://jour.hkbu.edu.hk/faculty-member/robin-ewing/
# https://jour.hkbu.edu.hk/faculty-member/dr-brian-so/
# https://jour.hkbu.edu.hk/faculty-member/mr-pun-wai-lam/
# https://jour.hkbu.edu.hk/faculty-member/dr-bess-wang-yue/
# https://jour.hkbu.edu.hk/faculty-member/xiaoyi-fu/
# https://jour.hkbu.edu.hk/faculty-member/janet-lo/
# https://jour.hkbu.edu.hk/faculty-member/dr-wang-dan/
# https://jour.hkbu.edu.hk/faculty-member/dr-yu-wenting/
# https://jour.hkbu.edu.hk/faculty-member/nick-zhang/
# https://jour.hkbu.edu.hk/faculty-member/dr-sheng-zou/
# https://jour.hkbu.edu.hk/faculty-member/bonnie-chiu/
# https://jour.hkbu.edu.hk/faculty-member/clemence-poon/
# https://jour.hkbu.edu.hk/faculty-member/jenny-lam/
# https://jour.hkbu.edu.hk/faculty-member/ms-lam-wing-yan/
# https://jour.hkbu.edu.hk/faculty-member/alison-leung/

# %%
# another way to find all the URLs of faculty members from the root page ("soup")

for link in soup.find_all('a'):
    a = link.get('href')
    if '/faculty-member/' in a:
        print(a)
# Out:
# https://jour.hkbu.edu.hk/faculty-member/raymond-li/
# https://jour.hkbu.edu.hk/faculty-member/luwei-rose-luqiu/
# https://jour.hkbu.edu.hk/faculty-member/prof-chan-king-cheung/
# https://jour.hkbu.edu.hk/faculty-member/steve-guo/
# https://jour.hkbu.edu.hk/faculty-member/cherian-george/
# https://jour.hkbu.edu.hk/faculty-member/daya-thussu/
# https://jour.hkbu.edu.hk/faculty-member/prof-kennth-paul-tan/
# https://jour.hkbu.edu.hk/faculty-member/wang-xiangwei/
# https://jour.hkbu.edu.hk/faculty-member/robin-ewing/
# https://jour.hkbu.edu.hk/faculty-member/dr-brian-so/
# https://jour.hkbu.edu.hk/faculty-member/mr-pun-wai-lam/
# https://jour.hkbu.edu.hk/faculty-member/dr-bess-wang-yue/
# https://jour.hkbu.edu.hk/faculty-member/xiaoyi-fu/
# https://jour.hkbu.edu.hk/faculty-member/janet-lo/
# https://jour.hkbu.edu.hk/faculty-member/dr-wang-dan/
# https://jour.hkbu.edu.hk/faculty-member/dr-yu-wenting/
# https://jour.hkbu.edu.hk/faculty-member/nick-zhang/
# https://jour.hkbu.edu.hk/faculty-member/dr-sheng-zou/
# https://jour.hkbu.edu.hk/faculty-member/bonnie-chiu/
# https://jour.hkbu.edu.hk/faculty-member/clemence-poon/
# https://jour.hkbu.edu.hk/faculty-member/jenny-lam/
# https://jour.hkbu.edu.hk/faculty-member/ms-lam-wing-yan/
# https://jour.hkbu.edu.hk/faculty-member/alison-leung/

# %% [markdown]
# ## More extraction

# %%
print( soup.find_all(class_ = 'staff-inner'))
# Out:
# [<div class="staff-inner">
# <h4>
#                                         Prof. Raymond Li                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor of Practice<br/>
# Department Head</p>
# </h5>
# <div class="visible-lg">
# <p>A veteran journalist working at the BBC for over 24 years. Mr. Li was also the first native Chinese to be appointed the Head of Chinese at the BBC.</p>
# </div>
# </div>, <div class="staff-inner">
# <h4>
#                                         Dr. Luwei Rose Luqiu                                    </h4>
# <h5 class="hidden-xs">
# <p>Associate Professor<br/>
# Associate Head</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Luqiu had been a television journalist for 20 years. She has covered many major international events ranging from the wars and also reported on Chinese political news and interviewed several Chinese leaders.</p>
# </div>
# </div>, <div class="staff-inner">
# <h4>
#                                         PROF. CHAN King Cheung                                    </h4>
# <h5 class="hidden-xs">
# <p>Raymond R. Wong Endowed Professor in Media Ethics<br/>
# Professor of Practice</p>
# </h5>
# <div class="visible-lg">
# <p>A veteran journalist with more than 30 years of experience, Professor CHAN King Cheung received his Bachelor degree in Arts, Master degree in Communication and MBA degree from the Chinese University of Hong Kong. He was also a Fellow in Media Management of the Poynter Institute for Media Studies in the United States.</p>
# </div>
# </div>, <div class="staff-inner">
# <h4>
#                                         Prof. Steve Guo                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor<br/>
# Interim Dean, School of Communication</p>
# </h5>
# <div class="visible-lg">
# <p>Prof. Guo has spent his career in journalism and academia, including working at China Daily and researching news production and its social impact. He has been with university for more than 20 years.</p>
# </div>
# </div>, <div class="staff-inner">
# <h4>
#                                         Prof. Cherian George                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Professor George has spent his career in journalism practice, education, research and advocacy, including working at the Straits Times, editing journals and founding a newspaper for children.</p>
# </div>
# </div>, <div class="staff-inner">
# <h4>
#                                         Prof. Daya Thussu                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Daya Thussu is Professor of International Communication. He was Visiting Professor and inaugural Disney Chair in Global Media at Schwarzman College, Tsinghua University in Beijing. </p>
# </div>
# </div>, <div class="staff-inner">
# <h4>
#                                         Prof. Kenneth Paul TAN                                    </h4>
# <h5 class="hidden-xs">
# <p>Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Prof. Tan is a tenured Professor at Hong Kong Baptist University, which hired him under its Talent100 initiative in February 2021.</p>
# </div>
# </div>, <div class="staff-inner">
# <h4>
#                                         Mr. Wang Xiangwei                                    </h4>
# <h5 class="hidden-xs">
# <p>Mr. Wang Xiangwei<br/>
# Associate Professor of Practice</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>, <div class="staff-inner">
# <h4>
#                                         Ms. Robin Ewing                                    </h4>
# <h5 class="hidden-xs">
# <p>Senior Lecturer<br/>
# Director of International Journalism Concentration, BComm (Hons.) in Journalism</p>
# </h5>
# <div class="visible-lg">
# <p>Ms. Ewing has worked as a journalist and educator in Asia for most of the last 18 years with a focus on feature writing, narrative nonfiction and digital journalism.</p>
# </div>
# </div>, <div class="staff-inner">
# <h4>
#                                         DR. BRIAN SO                                    </h4>
# <h5 class="hidden-xs">
# <p>Associate Professor of Practice<br/>
# Coordinator of Financial Journalism Stream, Undergraduate Studies</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>, <div class="staff-inner">
# <h4>
#                                         Mr. Pun Wai Lam                                    </h4>
# <h5 class="hidden-xs">
# <p>Associate Professor of Practice</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>, <div class="staff-inner">
# <h4>
#                                         Dr. Bess WANG Yue                                    </h4>
# <h5 class="hidden-xs">
# <p>Senior lecturer<br/>
# Programme Director of Data and Media Communication Concentration (DMC)<br/>
# Associate director of HKBU Fact Check</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>, <div class="staff-inner">
# <h4>
#                                         Dr. Xiaoyi Fu                                    </h4>
# <h5 class="hidden-xs">
# <p>Lecturer I</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Fu holds a Ph.D. degree in Computer Science from Hong Kong Baptist University. She works in the fields of databases, location-based services, geo-social computing and geo-spatial recommendation. </p>
# </div>
# </div>, <div class="staff-inner">
# <h4>
#                                         Dr. Janet Lo                                    </h4>
# <h5 class="hidden-xs">
# <p>Assistant Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Lo has published in a number of peer-reviewed journals, and received top research paper awards in international conferences.</p>
# </div>
# </div>, <div class="staff-inner">
# <h4>
#                                         Dr. WANG DAN (Angela)                                    </h4>
# <h5 class="hidden-xs">
# <p>Research Assistant Professor<br/>
# Programme Director, MSocSc in Media Management</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Wang’s doctoral dissertation was about how a Communist Party newspaper organisation responded to the impact of digital media. Her main research interest lies in reconciling macro political economy with micro-sociological details</p>
# </div>
# </div>, <div class="staff-inner">
# <h4>
#                                         Dr. YU Wenting                                    </h4>
# <h5 class="hidden-xs">
# <p>Research Assistant Professor</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>, <div class="staff-inner">
# <h4>
#                                         Dr. Nick Yin ZHANG                                    </h4>
# <h5 class="hidden-xs">
# <p>Assistant Professor<br/>
# Programme Director of Bachelor of Arts, Science and Technology (Hons) in Individualised Major</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Zhang is an interdisciplinary researcher of social science, humanities, and computer science. His research focuses on CMC, social networks, big data, and quality of life.</p>
# </div>
# </div>, <div class="staff-inner">
# <h4>
#                                         DR. SHENG ZOU                                    </h4>
# <h5 class="hidden-xs">
# <p>Assistant Professor</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Sheng Zou is an interdisciplinary media scholar whose research interests span such areas as critical theory, political aesthetics, digital media and society, cultural industries, and global communication. </p>
# </div>
# </div>, <div class="staff-inner">
# <h4>
#                                         Ms. CHIU Lai Yu Bonnie                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Teaching Fellow</p>
# </h5>
# <div class="visible-lg">
# <p>Ms. Chiu has extensive experience in broadcast journalism, including at RTHK, Cable TV and TVB, as well as a being a solicitor admitted in the High Court of Hong Kong.</p>
# </div>
# </div>, <div class="staff-inner">
# <h4>
#                                         Mr. Clemence Poon                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Lecturer</p>
# </h5>
# <div class="visible-lg">
# <p>Mr. Poon started off as a financial journalist and moved into financial analysis career, with more than 20 years’ experience in management accounting, financial analysis, business planning and investment appraisal.</p>
# </div>
# </div>, <div class="staff-inner">
# <h4>
#                                         Ms. Jenny Lam                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Lecturer</p>
# </h5>
# <div class="visible-lg">
# <p>Ms. Lam has extensive experience in broadcast news journalism, including work at TVB and the BBC. She anchored the news for more than 20 years.</p>
# </div>
# </div>, <div class="staff-inner">
# <h4>
#                                         MS. LAM WING YAN                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Lecturer</p>
# </h5>
# <div class="visible-lg">
# </div>
# </div>, <div class="staff-inner">
# <h4>
#                                         DR.  ALISON LEUNG                                    </h4>
# <h5 class="hidden-xs">
# <p>Visiting Senior Lecturer</p>
# </h5>
# <div class="visible-lg">
# <p>Dr. Leung has taught journalism at universities in Hong Kong. Before that she was a Senior Correspondent and Deputy Chief of Thomson Reuters’ Hong Kong Bureau.</p>
# </div>
# </div>]

# %%
div_staffinner = soup.find_all('div', class_ ='staff-inner')
# div_staffinner = soup.find_all(class_ = 'staff-inner')

try:
    for name_element in div_staffinner:
        name = name_element.find('h4').get_text().strip() #strip() remove the white spaces before and after the text
        print(name)
except:
    pass
# Out:
# Prof. Raymond Li
# Dr. Luwei Rose Luqiu
# PROF. CHAN King Cheung
# Prof. Steve Guo
# Prof. Cherian George
# Prof. Daya Thussu
# Prof. Kenneth Paul TAN
# Mr. Wang Xiangwei
# Ms. Robin Ewing
# DR. BRIAN SO
# Mr. Pun Wai Lam
# Dr. Bess WANG Yue
# Dr. Xiaoyi Fu
# Dr. Janet Lo
# Dr. WANG DAN (Angela)
# Dr. YU Wenting
# Dr. Nick Yin ZHANG
# DR. SHENG ZOU
# Ms. CHIU Lai Yu Bonnie
# Mr. Clemence Poon
# Ms. Jenny Lam
# MS. LAM WING YAN
# DR.  ALISON LEUNG

# %% [markdown]
# ## Scrape images
#
#  - **please proceed with caution and always check the terms of use!!**

# %%
# As we can see there are several images
# Images are displayed with the <img> tag in HTML

# open connection and create new soup

raw = requests.get('http://www.jour.hkbu.edu.hk/faculty/').content
soup = bs.BeautifulSoup(raw, features='lxml')

print(soup.find('img'))
# as we can see below the image urls
# are stored as the src inside the img tag
# Out:
# <img src="http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/hkbu.png"/>

# %%
# Parse all url to the images
img_urls = list() # create an empty list first, and put elements into it
for img in soup.find_all('img'):
    img_url = img.get('src')
    if '.jpeg' in img_url or '.jpg' in img_url:
        print(img_url)
        img_urls.append(img_url)
# Out:
# http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/bg_people.jpg
# http://jour.hkbu.edu.hk/home/wp-content/themes/journalism/images/bg_people2.jpg
# https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/03/ppl_ray-li.jpg
# https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/07/ppl_luwei-rose-400x400.jpg
# https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_steve-guo.jpg
# https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/Cherian-George-2018-400x400.jpg
# https://jour.hkbu.edu.hk/home/wp-content/uploads/2019/07/Professor-Daya-Thussu-400x400.jpg
# https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/02/Kenneth-Paul-Tan-400x400.jpg
# https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/08/ppl_robin-ewing.jpg
# https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Pun-Wai-Lam-Profile-Picture--400x400.jpg
# https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/02/Bess-Wang-400x400.jpg
# https://jour.hkbu.edu.hk/home/wp-content/uploads/2020/01/photo-400x400.jpg
# https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/06/ppl_janet-lo.jpg
# https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/YuWenting-400x400.jpg
# https://jour.hkbu.edu.hk/home/wp-content/uploads/2023/09/Nick-1-400x400.jpg
# https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/03/ppl_bonnie-chiu.jpg
# https://jour.hkbu.edu.hk/home/wp-content/uploads/2018/03/ppl_clemence.jpg
# https://jour.hkbu.edu.hk/home/wp-content/uploads/2016/09/ppl_jenny-lam.jpg
# https://jour.hkbu.edu.hk/home/wp-content/uploads/2021/01/Lam-Wing-Yan-1-400x400.jpeg

# %%
#print(img_urls)
print(type(img_urls))
print(len(img_urls))
# Out:
# <class 'list'>
# 19

# %% [markdown]
# Before we can download the images, we first we need to connect to your Google Drive account.
#
# For security reasons, you will be requested to grant permission to Google Colab to access your Google Drive. Please allow the operation by selecting the correct account where you store your Colab Notebooks.

# %%
from google.colab import drive
drivePath = '/content/drive' #please do not change
drive.mount(drivePath)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Now we can select the correct directory in your Google drive.

# %%
# path to figures directory
figuresPath = drivePath + '/MyDrive/Colab Notebooks/figures' + "/"

# %% [markdown]
# We will also check if the directory is present, creating a new one if needed.

# %%
import os, pathlib
if not(os.path.exists(figuresPath)):
  # os.mkdir(dataPath) # Creates only the last directory if missing. Rises error if it exists
  path = pathlib.Path(figuresPath)
  path.mkdir(parents=True, exist_ok=True) # Can create the folders in the path if missing. No error if path exists
  print('Path has been created')
else:
  print('The figures path you selected already exists')
# Out:
# Path has been created

# %%
# To downloads and save files with Python
# the shutil library which is a file operations library
# it is always good to add a time delay via the "time.sleep" function

import shutil

import time
from random import randint

for idx, img_url in enumerate(img_urls):
    # enumerate to create a file integer name for every image, see the tutorial: http://book.pythontips.com/en/latest/enumerate.html

    # time.sleep(5) # a fixed rate (delay 5 sec)
    time.sleep(randint(2,6))  # a random int delay between 1 to 5 sec

    img_source = requests.get(img_url, stream=True)
    # we set stream = True to download/stream the content of the data

    with open(figuresPath + 'facultyProfilePic' + str(idx) + '.jpg', 'wb') as file:
        # open file connection in write binary mode, create file and write to it
        shutil.copyfileobj(img_source.raw, file)
        # save the raw file object, see the tutorial: https://docs.python.org/3/library/shutil.html

    del img_source # to remove the file from memory
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     467             try:
# --> 468                 self._validate_conn(conn)
#     469             except (SocketTimeout, BaseSSLError) as e:
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1096         if conn.is_closed:
# -> 1097             conn.connect()
#    1098
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in connect(self)
#     641
# --> 642         sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     643             sock=sock,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     782
# --> 783     ssl_sock = ssl_wrap_socket(
#     784         sock=sock,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     470
# --> 471     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     472     return ssl_sock
#
# /usr/local/lib/python3.10/dist-packages/urllib3/util/ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     514
# --> 515     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# /usr/lib/python3.10/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     512         # ctx._wrap_socket()
# --> 513         return self.sslsocket_class._create(
#     514             sock=sock,
#
# /usr/lib/python3.10/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1070                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1071                     self.do_handshake()
#    1072             except (OSError, ValueError):
#
# /usr/lib/python3.10/ssl.py in do_handshake(self, block)
#    1341                 self.settimeout(None)
# -> 1342             self._sslobj.do_handshake()
#    1343         finally:
#
# SSLError: [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1007)
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     491                 new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 492             raise new_e
#     493
#
# SSLError: [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1007)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     844
# --> 845             retries = retries.increment(
#     846                 method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# /usr/local/lib/python3.10/dist-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     514             reason = error or ResponseError(cause)
# --> 515             raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     516
#
# MaxRetryError: HTTPSConnectionPool(host='jour.hkbu.edu.hk', port=443): Max retries exceeded with url: /home/wp-content/uploads/2018/03/ppl_ray-li.jpg (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1007)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-39-aeb49e0248d2> in <cell line: 10>()
#      14     time.sleep(randint(2,6))  # a random int delay between 1 to 5 sec
#      15
# ---> 16     img_source = requests.get(img_url, stream=True)
#      17     # we set stream = True to download/stream the content of the data
#      18
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     515             if isinstance(e.reason, _SSLError):
#     516                 # This branch is for urllib3 v1.22 and later.
# --> 517                 raise SSLError(e, request=request)
#     518
#     519             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='jour.hkbu.edu.hk', port=443): Max retries exceeded with url: /home/wp-content/uploads/2018/03/ppl_ray-li.jpg (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1007)')))

# %% [markdown]
# # Acknowledgements
#
# - The code in this notebook are modified from Dr. Xinzhi Zhang teaching material and other various sources. All codes are for educational purposes only and released under the CC1.0.
